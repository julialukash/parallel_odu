# %%
import pickle
import sys
import numpy as np
import pandas as pd
import artm
import seaborn as sns
import matplotlib.pyplot as plt
print artm.version()

from os import path, mkdir
from datetime import datetime
sys.path.insert(0, '..\\modules\\helpers')

import distances_helper as dh 
import print_helper as ph
import create_model_helper as cmh
import build_convex_hull_helper as bchh
import different_models as dm

from plot_helper import PlotMaker
from config_helper import ConfigPaths
from scipy.optimize import minimize
# Out:
# 0.8.1

# %%
config = ConfigPaths('config_sample_m3.cfg')
print config.models_file_name
models_file = open(config.models_file_name, 'a')

plot_maker = PlotMaker()

batch_vectorizer = artm.BatchVectorizer(data_path=config.output_batches_path,
                                        data_format='batches')
dictionary = artm.Dictionary()
dictionary.load(dictionary_path=config.dictionary_path + '.dict')
# Out:
# Q:\\topic_modeling\\csi_science_collections.git\experiments\pn_model3\np_24_02_kl\models.txt

# %%
def create_model_fn_1(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                             n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_20_m1_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_2(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=100, n_doc_passes=5, seed_value=100 + n_iteration,
                             n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_100_m2_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_3(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = 300
    tmp_model.regularizers['ss_theta_regularizer'].tau = -5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -20
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_20_m3_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_4(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=100, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = 10
    tmp_model.regularizers['ss_theta_regularizer'].tau = -0.5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -2
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_20_m4_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_1(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -3
    tmp_model.regularizers['ss_phi_regularizer'].tau = -3
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                   tmp_model, _n_iterations=20, 
                                   _model_name='model_20_reg_1_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_2(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -5
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,                               
                                  _model_name='model_20_reg_2_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_3(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -10
    tmp_model.regularizers['ss_phi_regularizer'].tau = -10
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_3_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_5(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -20
    tmp_model.regularizers['ss_phi_regularizer'].tau = -20
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_3_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_6(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -30
    tmp_model.regularizers['ss_phi_regularizer'].tau = -30
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_3_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_7(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -40
    tmp_model.regularizers['ss_phi_regularizer'].tau = -40
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_3_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_4(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -5
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = -10 
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_4_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_complex_reg_1(n_iteration):
    n_topics = 20
    common_topics = [u'topic_0', u'topic_1']
    subject_topics = list(set([u'topic_{}'.format(idx) for idx in range(2, 20)]) - set(common_topics))
    tmp_model = create_model_complex(current_dictionary=dictionary, n_topics=n_topics, n_doc_passes=5, 
        seed_value=100 + n_iteration, n_top_tokens=15, p_mass_threshold=0.25, 
        common_topics=common_topics, subject_topics=subject_topics)
    # subject topics
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer_subject', 
        topic_names=subject_topics))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer_subject', 
        topic_names=subject_topics, class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer_subject', 
        topic_names=subject_topics, class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer_subject'].tau = -0.5
    tmp_model.regularizers['ss_phi_regularizer_subject'].tau = -0.5
    tmp_model.regularizers['decorrelator_phi_regularizer_subject'].tau = -10

    # common topics
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer_common', 
        topic_names=subject_topics))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer_common', 
        topic_names=subject_topics, class_ids=['@default_class']))
#     tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer_common', 
#         topic_names=subject_topics, class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer_common'].tau = 0.5
    tmp_model.regularizers['ss_phi_regularizer_common'].tau = 0.5
#     tmp_model.regularizers['decorrelator_phi_regularizer_common'].tau = -10

    tmp_model = fit_one_model_complex(plot_maker, batch_vectorizer, models_file, config, 
                                      tmp_model, _n_iterations=20,             
                                      _model_name='model_20_complex_reg_1_iter_{}'.format(n_iteration))
    return tmp_model

# %%
def save_pickle_file(dists, filename, _path=config.experiment_path):
    pickle_filename = path.join(_path, filename)
    pickle_file = open(pickle_filename, 'wb')
    pickle.dump(dists, pickle_file)
    pickle_file.close()
def save_model_pickle(_model_name, _model, _save=True):
    phi = _model.get_phi()
    phi = phi[(phi.T != 0).any()]
    theta = _model.get_theta()    
    saved_top_tokens = _model.score_tracker['top_tokens_score'].last_tokens
    if _save:
        save_pickle_file(phi, 'phi_{}.p'.format(_model_name))
        save_pickle_file(theta, 'theta_{}.p'.format(_model_name))
        save_pickle_file(saved_top_tokens, 'saved_top_tokens_{}.p'.format(_model_name))
    return phi, theta, saved_top_tokens
def load_pickle_file(filename, _path=config.experiment_path):
    pickle_filename = path.join(_path, filename)
    pickle_file = open(pickle_filename, 'rb')
    p_file = pickle.load(pickle_file)
    pickle_file.close()
    return p_file
def load_model_pickle(_model_name, _distance_name=None, _path=config.experiment_path):
    phi = load_pickle_file('phi_{}.p'.format(_model_name), _path)
    theta = load_pickle_file('theta_{}.p'.format(_model_name), _path)
    saved_top_tokens = load_pickle_file('saved_top_tokens_{}.p'.format(_model_name), _path)
    distances = None
    if _distance_name is not None:
        distances = load_pickle_file('{}.p'.format(_distance_name), _path)
    return phi, theta, saved_top_tokens, distances

# %% [markdown]
# Загрузим оригинальный sample датасет (от model3), до этого скопировав в папку с batches нужные pickle файлы модели.
# Сначала провизуалируем по одной итерации каждой новой модели, а потом будем итерационно строить выпуклую оболочку для каждой модели по отдельности и затем сравнивать их.

# %%
phi_original, theta_original, saved_top_tokens_original, distances_hellinger_model_original = load_model_pickle('model3', 'distances_hellinger_model3', config.output_batches_path)
print phi_original.shape, theta_original.shape
# Out:
# (2216, 100) (100, 3446)

# %% [markdown]
# Запустить несколько раз с разным рандомом. Следить за тем, чтобы накапливались только независимые темы. Каждый раз смотреть. как проектируется на оригинальную матрицу.

# %%
# now some info from run
# distibution of topics in convex hull by iteration
def plot_convex_hull_topics_iterations_distribution(_phi_convex_hull):
    get_iteration_number_fn = lambda x: int(x[x.find('_', 6) + 1 : ])
    phi_convex_hull_iteration_number = [get_iteration_number_fn(col) for col in _phi_convex_hull.columns]
    phi_convex_hull_iteration_number = [(val, phi_convex_hull_iteration_number.count(val), 1.0 * phi_convex_hull_iteration_number.count(val) / len(phi_convex_hull_iteration_number)) for val in set(phi_convex_hull_iteration_number)]
    
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
    sns.barplot([x[0] for x in phi_convex_hull_iteration_number], [x[1] for x in phi_convex_hull_iteration_number], ax=ax1)
    ax1.set_title('Number of topics from each iteration')
    ax1.set_xlabel('n iteration')

    sns.barplot([x[0] for x in phi_convex_hull_iteration_number], [x[2] for x in phi_convex_hull_iteration_number], ax=ax2)
    ax2.set_title('Number of topics from each iteration (%)')
    ax2.set_xlabel('n iteration')
def plot_convex_hull_columns_change(iterations_info):
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
    ax1.plot([sum([val['n_topics_to_remove']for val in it['iterations_info_filter']]) for it in iterations_info], 
             color='r', label = 'total')
    ax1.set_title('Num columns to remove')
    get_topic_iteration_fn = lambda x: int(x[x.rfind('_') + 1 :])
    get_topic_filter_iteration_list_fn = lambda x, y: [get_topic_iteration_fn(topic) for topic in x].count(y)
    n_topics_removed_from_current_iteration = [sum([get_topic_filter_iteration_list_fn(val['removed_topics'], indx) for val in it['iterations_info_filter']]) for indx, it in enumerate(iterations_info)]
    ax1.plot(n_topics_removed_from_current_iteration, color='b', label='current iteration')
    ax1.set_xlabel('n iteration')
    ax1.legend()

    ax2.plot([val['phi_convex_hull_shape'][1] for val in iterations_info], color='r')
    ax2.set_title('Num columns of convex hull')
    ax2.set_xlabel('n iteration')
    ax2.legend()
def plot_opt_res_fun(iterations_filtering_info_name):
    # %matplotlib inline
    iterations_filtering_info = load_pickle_file(iterations_filtering_info_name)
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
    values = [x.fun for item in iterations_filtering_info for val in item for x in val['opt_res'].values()]
    sns.distplot(values, color='r', bins=10, ax=ax1)
    values = [[x.fun for val in item for x in val['opt_res'].values()] for item in iterations_filtering_info]
    for val in values:
        sns.distplot(val, bins=10, ax=ax2)
def plot_opt_res_fun_filtering(iterations_filtering_info_name):
    iterations_info = load_pickle_file(iterations_filtering_info_name)
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
    values = [x.fun for item in iterations_info for val in item['iterations_info_filter'] for x in val['opt_res'].values()]
    sns.distplot(values, color='r', bins=10, ax=ax1)
    values = [[x.fun for val in item['iterations_info_filter'] for x in val['opt_res'].values()] for item in iterations_info]
    for val in values:
        sns.distplot(val, bins=10, ax=ax2)

# %% [markdown]
# # granularity

# %%
def get_phi_granularity(phi):
    return np.mean([get_words_close_to_th_count(col)[0] for topic, col in phi.iteritems()])
def get_words_close_to_th_count(col, global_th=0.95):
    cur_sum, sum_count = 0, 0
    for val in col.sort_values()[::-1]:
        if cur_sum + val <= global_th:
            cur_sum += val
            sum_count += 1
        else:
            break
    return sum_count + 1, cur_sum
def get_opt_x_granularity(opt):
    return np.mean([get_opt_x_close_to_th_count(opt_res.x)[0] for topic, opt_res in opt.iteritems()])
def get_opt_x_close_to_th_count(opt_x, cut_th=None, global_th=0.95):
    cur_sum, sum_count = 0, 0
    opt_x_val = opt_x.copy()
    if cut_th != None:
        opt_x_val[opt_x_val < cut_th] = 0
    for val in sorted(opt_x_val)[::-1]:
        if val !=0 and cur_sum + val <= global_th:
            cur_sum += val
            sum_count += 1
        else:
            break
    return sum_count + 1, cur_sum
def get_and_plot_granularity(phi, opt_to_original, name):
    x_count_grans = [get_opt_x_close_to_th_count(opt_res['x'])[0] for topic, opt_res in opt_to_original.iteritems()]
    x_count_grans_mean = np.mean(x_count_grans)
    x_count_grans_th = [get_opt_x_close_to_th_count(opt_res['x'], cut_th=5*1e-2)[0] for topic, opt_res in opt_to_original.iteritems()]
    x_count_grans_mean_th = np.mean(x_count_grans_th)
    grans = [get_words_close_to_th_count(col)[0] for topic, col in phi.iteritems()]
    grans_mean = np.mean(grans) 
    
    fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=False, figsize=(15,5))
    sns.distplot(x_count_grans, color='r', bins=5, ax=ax1)
    sns.distplot(x_count_grans_th, color='b', bins=5, ax=ax1)
    for topic, opt_res in opt_to_original.iteritems():
        ax2.plot(sorted(opt_res['x'])[::-1])
    sns.distplot(grans, color='r', bins=5, ax=ax3)
    title = '{} {} \nx_count_grans_mean = {}; th={}'.format(name, phi.shape, x_count_grans_mean, x_count_grans_mean_th)
    ax1.set_title(title)
    title = '{} {} \ngrans_mean = {}'.format(name, phi.shape, grans_mean)
    ax3.set_title(title)

    return x_count_grans, x_count_grans_mean, grans, grans_mean
def get_distances(phi_original, name):
    phi_convex_hull = load_pickle_file(name)
    distances_to_original = bchh.calculate_distances(dh.hellinger_dist, phi_convex_hull, phi_original)
    inter_distances = bchh.calculate_distances(dh.hellinger_dist, phi_convex_hull, phi_convex_hull)
    opt_res_to_original = bchh.get_optimization_result(dh.hellinger_dist, None, phi_convex_hull, phi_original,
                                                       distances_to_original, n_closest_topics=N_CLOSEST_TOPICS)
    save_pickle_file(distances_to_original, 'distances_to_original__' + name)
    save_pickle_file(inter_distances, 'inter_distances__' + name)
    save_pickle_file(opt_res_to_original, 'opt_res_to_original__' + name)
    return phi_convex_hull, distances_to_original, inter_distances, opt_res_to_original
def load_distances(name):
    phi_convex_hull = load_pickle_file(name)
    distances_to_original = load_pickle_file('distances_to_original__' + name)
    inter_distances = load_pickle_file('inter_distances__' + name)
    opt_res_to_original = load_pickle_file('opt_res_to_original__' + name)
    return phi_convex_hull, distances_to_original, inter_distances, opt_res_to_original
# построим распределение полученных distances
def plot_dists(distances_to_original, inter_distances, opt_res_to_original, name):
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
    vals = distances_to_original.values.flatten()
    sns.distplot(vals[vals != 0], color='r', ax = ax1, label='Inter distances')
    vals = inter_distances.values.flatten()
    sns.distplot(vals[vals != 0],  color='b', ax = ax1, label='Distances to original')
    ax1.set_title("distances  " + name)
    ax1.legend()
    sns.distplot([val.fun for val in opt_res_to_original.itervalues()], color='r', bins=10, ax=ax2)
    ax2.set_title("opts  " + name)
    ax2.legend()

# %% [markdown]
# # task1
# Найти модель (1 итерация filter ch), которая
# * будет иметь гранулярность близкую к original (=55)
# * будет иметь opt_res_mean - через 1

# %%
models_count = 20
names_list, phi_convex_hull_list =  [0] * models_count,  [0] * models_count
iterations_info_list, iterations_filtering_list =  [0] * models_count, [0] * models_count
distances_to_original_list, opt_res_to_original_list, opt_original_to_res_list = [0] * models_count, [0] * models_count, [0] * models_count

# %%
# %matplotlib inline
idx = 0

OPT_FUN_THRESHOLD, N_CLOSEST_TOPICS_COUNT, DIST_FN = 0.6, 15, dh.kl_dist
names_list[idx] = 'em__kl__wf__model_reg3__0.6__15_r1'
phi_convex_hull_list[idx], iterations_info_list[idx], iterations_filtering_list[idx] = bchh \
                                                    .build_convex_hull_with_filtering(
                                                     create_model_fn_20_reg_3,
                                                     bchh.get_topics_to_remove_by_opt_fun_and_distance, 
                                                     DIST_FN,
                                                     bchh.get_em_result_one_matrix,
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     n_closest_topics_count=N_CLOSEST_TOPICS_COUNT,
                                                     opt_fun_threshold=OPT_FUN_THRESHOLD,
                                                     max_iteration=2)
distances_to_original_list[idx] = bchh.calculate_distances(DIST_FN, phi_convex_hull_list[idx], phi_original)
opt_res_to_original_list[idx] = bchh.get_em_result(DIST_FN, None, phi_convex_hull_list[idx], phi_original,
                                                   distances_to_original_list[idx], n_closest_topics=N_CLOSEST_TOPICS_COUNT)
opt_original_to_res_list[idx] = bchh.get_em_result(DIST_FN, None, phi_original,  phi_convex_hull_list[idx],
                                                   distances_to_original_list[idx].T, n_closest_topics=N_CLOSEST_TOPICS_COUNT)

_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_res_to_original_list[idx], names_list[idx])
_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_original_to_res_list[idx], names_list[idx])
# idx += 1
# Out:
# [2017-02-26 20:07:11.429000] ********** iteration = 1 / 2
# name = model_20_reg_3_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-02-26 20:07:38.267000] filtering iteration = 1 / 50
# [2017-02-26 20:09:24.211000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-02-26 20:09:24.212000] topics to remove not increasing, breaking the for loop
# [2017-02-26 20:09:24.212000] current convex_hull shape = (2216, 20)
# [2017-02-26 20:09:24.212000] ********** iteration = 2 / 2
# name = model_20_reg_3_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-02-26 20:09:53.388000] filtering iteration = 1 / 50
# [2017-02-26 20:12:44.194000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-02-26 20:12:44.195000] filtering iteration = 2 / 50
# [2017-02-26 20:15:36.986000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-02-26 20:15:36.987000] topics to remove not increasing, breaking the for loop
# [2017-02-26 20:15:36.987000] current convex_hull shape = (2216, 38)

# %%
# %matplotlib inline
idx = 1

OPT_FUN_THRESHOLD, N_CLOSEST_TOPICS_COUNT, DIST_FN = 0.6, 15, dh.hellinger_dist
names_list[idx] = 'em__hel__wf__model_reg3__0.6__15_r1'
phi_convex_hull_list[idx], iterations_info_list[idx], iterations_filtering_list[idx] = bchh \
                                                    .build_convex_hull_with_filtering(
                                                     create_model_fn_20_reg_3,
                                                     bchh.get_topics_to_remove_by_opt_fun_and_distance, 
                                                     DIST_FN,
                                                     bchh.get_em_result_one_matrix,
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     n_closest_topics_count=N_CLOSEST_TOPICS_COUNT,
                                                     opt_fun_threshold=OPT_FUN_THRESHOLD,
                                                     max_iteration=2)
distances_to_original_list[idx] = bchh.calculate_distances(DIST_FN, phi_convex_hull_list[idx], phi_original)
opt_res_to_original_list[idx] = bchh.get_em_result(DIST_FN, None, phi_convex_hull_list[idx], phi_original,
                                                   distances_to_original_list[idx], n_closest_topics=N_CLOSEST_TOPICS_COUNT)
opt_original_to_res_list[idx] = bchh.get_em_result(DIST_FN, None, phi_original,  phi_convex_hull_list[idx],
                                                   distances_to_original_list[idx].T, n_closest_topics=N_CLOSEST_TOPICS_COUNT)

_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_res_to_original_list[idx], names_list[idx])
_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_original_to_res_list[idx], names_list[idx])
# Out:
# [2017-02-26 19:39:11.813000] ********** iteration = 1 / 2
# name = model_20_reg_3_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-02-26 19:39:35.242000] filtering iteration = 1 / 50
# [2017-02-26 19:41:44.754000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-02
] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 16)
# [2017-02-26 23:24:42.999000] topics to remove not increasing, breaking the for loop
# [2017-02-26 23:24:43] current convex_hull shape = (2216, 16)
# [2017-02-26 23:24:43] ********** iteration = 2 / 2
# name = model_20_reg_3_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-26 23:25:08.606000] filtering iteration = 1 / 50
# [2017-02-26 23:25:15.747000] 1 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 35)
# [2017-02-26 23:25:15.748000] filtering iteration = 2 / 50
# [2017-02-26 23:25:24.251000] 1 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 34)
# [2017-02-26 23:25:24.252000] filtering iteration = 3 / 50
# [2017-02-26 23:25:32.754000] 2 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-02-26 23:25:32.754000] filtering iteration = 4 / 50
# [2017-02-26 23:25:41.375000] 1 topics to remove, 18 not_removed_topics_count because close topics, current convex_hull shape = (2216, 31)
# [2017-02-26 23:25:41.376000] filtering iteration = 5 / 50
# [2017-02-26 23:25:48.276000] 2 topics to remove, 16 not_removed_topics_count because close topics, current convex_hull shape = (2216, 29)
# [2017-02-26 23:25:48.276000] filtering iteration = 6 / 50
# [2017-02-26 23:25:56.881000] 1 topics to remove, 14 not_removed_topics_count because close topics, current convex_hull shape = (2216, 28)
# [2017-02-26 23:25:56.881000] filtering iteration = 7 / 50
# [2017-02-26 23:26:06.290000] 1 topics to remove, 13 not_removed_topics_count because close topics, current convex_hull shape = (2216, 27)
# [2017-02-26 23:26:06.290000] filtering iteration = 8 / 50
# [2017-02-26 23:26:15.085000] 1 topics to remove, 12 not_removed_topics_count because close topics, current convex_hull shape = (2216, 26)
# [2017-02-26 23:26:15.085000] filtering iteration = 9 / 50
# [2017-02-26 23:26:24.047000] 1 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 25)
# [2017-02-26 23:26:24.047000] filtering iteration = 10 / 50
# [2017-02-26 23:26:31.347000] 2 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 23)
# [2017-02-26 23:26:31.347000] filtering iteration = 11 / 50
# [2017-02-26 23:26:38.513000] 2 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 21)
# [2017-02-26 23:26:38.513000] filtering iteration = 12 / 50
# [2017-02-26 23:26:44.041000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-02-26 23:26:44.041000] filtering iteration = 13 / 50
# [2017-02-26 23:26:49.061000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-02-26 23:26:49.061000] topics to remove not increasing, breaking the for loop
# [2017-02-26 23:26:49.061000] current convex_hull shape = (2216, 20)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-1f911b505401> in <module>()
#      22 _,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_res_to_original_list[idx], names_list[idx])
#      23 _,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_original_to_res_list[idx], names_list[idx])
# ---> 24 plot_dists(opt_res_to_original_list[idx], opt_original_to_res_list[idx], names_list[idx])
#
# TypeError: plot_dists() takes exactly 4 arguments (3 given)

# %%
# %matplotlib inline
idx = 7

OPT_FUN_THRESHOLD, N_CLOSEST_TOPICS_COUNT, DIST_FN = 0.6, 15, dh.hellinger_dist
names_list[idx] = 'opt__hel__wf__model_reg7__0.6__15_r1'
phi_convex_hull_list[idx], iterations_info_list[idx], iterations_filtering_list[idx] = bchh \
                                                    .build_convex_hull_with_filtering(
                                                     create_model_fn_20_reg_7,
                                                     bchh.get_topics_to_remove_by_opt_fun_and_distance, 
                                                     DIST_FN,
                                                     bchh.get_optimization_result_one_matrix,
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     n_closest_topics_count=N_CLOSEST_TOPICS_COUNT,
                                                     opt_fun_threshold=OPT_FUN_THRESHOLD,
                                                     max_iteration=2)
distances_to_original_list[idx] = bchh.calculate_distances(DIST_FN, phi_convex_hull_list[idx], phi_original)
opt_res_to_original_list[idx] = bchh.get_optimization_result(DIST_FN, None, phi_convex_hull_list[idx], phi_original,
                                                   distances_to_original_list[idx], n_closest_topics=N_CLOSEST_TOPICS_COUNT)
opt_original_to_res_list[idx] = bchh.get_optimization_result(DIST_FN, None, phi_original,  phi_convex_hull_list[idx],
                                                   distances_to_original_list[idx].T, n_closest_topics=N_CLOSEST_TOPICS_COUNT)

_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_res_to_original_list[idx], names_list[idx])
_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_original_to_res_list[idx], names_list[idx])
# Out:
# [2017-02-27 08:34:22.719000] ********** iteration = 1 / 2
# name = model_20_reg_3_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -40
# ss_phi_regularizer, tau = -40
#
# [2017-02-27 08:34:43.416000] filtering iteration = 1 / 50
# [2017-02-27 08:34:44.513000] 1 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 19)
# [2017-02-27 08:34:44.513000] filtering iteration = 2 / 50
# [2017-02-27 08:34:45.475000] 1 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 18)
# [2017-02-27 08:34:45.476000] filtering iteration = 3 / 50
# [2017-02-27 08:34:46.649000] 1 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 17)
# [2017-02-27 08:34:46.649000] filtering iteration = 4 / 50
# [2017-02-27 08:34:47.530000] 1 topics to remove, 8 not_removed_topics_count because close topics, current convex_hull shape = (2216, 16)
# [2017-02-27 08:34:47.530000] filtering iteration = 5 / 50
# [2017-02-27 08:34:48.521000] 1 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 15)
# [2017-02-27 08:34:48.521000] filtering iteration = 6 / 50
# [2017-02-27 08:34:49.246000] 1 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 14)
# [2017-02-27 08:34:49.247000] filtering iteration = 7 / 50
# [2017-02-27 08:34:49.965000] 1 topics to remove, 5 not_removed_topics_count because close topics, current convex_hull shape = (2216, 13)
# [2017-02-27 08:34:49.965000] filtering iteration = 8 / 50
# [2017-02-27 08:34:50.898000] 1 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 12)
# [2017-02-27 08:34:50.899000] filtering iteration = 9 / 50
# [2017-02-27 08:34:51.805000] 1 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 11)
# [2017-02-27 08:34:51.806000] filtering iteration = 10 / 50
# [2017-02-27 08:34:52.708000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 10)
# [2017-02-27 08:34:52.708000] filtering iteration = 11 / 50
# [2017-02-27 08:34:53.240000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216,
] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-02-27 10:25:00.476000] topics to remove not increasing, breaking the for loop
# [2017-02-27 10:25:00.476000] current convex_hull shape = (2216, 37)
# [2017-02-27 10:25:00.476000] ********** iteration = 15 / 300
# name = model_20_reg_3_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 10:25:21.868000] filtering iteration = 1 / 50
# [2017-02-27 10:25:30.103000] 2 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-27 10:25:30.103000] filtering iteration = 2 / 50
# [2017-02-27 10:25:39.007000] 3 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-27 10:25:39.007000] filtering iteration = 3 / 50
# [2017-02-27 10:25:46.681000] 1 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-27 10:25:46.681000] filtering iteration = 4 / 50
# [2017-02-27 10:25:55.602000] 1 topics to remove, 19 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-27 10:25:55.602000] filtering iteration = 5 / 50
# [2017-02-27 10:26:03.567000] 3 topics to remove, 16 not_removed_topics_count because close topics, current convex_hull shape = (2216, 47)
# [2017-02-27 10:26:03.567000] filtering iteration = 6 / 50
# [2017-02-27 10:26:09.915000] 1 topics to remove, 14 not_removed_topics_count because close topics, current convex_hull shape = (2216, 46)
# [2017-02-27 10:26:09.915000] filtering iteration = 7 / 50
# [2017-02-27 10:26:18.400000] 1 topics to remove, 13 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-27 10:26:18.400000] filtering iteration = 8 / 50
# [2017-02-27 10:26:25.752000] 1 topics to remove, 12 not_removed_topics_count because close topics, current convex_hull shape = (2216, 44)
# [2017-02-27 10:26:25.752000] filtering iteration = 9 / 50
# [2017-02-27 10:26:34.800000] 4 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 40)
# [2017-02-27 10:26:34.800000] filtering iteration = 10 / 50
# [2017-02-27 10:26:40.720000] 1 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-27 10:26:40.720000] filtering iteration = 11 / 50
# [2017-02-27 10:26:46.954000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-27 10:26:46.954000] topics to remove not increasing, breaking the for loop
# [2017-02-27 10:26:46.954000] current convex_hull shape = (2216, 39)
# [2017-02-27 10:26:46.954000] ********** iteration = 16 / 300
# name = model_20_reg_3_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 10:27:08.476000] filtering iteration = 1 / 50
# [2017-02-27 10:27:16.168000] 1 topics to remove, 30 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-27 10:27:16.168000] filtering iteration = 2 / 50
# [2017-02-27 10:27:24.405000] 2 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-27 10:27:24.405000] filtering iteration = 3 / 50
# [2017-02-27 10:27:32.415000] 1 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-27 10:27:32.415000] filtering iteration = 4 / 50
# [2017-02-27 10:27:40.684000] 1 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 10:27:40.684000] filtering iteration = 5 / 50
# [2017-02-27 10:27:49.402000] 1 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-27 10:27:49.402000] filtering iteration = 6 / 50
# [2017-02-27 10:27:57.366000] 1 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-27 10:27:57.366000] filtering iteration = 7 / 50
# [2017-02-27 10:28:07.225000] 1 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-27 10:28:07.225000] filtering iteration = 8 / 50
# [2017-02-27 10:28:16.905000] 1 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-27 10:28:16.906000] filtering iteration = 9 / 50
# [2017-02-27 10:28:27.422000] 5 topics to remove, 15 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-27 10:28:27.422000] filtering iteration = 10 / 50
# [2017-02-27 10:28:35.807000] 2 topics to remove, 8 not_removed_topics_count because close topics, current convex_hull shape = (2216, 43)
# [2017-02-27 10:28:35.807000] filtering iteration = 11 / 50
# [2017-02-27 10:28:42.442000] 1 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 42)
# [2017-02-27 10:28:42.442000] filtering iteration = 12 / 50
# [2017-02-27 10:28:48.575000] 1 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-02-27 10:28:48.575000] filtering iteration = 13 / 50
# [2017-02-27 10:28:54.170000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-27 10:28:54.170000] filtering iteration = 14 / 50
# [2017-02-27 10:29:00.949000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-27 10:29:00.949000] topics to remove not increasing, breaking the for loop
# [2017-02-27 10:29:00.949000] current convex_hull shape = (2216, 39)
# [2017-02-27 10:29:00.949000] ********** iteration = 17 / 300
# name = model_20_reg_3_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 10:29:22.024000] filtering iteration = 1 / 50
# [2017-02-27 10:29:31.524000] 2 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-27 10:29:31.524000] filtering iteration = 2 / 50
# [2017-02-27 10:29:42.375000] 1 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-27 10:29:42.375000] filtering iteration = 3 / 50
# [2017-02-27 10:29:51.252000] 1 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-27 10:29:51.253000] filtering iteration = 4 / 50
# [2017-02-27 10:30:00.442000] 1 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 10:30:00.442000] filtering iteration = 5 / 50
# [2017-02-27 10:30:11.602000] 1 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-27 10:30:11.602000] filtering iteration = 6 / 50
# [2017-02-27 10:30:22.220000] 1 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-27 10:30:22.220000] filtering iteration = 7 / 50
# [2017-02-27 10:30:33.070000] 7 topics to remove, 15 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-27 10:30:33.070000] filtering iteration = 8 / 50
# [2017-02-27 10:30:42.291000] 2 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 43)
# [2017-02-27 10:30:42.291000] filtering iteration = 9 / 50
# [2017-02-27 10:30:50.023000] 1 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 42)
# [2017-02-27 10:30:50.023000] filtering iteration = 10 / 50
# [2017-02-27 10:30:56.892000] 1 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-02-27 10:30:56.892000] filtering iteration = 11 / 50
# [2017-02-27 10:31:03.111000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 40)
# [2017-02-27 10:31:03.111000] filtering iteration = 12 / 50
# [2017-02-27 10:31:07.903000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-27 10:31:07.903000] filtering iteration = 13 / 50
# [2017-02-27 10:31:11.970000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-27 10:31:11.970000] topics to remove not increasing, breaking the for loop
# [2017-02-27 10:31:11.970000] current convex_hull shape = (2216, 39)
# [2017-02-27 10:31:11.970000] ********** iteration = 18 / 300
# name = model_20_reg_3_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 10:31:33.337000] filtering iteration = 1 / 50
# [2017-02-27 10:31:40.596000] 9 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-27 10:31:40.596000] filtering iteration = 2 / 50
# [2017-02-27 10:31:45.327000] 1 topics to remove, 13 not_removed_topics_count because close topics, current convex_hull shape = (2216, 49)
# [2017-02-27 10:31:45.327000] filtering iteration = 3 / 50
# [2017-02-27 10:31:50.112000] 1 topics to remove, 12 not_removed_topics_count because close topics, current convex_hull shape = (2216, 48)
# [2017-02-27 10:31:50.112000] filtering iteration = 4 / 50
# [2017-02-27 10:31:55.122000] 1 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 47)
# [2017-02-27 10:31:55.122000] filtering iteration = 5 / 50
# [2017-02-27 10:32:00.958000] 1 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 46)
# [2017-02-27 10:32:00.958000] filtering iteration = 6 / 50
# [2017-02-27 10:32:06.342000] 1 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-27 10:32:06.342000] filtering iteration = 7 / 50
# ...
# [2017-02-27 20:56:44.286000] ********** iteration = 295 / 300
# name = model_20_reg_3_iter_294, n_topics = 20, n_doc_passes = 5, seed_value = 394, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 20:57:07.940000] filtering iteration = 1 / 50
# [2017-02-27 20:57:21.622000] 4 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 69)
# [2017-02-27 20:57:21.622000] filtering iteration = 2 / 50
# [2017-02-27 20:57:34.646000] 2 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 67)
# [2017-02-27 20:57:34.661000] filtering iteration = 3 / 50
# [2017-02-27 20:57:48.440000] 1 topics to remove, 19 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-27 20:57:48.440000] filtering iteration = 4 / 50
# [2017-02-27 20:58:04.077000] 1 topics to remove, 18 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-27 20:58:04.077000] filtering iteration = 5 / 50
# [2017-02-27 20:58:18.590000] 1 topics to remove, 17 not_removed_topics_count because close topics, current convex_hull shape = (2216, 64)
# [2017-02-27 20:58:18.590000] filtering iteration = 6 / 50
# [2017-02-27 20:58:32.498000] 1 topics to remove, 16 not_removed_topics_count because close topics, current convex_hull shape = (2216, 63)
# [2017-02-27 20:58:32.498000] filtering iteration = 7 / 50
# [2017-02-27 20:58:47.379000] 1 topics to remove, 16 not_removed_topics_count because close topics, current convex_hull shape = (2216, 62)
# [2017-02-27 20:58:47.379000] filtering iteration = 8 / 50
# [2017-02-27 20:59:08.280000] 5 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-27 20:59:08.280000] filtering iteration = 9 / 50
# [2017-02-27 20:59:22.277000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 20:59:22.277000] filtering iteration = 10 / 50
# [2017-02-27 20:59:30.739000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-27 20:59:30.755000] filtering iteration = 11 / 50
# [2017-02-27 20:59:37.224000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-27 20:59:37.224000] topics to remove not increasing, breaking the for loop
# [2017-02-27 20:59:37.224000] current convex_hull shape = (2216, 53)
# [2017-02-27 20:59:37.224000] ********** iteration = 296 / 300
# name = model_20_reg_3_iter_295, n_topics = 20, n_doc_passes = 5, seed_value = 395, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 21:00:00.575000] filtering iteration = 1 / 50
# [2017-02-27 21:00:10.713000] 3 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 70)
# [2017-02-27 21:00:10.713000] filtering iteration = 2 / 50
# [2017-02-27 21:00:22.775000] 2 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 68)
# [2017-02-27 21:00:22.775000] filtering iteration = 3 / 50
# [2017-02-27 21:00:33.166000] 1 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 67)
# [2017-02-27 21:00:33.166000] filtering iteration = 4 / 50
# [2017-02-27 21:00:45.983000] 1 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-27 21:00:45.983000] filtering iteration = 5 / 50
# [2017-02-27 21:01:00.321000] 1 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-27 21:01:00.321000] filtering iteration = 6 / 50
# [2017-02-27 21:01:10.015000] 1 topics to remove, 19 not_removed_topics_count because close topics, current convex_hull shape = (2216, 64)
# [2017-02-27 21:01:10.015000] filtering iteration = 7 / 50
# [2017-02-27 21:01:25.545000] 1 topics to remove, 18 not_removed_topics_count because close topics, current convex_hull shape = (2216, 63)
# [2017-02-27 21:01:25.545000] filtering iteration = 8 / 50
# [2017-02-27 21:01:37.610000] 1 topics to remove, 17 not_removed_topics_count because close topics, current convex_hull shape = (2216, 62)
# [2017-02-27 21:01:37.610000] filtering iteration = 9 / 50
# [2017-02-27 21:01:52.754000] 5 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-27 21:01:52.754000] filtering iteration = 10 / 50
# [2017-02-27 21:02:03.824000] 3 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 21:02:03.824000] filtering iteration = 11 / 50
# [2017-02-27 21:02:12.306000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-27 21:02:12.306000] filtering iteration = 12 / 50
# [2017-02-27 21:02:18.766000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-27 21:02:18.766000] topics to remove not increasing, breaking the for loop
# [2017-02-27 21:02:18.766000] current convex_hull shape = (2216, 53)
# [2017-02-27 21:02:18.766000] ********** iteration = 297 / 300
# name = model_20_reg_3_iter_296, n_topics = 20, n_doc_passes = 5, seed_value = 396, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 21:02:42.638000] filtering iteration = 1 / 50
# [2017-02-27 21:02:53.657000] 3 topics to remove, 31 not_removed_topics_count because close topics, current convex_hull shape = (2216, 70)
# [2017-02-27 21:02:53.657000] filtering iteration = 2 / 50
# [2017-02-27 21:03:05.849000] 2 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 68)
# [2017-02-27 21:03:05.849000] filtering iteration = 3 / 50
# [2017-02-27 21:03:18.388000] 1 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 67)
# [2017-02-27 21:03:18.388000] filtering iteration = 4 / 50
# [2017-02-27 21:03:28.543000] 1 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-27 21:03:28.543000] filtering iteration = 5 / 50
# [2017-02-27 21:03:39.641000] 1 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-27 21:03:39.641000] filtering iteration = 6 / 50
# [2017-02-27 21:03:52.100000] 9 topics to remove, 14 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-27 21:03:52.100000] filtering iteration = 7 / 50
# [2017-02-27 21:04:03.628000] 2 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 21:04:03.628000] filtering iteration = 8 / 50
# [2017-02-27 21:04:11.647000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 21:04:11.647000] topics to remove not increasing, breaking the for loop
# [2017-02-27 21:04:11.647000] current convex_hull shape = (2216, 54)
# [2017-02-27 21:04:11.647000] ********** iteration = 298 / 300
# name = model_20_reg_3_iter_297, n_topics = 20, n_doc_passes = 5, seed_value = 397, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 21:04:35.524000] filtering iteration = 1 / 50
# [2017-02-27 21:04:44.713000] 1 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 73)
# [2017-02-27 21:04:44.713000] filtering iteration = 2 / 50
# [2017-02-27 21:04:53.728000] 2 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 71)
# [2017-02-27 21:04:53.728000] filtering iteration = 3 / 50
# [2017-02-27 21:05:03.218000] 1 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 70)
# [2017-02-27 21:05:03.218000] filtering iteration = 4 / 50
# [2017-02-27 21:05:13.185000] 1 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 69)
# [2017-02-27 21:05:13.185000] filtering iteration = 5 / 50
# [2017-02-27 21:05:22.464000] 1 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 68)
# [2017-02-27 21:05:22.464000] filtering iteration = 6 / 50
# [2017-02-27 21:05:33.227000] 1 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 67)
# [2017-02-27 21:05:33.227000] filtering iteration = 7 / 50
# [2017-02-27 21:05:42.978000] 1 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-27 21:05:42.978000] filtering iteration = 8 / 50
# [2017-02-27 21:05:53.846000] 1 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-27 21:05:53.847000] filtering iteration = 9 / 50
# [2017-02-27 21:06:03.925000] 1 topics to remove, 18 not_removed_topics_count because close topics, current convex_hull shape = (2216, 64)
# [2017-02-27 21:06:03.925000] filtering iteration = 10 / 50
# [2017-02-27 21:06:16.723000] 1 topics to remove, 18 not_removed_topics_count because close topics, current convex_hull shape = (2216, 63)
# [2017-02-27 21:06:16.723000] filtering iteration = 11 / 50
# [2017-02-27 21:06:29.047000] 1 topics to remove, 17 not_removed_topics_count because close topics, current convex_hull shape = (2216, 62)
# [2017-02-27 21:06:29.047000] filtering iteration = 12 / 50
# [2017-02-27 21:06:42.653000] 5 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-27 21:06:42.653000] filtering iteration = 13 / 50
# [2017-02-27 21:06:56.127000] 2 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-27 21:06:56.127000] filtering iteration = 14 / 50
# [2017-02-27 21:07:05.616000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 21:07:05.616000] filtering iteration = 15 / 50
# [2017-02-27 21:07:13.120000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 21:07:13.120000] topics to remove not increasing, breaking the for loop
# [2017-02-27 21:07:13.120000] current convex_hull shape = (2216, 54)
# [2017-02-27 21:07:13.120000] ********** iteration = 299 / 300
# name = model_20_reg_3_iter_298, n_topics = 20, n_doc_passes = 5, seed_value = 398, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 21:07:37.103000] filtering iteration = 1 / 50
# [2017-02-27 21:07:48.988000] 2 topics to remove, 30 not_removed_topics_count because close topics, current convex_hull shape = (2216, 72)
# [2017-02-27 21:07:48.988000] filtering iteration = 2 / 50
# [2017-02-27 21:08:00.131000] 1 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 71)
# [2017-02-27 21:08:00.131000] filtering iteration = 3 / 50
# [2017-02-27 21:08:10.955000] 3 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 68)
# [2017-02-27 21:08:10.955000] filtering iteration = 4 / 50
# Column topic_16_298 not optimized
# [2017-02-27 21:08:24.905000] 1 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 67)
# [2017-02-27 21:08:24.905000] filtering iteration = 5 / 50
# [2017-02-27 21:08:39.054000] 1 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-27 21:08:39.054000] filtering iteration = 6 / 50
# [2017-02-27 21:08:52.971000] 1 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-27 21:08:52.971000] filtering iteration = 7 / 50
# [2017-02-27 21:09:08.440000] 1 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 64)
# [2017-02-27 21:09:08.440000] filtering iteration = 8 / 50
# [2017-02-27 21:09:22.548000] 1 topics to remove, 19 not_removed_topics_count because close topics, current convex_hull shape = (2216, 63)
# [2017-02-27 21:09:22.548000] filtering iteration = 9 / 50
# [2017-02-27 21:09:41.530000] 5 topics to remove, 13 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-27 21:09:41.530000] filtering iteration = 10 / 50
# [2017-02-27 21:09:55.264000] 3 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-27 21:09:55.264000] filtering iteration = 11 / 50
# [2017-02-27 21:10:04.167000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 21:10:04.167000] filtering iteration = 12 / 50
# [2017-02-27 21:10:13.386000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-27 21:10:13.386000] topics to remove not increasing, breaking the for loop
# [2017-02-27 21:10:13.386000] current convex_hull shape = (2216, 54)
# [2017-02-27 21:10:13.386000] ********** iteration = 300 / 300
# name = model_20_reg_3_iter_299, n_topics = 20, n_doc_passes = 5, seed_value = 399, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-02-27 21:10:37.354000] filtering iteration = 1 / 50
# [2017-02-27 21:10:50.317000] 2 topics to remove, 29 not_removed_topics_count because close topics, current convex_hull shape = (2216, 72)
# [2017-02-27 21:10:50.317000] filtering iteration = 2 / 50
# [2017-02-27 21:11:06.370000] 2 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 70)
# [2017-02-27 21:11:06.370000] filtering iteration = 3 / 50
# [2017-02-27 21:11:24.693000] 1 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 69)
# [2017-02-27 21:11:24.693000] filtering iteration = 4 / 50
# [2017-02-27 21:11:41.428000] 1 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 68)
# [2017-02-27 21:11:41.428000] filtering iteration = 5 / 50
# [2017-02-27 21:11:58.118000] 1 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 67)
# [2017-02-27 21:11:58.118000] filtering iteration = 6 / 50
# [2017-02-27 21:12:13.851000] 1 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-27 21:12:13.851000] filtering iteration = 7 / 50
# [2017-02-27 21:12:34.592000] 7 topics to remove, 16 not_removed_topics_count because close topics, current convex_hull shape = (2216, 59)
# [2017-02-27 21:12:34.592000] filtering iteration = 8 / 50
# [2017-02-27 21:12:48.337000] 3 topics to remove, 5 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-27 21:12:48.337000] filtering iteration = 9 / 50
# [2017-02-27 21:13:00.329000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-27 21:13:00.329000] filtering iteration = 10 / 50
# [2017-02-27 21:13:08.608000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-27 21:13:08.608000] topics to remove not increasing, breaking the for loop
# [2017-02-27 21:13:08.608000] current convex_hull shape = (2216, 55)
# Column topic_38 not optimized

# %%
save_pickle_file(phi_convex_hull_list[idx], 'phi_convex_hull___' + names_list[idx])
save_pickle_file(iterations_info_list[idx], 'iterations_info_list___' + names_list[idx])
save_pickle_file(iterations_filtering_list[idx], 'iterations_filtering_list___' + names_list[idx])

plot_convex_hull_topics_iterations_distribution(phi_convex_hull_list[idx])
plot_convex_hull_columns_change(iterations_info_list[idx])
# Out:
# C:\Users\Sheldon\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# %matplotlib inline
idx = 9

OPT_FUN_THRESHOLD, N_CLOSEST_TOPICS_COUNT, DIST_FN = 0.6, 15, dh.hellinger_dist
names_list[idx] = 'opt__hel__wf__model_reg6__0.6__15_r2'
phi_convex_hull_list[idx], iterations_info_list[idx], iterations_filtering_list[idx] = bchh \
                                                    .build_convex_hull_with_filtering(
                                                     create_model_fn_20_reg_6,
                                                     bchh.get_topics_to_remove_by_opt_fun_and_distance, 
                                                     DIST_FN,
                                                     bchh.get_optimization_result_one_matrix,
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     n_closest_topics_count=N_CLOSEST_TOPICS_COUNT,
                                                     opt_fun_threshold=OPT_FUN_THRESHOLD,
                                                     max_iteration=10)
distances_to_original_list[idx] = bchh.calculate_distances(DIST_FN, phi_convex_hull_list[idx], phi_original)
opt_res_to_original_list[idx] = bchh.get_optimization_result(DIST_FN, None, phi_convex_hull_list[idx], phi_original,
                                                   distances_to_original_list[idx], n_closest_topics=N_CLOSEST_TOPICS_COUNT)
opt_original_to_res_list[idx] = bchh.get_optimization_result(DIST_FN, None, phi_original,  phi_convex_hull_list[idx],
                                                   distances_to_original_list[idx].T, n_closest_topics=N_CLOSEST_TOPICS_COUNT)

_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_res_to_original_list[idx], names_list[idx])
_,_,_,_ = get_and_plot_granularity(phi_convex_hull_list[idx], opt_original_to_res_list[idx], names_list[idx])
# Out:
# [2017-03-01 16:36:24.992000] ********** iteration = 1 / 10
# name = model_20_reg_3_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-01 16:37:39.734000] filtering iteration = 1 / 50
# [2017-03-01 16:37:45.276000] 1 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 19)
# [2017-03-01 16:37:45.276000] filtering iteration = 2 / 50
# [2017-03-01 16:37:50.496000] 1 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 18)
# [2017-03-01 16:37:50.496000] filtering iteration = 3 / 50
# [2017-03-01 16:37:56.558000] 1 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216,
] 2 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 31)
# [2017-03-01 17:46:52.854000] filtering iteration = 11 / 50
# Column topic_4_7 not optimized
# [2017-03-01 17:47:11.223000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 30)
# [2017-03-01 17:47:11.224000] filtering iteration = 12 / 50
# [2017-03-01 17:47:20.296000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 29)
# [2017-03-01 17:47:20.296000] filtering iteration = 13 / 50
# [2017-03-01 17:47:28.501000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 29)
# [2017-03-01 17:47:28.502000] topics to remove not increasing, breaking the for loop
# [2017-03-01 17:47:28.502000] current convex_hull shape = (2216, 29)
# [2017-03-01 17:47:28.503000] ********** iteration = 9 / 10
# name = model_20_reg_3_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-01 17:47:50.782000] filtering iteration = 1 / 50
# [2017-03-01 17:48:03.617000] 3 topics to remove, 29 not_removed_topics_count because close topics, current convex_hull shape = (2216, 46)
# [2017-03-01 17:48:03.617000] filtering iteration = 2 / 50
# [2017-03-01 17:48:16.501000] 1 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-03-01 17:48:16.502000] filtering iteration = 3 / 50
# [2017-03-01 17:48:29.512000] 2 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 43)
# [2017-03-01 17:48:29.512000] filtering iteration = 4 / 50
# [2017-03-01 17:48:41.036000] 1 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 42)
# [2017-03-01 17:48:41.037000] filtering iteration = 5 / 50
# [2017-03-01 17:48:57.653000] 1 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-03-01 17:48:57.653000] filtering iteration = 6 / 50
# [2017-03-01 17:49:09.506000] 1 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 40)
# [2017-03-01 17:49:09.506000] filtering iteration = 7 / 50
# [2017-03-01 17:49:24.217000] 3 topics to remove, 16 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-03-01 17:49:24.218000] filtering iteration = 8 / 50
# [2017-03-01 17:49:37.686000] 3 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 34)
# [2017-03-01 17:49:37.686000] filtering iteration = 9 / 50
# [2017-03-01 17:49:46.965000] 2 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-03-01 17:49:46.965000] filtering iteration = 10 / 50
# [2017-03-01 17:49:55.601000] 1 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 31)
# [2017-03-01 17:49:55.601000] filtering iteration = 11 / 50
# [2017-03-01 17:50:03.211000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 30)
# [2017-03-01 17:50:03.211000] filtering iteration = 12 / 50
# [2017-03-01 17:50:10.353000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 30)
# [2017-03-01 17:50:10.353000] topics to remove not increasing, breaking the for loop
# [2017-03-01 17:50:10.354000] current convex_hull shape = (2216, 30)
# [2017-03-01 17:50:10.354000] ********** iteration = 10 / 10
# name = model_20_reg_3_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-01 17:50:31.604000] filtering iteration = 1 / 50
# [2017-03-01 17:50:42.623000] 8 topics to remove, 19 not_removed_topics_count because close topics, current convex_hull shape = (2216, 42)
# [2017-03-01 17:50:42.623000] filtering iteration = 2 / 50
# [2017-03-01 17:50:51.085000] 1 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-03-01 17:50:51.085000] filtering iteration = 3 / 50
# [2017-03-01 17:50:59.701000] 1 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 40)
# [2017-03-01 17:50:59.701000] filtering iteration = 4 / 50
# [2017-03-01 17:51:08.946000] 1 topics to remove, 8 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-03-01 17:51:08.946000] filtering iteration = 5 / 50
# [2017-03-01 17:51:18.346000] 1 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-03-01 17:51:18.346000] filtering iteration = 6 / 50
# [2017-03-01 17:51:27.797000] 1 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-03-01 17:51:27.798000] filtering iteration = 7 / 50
# [2017-03-01 17:51:36.823000] 1 topics to remove, 5 not_removed_topics_count because close topics, current convex_hull shape = (2216, 36)
# [2017-03-01 17:51:36.823000] filtering iteration = 8 / 50
# [2017-03-01 17:51:48.147000] 1 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 35)
# [2017-03-01 17:51:48.147000] filtering iteration = 9 / 50
# [2017-03-01 17:51:59.239000] 1 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 34)
# [2017-03-01 17:51:59.240000] filtering iteration = 10 / 50
# [2017-03-01 17:52:08.500000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 33)
# [2017-03-01 17:52:08.501000] filtering iteration = 11 / 50
# [2017-03-01 17:52:17.574000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 33)
# [2017-03-01 17:52:17.575000] topics to remove not increasing, breaking the for loop
# [2017-03-01 17:52:17.575000] current convex_hull shape = (2216, 33)
