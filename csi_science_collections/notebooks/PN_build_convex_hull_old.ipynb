# %%
import pickle
import sys
import numpy as np
import pandas as pd
import artm
import seaborn as sns
import matplotlib.pyplot as plt
print artm.version()

from os import path, mkdir
from datetime import datetime
sys.path.insert(0, '..\\modules\\helpers')
import distances_helper as dh 
from plot_helper import PlotMaker
from config_helper import ConfigPaths
from print_helper import PrintHelper
from sklearn.decomposition import PCA
from scipy.spatial import ConvexHull
from scipy.optimize import minimize
from sklearn.metrics.pairwise import cosine_distances
from numpy.linalg import norm as euclidean_norm
# Out:
# 0.8.1

# %%
config = ConfigPaths('config_sample_m3.cfg')
print config.models_file_name
models_file = open(config.models_file_name, 'a')

plot_maker = PlotMaker()
printer = PrintHelper()



batch_vectorizer = artm.BatchVectorizer(data_path=config.output_batches_path,
                                        data_format='batches')
dictionary = artm.Dictionary()
dictionary.load(dictionary_path=config.dictionary_path + '.dict')
# Out:
# Q:\\topic_modeling\\csi_science_collections.git\experiments\pn_model3\np_25_01_m3_convex\models.txt

# %%
def create_model(current_dictionary, n_topics, n_doc_passes, seed_value, n_top_tokens, p_mass_threshold, _debug_print=False):    
    if _debug_print:
        print '[{}] creating model'.format(datetime.now())
    model = artm.ARTM(num_topics=n_topics, dictionary=current_dictionary, cache_theta=True, seed=seed_value, 
                  class_ids={'@default_class': 1.0})
    model.num_document_passes = n_doc_passes
    add_scores_to_model(model, n_top_tokens=n_top_tokens, p_mass_threshold=p_mass_threshold)
    return model
def add_scores_to_model(artm_model, n_top_tokens, p_mass_threshold, _debug_print=False):
    if _debug_print:
        print '[{}] adding scores'.format(datetime.now())
    artm_model.scores.add(artm.PerplexityScore(name='perplexity_score',
                                      dictionary=dictionary))
    artm_model.scores.add(artm.SparsityPhiScore(name='ss_phi_score', class_id='@default_class'))
    artm_model.scores.add(artm.SparsityThetaScore(name='ss_theta_score'))
    artm_model.scores.add(artm.TopicKernelScore(name='topic_kernel_score', class_id='@default_class', 
                                                probability_mass_threshold=p_mass_threshold))
    artm_model.scores.add(artm.TopTokensScore(name='top_tokens_score', class_id='@default_class', num_tokens=n_top_tokens))
def fit_one_model(model, _n_iterations, _model_name='', _debug_print=False): 
    if _debug_print:
        print '[{}] fitting'.format(datetime.now())
    model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=_n_iterations)
    if _debug_print:
        print '[{}] outputting'.format(datetime.now())
    printer.print_artm_model(model, _model_name, _n_iterations, output_file=models_file)
    model_pics_file_name =  path.join(config.experiment_path, _model_name)
    plot_maker.make_tm_plots(model, model_pics_file_name)
    model_output_file_name = path.join(config.experiment_path, _model_name + '.txt')
    printer.print_scores(model, _model_name, _n_iterations, model_output_file_name)
    printer.print_top_tokens(model, model_output_file_name)
    return model
def save_pickle_file(dists, filename, _path=config.experiment_path):
    pickle_filename = path.join(_path, filename)
    pickle_file = open(pickle_filename, 'wb')
    pickle.dump(dists, pickle_file)
    pickle_file.close()
def save_model_pickle(_model_name, _model, _save=True):
    phi = _model.get_phi()
    phi = phi[(phi.T != 0).any()]
    theta = _model.get_theta()    
    saved_top_tokens = _model.score_tracker['top_tokens_score'].last_tokens
    if _save:
        save_pickle_file(phi, 'phi_{}.p'.format(_model_name))
        save_pickle_file(theta, 'theta_{}.p'.format(_model_name))
        save_pickle_file(saved_top_tokens, 'saved_top_tokens_{}.p'.format(_model_name))
    return phi, theta, saved_top_tokens
def load_pickle_file(filename, _path=config.experiment_path):
    pickle_filename = path.join(_path, filename)
    pickle_file = open(pickle_filename, 'rb')
    p_file = pickle.load(pickle_file)
    pickle_file.close()
    return p_file
def load_model_pickle(_model_name, _distance_name=None, _path=config.experiment_path):
    phi = load_pickle_file('phi_{}.p'.format(_model_name), _path)
    theta = load_pickle_file('theta_{}.p'.format(_model_name), _path)
    saved_top_tokens = load_pickle_file('saved_top_tokens_{}.p'.format(_model_name), _path)
    distances = None
    if _distance_name is not None:
        distances = load_pickle_file('{}.p'.format(_distance_name), _path)
    return phi, theta, saved_top_tokens, distances




def calculate_distances(dist_fun, _phi, _phi_other, _debug_print=False):
    if _debug_print:
        print '[{}] take_distances between {} columns and {} columns'.format(datetime.now(), len(_phi.columns), len(_phi_other.columns))
    distances = pd.DataFrame(0, index = _phi.columns, columns=_phi_other.columns)
    for idx, col in enumerate(_phi.columns):
        if _debug_print and idx % 20 == 0:
            print '[{}] column {} / {}'.format(datetime.now(), idx, len(_phi.columns))
        for idx_other, col_other in enumerate(_phi_other.columns):
            distance = dist_fun(_phi[col], _phi_other[col_other])
            distances.iloc[idx, idx_other] = distance
    return distances
def get_optimization_result_one_matrix(dist_fn, jac_dist_fn, phi, distances, _debug_print=False):
    opt_results = {}
    for col_idx, col_name in enumerate(phi.columns):
        if _debug_print and col_idx % 20 == 0:
            print '[{}] get_optimization_result for column {} / {}'.format(datetime.now(), col_idx, len(phi.columns))
        column = phi[col_name]
        # delete col from phi
        phi_cut = phi.drop(col_name, axis=1)
        opt_results[col_name] = solve_optimization_problem(dist_fn, jac_dist_fn, column, col_name, phi_cut, distances)
    return opt_results
def get_optimization_result(dist_fn, jac_dist_fn, phi, phi_other, distances):
    opt_results = {}
    for col_idx, col_name in enumerate(phi.columns):
        if _debug_print and col_idx % 20 == 0:
            print '[{}] get_optimization_result for column {} / {}'.format(datetime.now(), col_idx, len(phi.columns))        
        column = phi[col_name]
        opt_results[col_name] = solve_optimization_problem(dist_fn, jac_dist_fn, column, col_name, phi_other, distances)
    return opt_results
def solve_optimization_problem(dist_fn, jac_dist_fn, column, column_name, phi, distances, max_iter=7, verbose=False):
    max_iter = 50
    phi_columns = phi.columns
    # cut distances by phi columns 
    cut_distances = distances[phi_columns]
    # get n closest topics
    closest_column_names = cut_distances.loc[column_name].sort_values().head(N_CLOSEST_TOPICS).index.values
    phi_closest = phi[closest_column_names]
    
    # opt solver
    n_columns = phi_closest.shape[1] 
    bnds = [(0, 1)] * n_columns
    constraints = cons = ({'type': 'eq', 'fun': lambda x:  np.sum(x) - 1, 'jac': lambda x: [1] * n_columns})
    opt_fun = lambda x: dist_fn(column, phi_closest.dot(x))
    jac_fun = lambda x: jac_dist_fn(column, phi_closest, x)
    
    is_optimized = False
    it = 0
    while (not is_optimized) and it != max_iter:
        it += 1
        init_x = np.random.uniform(0, 1, (1, n_columns))
        init_x /= np.sum(init_x)
        if jac_dist_fn is not None:
            res = minimize(opt_fun, jac=jac_fun, x0=init_x, method='SLSQP', bounds=bnds, constraints=cons, options={'maxiter': max_iter, 'disp': verbose})
        else:
            res = minimize(opt_fun, x0=init_x, method='SLSQP', bounds=bnds, constraints=cons, options={'maxiter': max_iter, 'disp': verbose})
        is_optimized = res.success
    if not is_optimized:
        print('Column {} not optimized'.format(column_name))         
    res['column_names'] = phi_closest.columns
    res['optimized_column'] = column_name
#     res['projection'] = phi_closest.dot(res.x)
#     res['column'] = column
    return res

# %% [markdown]
# Загрузим оригинальный sample датасет (от model3), до этого скопировав в папку с batches нужные pickle файлы модели.
# Сначала провизуалируем по одной итерации каждой новой модели, а потом будем итерационно строить выпуклую оболочку для каждой модели по отдельности и затем сравнивать их.

# %%
phi_original, theta_original, saved_top_tokens_original, distances_hellinger_model_original = load_model_pickle('model3', 'distances_hellinger_model3', config.output_batches_path)
print phi_original.shape, theta_original.shape
# Out:
# (2216, 100) (100, 3446)

# %% [markdown]
# Запустить несколько раз с разным рандомом. Следить за тем, чтобы накапливались только независимые темы. Каждый раз смотреть. как проектируется на оригинальную матрицу.

# %%
N_CLOSEST_TOPICS = 10
def create_model_fn_1(n_iteration):
    tmp_model = create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                             n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model = fit_one_model(tmp_model, _n_iterations=20, _model_name='model_20_m1_iter_{}'.format(n_iteration))
    return tmp_model
def create_model_fn_2(n_iteration):
    tmp_model = create_model(current_dictionary=dictionary, n_topics=100, n_doc_passes=5, seed_value=100 + n_iteration,
                             n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model = fit_one_model(tmp_model, _n_iterations=20, _model_name='model_100_m2_iter_{}'.format(n_iteration))
    return tmp_model
def create_model_fn_3(n_iteration):
    tmp_model = create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = 300
    tmp_model.regularizers['ss_theta_regularizer'].tau = -5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -20
    tmp_model = fit_one_model(tmp_model, _n_iterations=20, _model_name='model_20_m3_iter_{}'.format(n_iteration))
    return tmp_model
def filter_convex_hull(phi_convex_hull, get_topics_to_remove_fn, max_iteration=10):
    distances_model_iter = calculate_distances(dh.hellinger_dist, phi_convex_hull, phi_convex_hull)
    iterations_info = []
    for n_iteration in range(max_iteration):
        print('[{}] filtering iteration = {} / {}'.format(datetime.now(), n_iteration + 1, max_iteration))
        # get new opts results
        opt_res_convex_hull_inter = get_optimization_result_one_matrix(dh.hellinger_dist, None, 
                                                                       phi_convex_hull, distances_model_iter)
        # get topics to remove
        topics_to_remove, not_removed_topics_count = get_topics_to_remove_fn(opt_res_convex_hull_inter, distances_model_iter)
        # update phi convex
        phi_convex_hull = remove_topics_from_phi(phi_convex_hull, topics_to_remove)
        distances_model_iter = remove_topics_from_distances_xy(distances_model_iter, topics_to_remove)
        iterations_info.append({'it': n_iteration,
                                'n_topics_to_remove': len(topics_to_remove),
                                'phi_convex_hull_shape': phi_convex_hull.shape,
                                'removed_topics': topics_to_remove,
                                'not_removed_topics_count': not_removed_topics_count,
#                                 'phi_convex_hull': phi_convex_hull, 
                                'opt_res': opt_res_convex_hull_inter})
        print('[{}] {} topics to remove, {} not_removed_topics_count because close topics, current convex_hull shape = {}'.format(datetime.now(), 
               iterations_info[-1]['n_topics_to_remove'], not_removed_topics_count, iterations_info[-1]['phi_convex_hull_shape']))
        if len(iterations_info) >= 2 and iterations_info[-1]['n_topics_to_remove'] == 0 and iterations_info[-2]['n_topics_to_remove'] == 0:
            print('[{}] topics to remove not increasing, breaking the for loop'.format(datetime.now()))
            break
    return phi_convex_hull, iterations_info
def build_convex_hull_with_filtering(create_model_fn, get_topics_to_remove_fn, words,
                      init_convex_hull, start_iteration, max_iteration):
    # init phi of convex hull
    phi_convex_hull = init_convex_hull
    if len(phi_convex_hull) == 0:
        phi_convex_hull = pd.DataFrame(0, index = words, columns=[])
    iterations_info = []
    for n_iteration in range(start_iteration, start_iteration + max_iteration):
        print('[{}] ********** iteration = {} / {}'.format(datetime.now(), n_iteration + 1, start_iteration + max_iteration))
        # build model
        model = create_model_fn(n_iteration)
        phi = model.get_phi()
        # rename phi columns 
        phi.columns = [c + '_{}'.format(n_iteration) for c in phi.columns]
        # add to convex hull
        phi_convex_hull_expanded = pd.concat([phi_convex_hull, phi], axis=1)
        # filter topics 
        phi_convex_hull, iterations_info_filter = filter_convex_hull(phi_convex_hull_expanded, get_topics_to_remove_fn,
                                                                     max_iteration=15)
        iterations_info.append({'it': n_iteration,
                                'phi_convex_hull_shape': phi_convex_hull.shape,
                                'phi_convex_hull_columns': phi_convex_hull.columns,
#                                 'phi_convex_hull': phi_convex_hull,
                                'iterations_info_filter': iterations_info_filter
                               })
        print('[{}] current convex_hull shape = {}'.format(datetime.now(), 
               iterations_info[-1]['phi_convex_hull_shape']))
    return phi_convex_hull, iterations_info
def build_convex_hull_delayed_filtering(create_model_fn, get_topics_to_remove_fn, words,
                      init_convex_hull, start_iteration, max_iteration):
    # init phi of convex hull
    phi_convex_hull = init_convex_hull
    if len(phi_convex_hull) == 0:
        phi_convex_hull = pd.DataFrame(0, index = words, columns=[])
    iterations_info = []
    for n_iteration in range(start_iteration, start_iteration + max_iteration):
        print('[{}] ********** iteration = {} / {}'.format(datetime.now(), n_iteration + 1, start_iteration + max_iteration))
        # build model
        model = create_model_fn(n_iteration)
        phi = model.get_phi()
        # rename phi columns 
        phi.columns = [c + '_{}'.format(n_iteration) for c in phi.columns]
        # add to convex hull
        phi_convex_hull = pd.concat([phi_convex_hull, phi], axis=1)
        # filter topics 
        iterations_info.append({'it': n_iteration,
                                'phi_convex_hull_shape': phi_convex_hull.shape})
        print('[{}] current convex_hull shape = {}'.format(datetime.now(), 
               iterations_info[-1]['phi_convex_hull_shape']))
    phi_convex_hull, iterations_info_filter = filter_convex_hull(phi_convex_hull, get_topics_to_remove_fn,
                                                                 max_iteration=150)    
    return phi_convex_hull, iterations_info_filter
def get_topics_to_remove_by_opt_fun_and_distance(opt_res, distances, n_closest=N_CLOSEST_TOPICS):
    small_dist_opts = {k:i for k, i in opt_res.iteritems() if i['fun'] < OPT_FUN_THRESHOLD}
    sorted_by_fun = sorted(small_dist_opts.values(), key = lambda opt: opt['fun'])
    topics_to_remove = []
    not_removed_count = 0 
    for opt_res in sorted_by_fun:
        topic_name = opt_res.optimized_column
        # check not close to current topics to remove
        is_close_fn = lambda topic, other_topic: other_topic in distances[topic].sort_values().head(n_closest).index
        is_close_to_topics_to_remove = [is_close_fn(topic_name, t) for t in topics_to_remove]
        is_close_to_topics_to_remove = True in is_close_to_topics_to_remove 
        if not is_close_to_topics_to_remove:
            topics_to_remove.append(topic_name)
        else:
            not_removed_count += 1 
    return topics_to_remove, not_removed_count
def get_topics_to_remove_by_opt_fun(opt_res, distances, n_closest=N_CLOSEST_TOPICS):
    small_dist_opts = {k:i for k, i in opt_res.iteritems() if i['fun'] < OPT_FUN_THRESHOLD}
    topics_to_remove = [x['optimized_column'] for x in small_dist_opts.values()]
    not_removed_count = 0
    return topics_to_remove, not_removed_count
def get_topics_to_remove_by_opt_fun_single(opt_res, distances, n_closest=N_CLOSEST_TOPICS):
    small_dist_opts = {k:i for k, i in opt_res.iteritems() if i['fun'] < OPT_FUN_THRESHOLD}
    topics_to_remove = [x['optimized_column'] for x in small_dist_opts.values()][0:1]
    not_removed_count = 0
    return topics_to_remove, not_removed_count
def remove_topics_from_phi(phi, topics_to_remove):
    return phi.drop(topics_to_remove, axis=1)
def remove_topics_from_distances_x(distances, topics_to_remove):
    distances_convex_hull = distances.drop(topics_to_remove, axis=0)
    return distances_convex_hull
def remove_topics_from_distances_xy(distances, topics_to_remove):
    distances_convex_hull = distances.drop(topics_to_remove, axis=1)
    distances_convex_hull = distances_convex_hull.drop(topics_to_remove, axis=0)
    return distances_convex_hull

# %%
# now some info from run
# distibution of topics in convex hull by iteration
def plot_convex_hull_topics_iterations_distribution(_phi_convex_hull):
    get_iteration_number_fn = lambda x: int(x[x.find('_', 6) + 1 : ])
    phi_convex_hull_iteration_number = [get_iteration_number_fn(col) for col in _phi_convex_hull.columns]
    phi_convex_hull_iteration_number = [(val, phi_convex_hull_iteration_number.count(val), 1.0 * phi_convex_hull_iteration_number.count(val) / len(phi_convex_hull_iteration_number)) for val in set(phi_convex_hull_iteration_number)]
    print(phi_convex_hull_iteration_number)
    
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
    sns.barplot([x[0] for x in phi_convex_hull_iteration_number], [x[1] for x in phi_convex_hull_iteration_number], ax=ax1)
    ax1.set_title('Number of topics from each iteration')
    ax1.set_xlabel('n iteration')

    sns.barplot([x[0] for x in phi_convex_hull_iteration_number], [x[2] for x in phi_convex_hull_iteration_number], ax=ax2)
    ax2.set_title('Number of topics from each iteration (%)')
    ax2.set_xlabel('n iteration')
def plot_convex_hull_columns_change(iterations_info):
    fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
    ax1.plot([sum([val['n_topics_to_remove']for val in it['iterations_info_filter']]) for it in iterations_info], 
             color='r', label = 'total')
    ax1.set_title('Num columns to remove')
    get_topic_iteration_fn = lambda x: int(x[x.rfind('_') + 1 :])
    get_topic_filter_iteration_list_fn = lambda x, y: [get_topic_iteration_fn(topic) for topic in x].count(y)
    n_topics_removed_from_current_iteration = [sum([get_topic_filter_iteration_list_fn(val['removed_topics'], indx) for val in it['iterations_info_filter']]) for indx, it in enumerate(iterations_info)]
    ax1.plot(n_topics_removed_from_current_iteration, color='b', label='current iteration')
    ax1.set_xlabel('n iteration')
    ax1.legend()

    ax2.plot([val['phi_convex_hull_shape'][1] for val in iterations_info], color='r')
    ax2.set_title('Num columns of convex hull')
    ax2.set_xlabel('n iteration')
    ax2.legend()

# %% [markdown]
# Попробовать несколько стратегий:
# 1. Запустить n раз построение модели и накопить n_topics * n тем. Затем запустить фильтрацию.
# 2. Запустить n раз построение модели, на каждом шаге производить фильтрацию.
#
# TODO:
# - попробовать другой метод оптимизации
# - увеличить число повторов
# - сохранять результат: для каждого шага сохранять названия тем, расстояния, топ слова

# %% [markdown]
# # build_convex_hull_delayed_filtering

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_1, iterations_info_1 = build_convex_hull_delayed_filtering(create_model_fn_1, get_topics_to_remove_by_opt_fun_and_distance, 
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=150)
# Out:
# [2017-02-04 14:00:44.447000] ********** iteration = 1 / 150
# name = model_20_m1_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:01:34.715000] current convex_hull shape = (2216, 20)
# [2017-02-04 14:01:34.716000] ********** iteration = 2 / 150
# name = model_20_m1_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:02:19.514000] current convex_hull shape = (2216, 40)
# [2017-02-04 14:02:19.514000] ********** iteration = 3 / 150
# name = model_20_m1_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:03:05.120000] current convex_hull shape = (2216, 60)
# [2017-02-04 14:03:05.120000] ********** iteration = 4 / 150
# name = model_20_m1_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:03:43.492000] current convex_hull shape = (2216, 80)
# [2017-02-04 14:03:43.492000] ********** iteration = 5 / 150
# name = model_20_m1_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:04:36.893000] current convex_hull shape = (2216, 100)
# [2017-02-04 14:04:36.893000] ********** iteration = 6 / 150
# name = model_20_m1_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:05:20.327000] current convex_hull shape = (2216, 120)
# [2017-02-04 14:05:20.328000] ********** iteration = 7 / 150
# name = model_20_m1_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:05:59.702000] current convex_hull shape = (2216, 140)
# [2017-02-04 14:05:59.702000] ********** iteration = 8 / 150
# name = model_20_m1_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:06:37.636000] current convex_hull shape = (2216, 160)
# [2017-02-04 14:06:37.638000] ********** iteration = 9 / 150
# name = model_20_m1_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:07:15.057000] current convex_hull shape = (2216, 180)
# [2017-02-04 14:07:15.058000] ********** iteration = 10 / 150
# name = model_20_m1_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:07:51.935000] current convex_hull shape = (2216, 200)
# [2017-02-04 14:07:51.935000] ********** iteration = 11 / 150
# name = model_20_m1_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:08:27.505000] current convex_hull shape = (2216, 220)
# [2017-02-04 14:08:27.505000] ********** iteration = 12 / 150
# name = model_20_m1_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:09:23.813000] current convex_hull shape = (2216, 240)
# [2017-02-04 14:09:23.813000] ********** iteration = 13 / 150
# name = model_20_m1_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:10:00.562000] current convex_hull shape = (2216, 260)
# [2017-02-04 14:10:00.562000] ********** iteration = 14 / 150
# name = model_20_m1_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:10:35.147000] current convex_hull shape = (2216, 280)
# [2017-02-04 14:10:35.148000] ********** iteration = 15 / 150
# name = model_20_m1_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:11:11.137000] current convex_hull shape = (2216, 300)
# [2017-02-04 14:11:11.138000] ********** iteration = 16 / 150
# name = model_20_m1_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:11:45.612000] current convex_hull shape = (2216, 320)
# [2017-02-04 14:11:45.612000] ********** iteration = 17 / 150
# name = model_20_m1_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:12:19.785000] current convex_hull shape = (2216, 340)
# [2017-02-04 14:12:19.786000] ********** iteration = 18 / 150
# name = model_20_m1_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:12:53.218000] current convex_hull shape = (2216, 360)
# [2017-02-04 14:12:53.219000] ********** iteration = 19 / 150
# name = model_20_m1_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:13:31.198000] current convex_hull shape = (2216, 380)
# [2017-02-04 14:13:31.199000] ********** iteration = 20 / 150
# name = model_20_m1_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:14:20.384000] current convex_hull shape = (2216, 400)
# [2017-02-04 14:14:20.385000] ********** iteration = 21 / 150
# name = model_20_m1_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:14:55.657000] current convex_hull shape = (2216, 420)
# [2017-02-04 14:14:55.658000] ********** iteration = 22 / 150
# name = model_20_m1_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:15:29.879000] current convex_hull shape = (2216, 440)
# [2017-02-04 14:15:29.880000] ********** iteration = 23 / 150
# name = model_20_m1_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:16:03.427000] current convex_hull shape = (2216, 460)
# [2017-02-04 14:16:03.428000] ********** iteration = 24 / 150
# name = model_20_m1_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:16:37.264000] current convex_hull shape = (2216, 480)
# [2017-02-04 14:16:37.265000] ********** iteration = 25 / 150
# name = model_20_m1_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:17:13.849000] current convex_hull shape = (2216, 500)
# [2017-02-04 14:17:13.849000] ********** iteration = 26 / 150
# name = model_20_m1_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:17:56.210000] current convex_hull shape = (2216, 520)
# [2017-02-04 14:17:56.210000] ********** iteration = 27 / 150
# name = model_20_m1_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:18:37.897000] current convex_hull shape = (2216, 540)
# [2017-02-04 14:18:37.898000] ********** iteration = 28 / 150
# name = model_20_m1_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:19:15.542000] current convex_hull shape = (2216, 560)
# [2017-02-04 14:19:15.542000] ********** iteration = 29 / 150
# name = model_20_m1_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:19:51.556000] current convex_hull shape = (2216, 580)
# [2017-02-04 14:19:51.556000] ********** iteration = 30 / 150
# name = model_20_m1_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:20:24.085000] current convex_hull shape = (2216, 600)
# [2017-02-04 14:20:24.085000] ********** iteration = 31 / 150
# name = model_20_m1_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:20:57.630000] current convex_hull shape = (2216, 620)
# [2017-02-04 14:20:57.631000] ********** iteration = 32 / 150
# name = model_20_m1_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:21:30.963000] current convex_hull shape = (2216, 640)
# [2017-02-04 14:21:30.964000] ********** iteration = 33 / 150
# name = model_20_m1_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:22:03.656000] current convex_hull shape = (2216, 660)
# [2017-02-04 14:22:03.657000] ********** iteration = 34 / 150
# name = model_20_m1_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:22:53.376000] current convex_hull shape = (2216, 680)
# [2017-02-04 14:22:53.376000] ********** iteration = 35 / 150
# name = model_20_m1_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:23:24.785000] current convex_hull shape = (2216, 700)
# [2017-02-04 14:23:24.785000] ********** iteration = 36 / 150
# name = model_20_m1_iter_35, n_topics = 20, n_doc_passes = 5, seed_value = 135, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:23:58.546000] current convex_hull shape = (2216, 720)
# [2017-02-04 14:23:58.546000] ********** iteration = 37 / 150
# name = model_20_m1_iter_36, n_topics = 20, n_doc_passes = 5, seed_value = 136, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:24:34.451000] current convex_hull shape = (2216, 740)
# [2017-02-04 14:24:34.452000] ********** iteration = 38 / 150
# name = model_20_m1_iter_37, n_topics = 20, n_doc_passes = 5, seed_value = 137, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:25:09.847000] current convex_hull shape = (2216, 760)
# [2017-02-04 14:25:09.848000] ********** iteration = 39 / 150
# name = model_20_m1_iter_38, n_topics = 20, n_doc_passes = 5, seed_value = 138, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:25:42.056000] current convex_hull shape = (2216, 780)
# [2017-02-04 14:25:42.057000] ********** iteration = 40 / 150
# name = model_20_m1_iter_39, n_topics = 20, n_doc_passes = 5, seed_value = 139, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:26:15.116000] current convex_hull shape = (2216, 800)
# [2017-02-04 14:26:15.117000] ********** iteration = 41 / 150
# name = model_20_m1_iter_40, n_topics = 20, n_doc_passes = 5, seed_value = 140, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:26:50.929000] current convex_hull shape = (2216, 820)
# [2017-02-04 14:26:50.929000] ********** iteration = 42 / 150
# name = model_20_m1_iter_41, n_topics = 20, n_doc_passes = 5, seed_value = 141, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:27:50.006000] current convex_hull shape = (2216, 840)
# [2017-02-04 14:27:50.007000] ********** iteration = 43 / 150
# name = model_20_m1_iter_42, n_topics = 20, n_doc_passes = 5, seed_value = 142, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:28:24.657000] current convex_hull shape = (2216, 860)
# [2017-02-04 14:28:24.657000] ********** iteration = 44 / 150
# name = model_20_m1_iter_43, n_topics = 20, n_doc_passes = 5, seed_value = 143, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:28:58.083000] current convex_hull shape = (2216, 880)
# [2017-02-04 14:28:58.084000] ********** iteration = 45 / 150
# name = model_20_m1_iter_44, n_topics = 20, n_doc_passes = 5, seed_value = 144, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:29:32.222000] current convex_hull shape = (2216, 900)
# [2017-02-04 14:29:32.223000] ********** iteration = 46 / 150
# name = model_20_m1_iter_45, n_topics = 20, n_doc_passes = 5, seed_value = 145, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:30:05.764000] current convex_hull shape = (2216, 920)
# [2017-02-04 14:30:05.764000] ********** iteration = 47 / 150
# name = model_20_m1_iter_46, n_topics = 20, n_doc_passes = 5, seed_value = 146, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:30:38.843000] current convex_hull shape = (2216, 940)
# [2017-02-04 14:30:38.843000] ********** iteration = 48 / 150
# name = model_20_m1_iter_47, n_topics = 20, n_doc_passes = 5, seed_value = 147, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:31:17.502000] current convex_hull shape = (2216, 960)
# [2017-02-04 14:31:17.503000] ********** iteration = 49 / 150
# name = model_20_m1_iter_48, n_topics = 20, n_doc_passes = 5, seed_value = 148, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:32:11.073000] current convex_hull shape = (2216, 980)
# [2017-02-04 14:32:11.074000] ********** iteration = 50 / 150
# name = model_20_m1_iter_49, n_topics = 20, n_doc_passes = 5, seed_value = 149, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:32:52.338000] current convex_hull shape = (2216, 1000)
# [2017-02-04 14:32:52.338000] ********** iteration = 51 / 150
# name = model_20_m1_iter_50, n_topics = 20, n_doc_passes = 5, seed_value = 150, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:33:31.895000] current convex_hull shape = (2216, 1020)
# [2017-02-04 14:33:31.895000] ********** iteration = 52 / 150
# name = model_20_m1_iter_51, n_topics = 20, n_doc_passes = 5, seed_value = 151, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:34:04.812000] current convex_hull shape = (2216, 1040)
# [2017-02-04 14:34:04.812000] ********** iteration = 53 / 150
# name = model_20_m1_iter_52, n_topics = 20, n_doc_passes = 5, seed_value = 152, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:34:39.189000] current convex_hull shape = (2216, 1060)
# [2017-02-04 14:34:39.189000] ********** iteration = 54 / 150
# name = model_20_m1_iter_53, n_topics = 20, n_doc_passes = 5, seed_value = 153, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:35:11.431000] current convex_hull shape = (2216, 1080)
# [2017-02-04 14:35:11.432000] ********** iteration = 55 / 150
# name = model_20_m1_iter_54, n_topics = 20, n_doc_passes = 5, seed_value = 154, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:35:45.181000] current convex_hull shape = (2216, 1100)
# [2017-02-04 14:35:45.182000] ********** iteration = 56 / 150
# name = model_20_m1_iter_55, n_topics = 20, n_doc_passes = 5, seed_value = 155, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:36:36.096000] current convex_hull shape = (2216, 1120)
# [2017-02-04 14:36:36.096000] ********** iteration = 57 / 150
# name = model_20_m1_iter_56, n_topics = 20, n_doc_passes = 5, seed_value = 156, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:37:09.411000] current convex_hull shape = (2216, 1140)
# [2017-02-04 14:37:09.411000] ********** iteration = 58 / 150
# name = model_20_m1_iter_57, n_topics = 20, n_doc_passes = 5, seed_value = 157, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:37:45.498000] current convex_hull shape = (2216, 1160)
# [2017-02-04 14:37:45.499000] ********** iteration = 59 / 150
# name = model_20_m1_iter_58, n_topics = 20, n_doc_passes = 5, seed_value = 158, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:38:16.939000] current convex_hull shape = (2216, 1180)
# [2017-02-04 14:38:16.939000] ********** iteration = 60 / 150
# name = model_20_m1_iter_59, n_topics = 20, n_doc_passes = 5, seed_value = 159, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:38:50.902000] current convex_hull shape = (2216, 1200)
# [2017-02-04 14:38:50.903000] ********** iteration = 61 / 150
# name = model_20_m1_iter_60, n_topics = 20, n_doc_passes = 5, seed_value = 160, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:39:25.421000] current convex_hull shape = (2216, 1220)
# [2017-02-04 14:39:25.421000] ********** iteration = 62 / 150
# name = model_20_m1_iter_61, n_topics = 20, n_doc_passes = 5, seed_value = 161, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:39:59.493000] current convex_hull shape = (2216, 1240)
# [2017-02-04 14:39:59.494000] ********** iteration = 63 / 150
# name = model_20_m1_iter_62, n_topics = 20, n_doc_passes = 5, seed_value = 162, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:40:48.148000] current convex_hull shape = (2216, 1260)
# [2017-02-04 14:40:48.149000] ********** iteration = 64 / 150
# name = model_20_m1_iter_63, n_topics = 20, n_doc_passes = 5, seed_value = 163, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:41:22.040000] current convex_hull shape = (2216, 1280)
# [2017-02-04 14:41:22.041000] ********** iteration = 65 / 150
# name = model_20_m1_iter_64, n_topics = 20, n_doc_passes = 5, seed_value = 164, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:41:55.526000] current convex_hull shape = (2216, 1300)
# [2017-02-04 14:41:55.527000] ********** iteration = 66 / 150
# name = model_20_m1_iter_65, n_topics = 20, n_doc_passes = 5, seed_value = 165, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:42:28.605000] current convex_hull shape = (2216, 1320)
# [2017-02-04 14:42:28.605000] ********** iteration = 67 / 150
# name = model_20_m1_iter_66, n_topics = 20, n_doc_passes = 5, seed_value = 166, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:43:02.315000] current convex_hull shape = (2216, 1340)
# [2017-02-04 14:43:02.315000] ********** iteration = 68 / 150
# name = model_20_m1_iter_67, n_topics = 20, n_doc_passes = 5, seed_value = 167, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:43:32.914000] current convex_hull shape = (2216, 1360)
# [2017-02-04 14:43:32.915000] ********** iteration = 69 / 150
# name = model_20_m1_iter_68, n_topics = 20, n_doc_passes = 5, seed_value = 168, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:44:22.653000] current convex_hull shape = (2216, 1380)
# [2017-02-04 14:44:22.654000] ********** iteration = 70 / 150
# name = model_20_m1_iter_69, n_topics = 20, n_doc_passes = 5, seed_value = 169, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:44:56.724000] current convex_hull shape = (2216, 1400)
# [2017-02-04 14:44:56.725000] ********** iteration = 71 / 150
# name = model_20_m1_iter_70, n_topics = 20, n_doc_passes = 5, seed_value = 170, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:45:31.152000] current convex_hull shape = (2216, 1420)
# [2017-02-04 14:45:31.152000] ********** iteration = 72 / 150
# name = model_20_m1_iter_71, n_topics = 20, n_doc_passes = 5, seed_value = 171, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:46:03.674000] current convex_hull shape = (2216, 1440)
# [2017-02-04 14:46:03.674000] ********** iteration = 73 / 150
# name = model_20_m1_iter_72, n_topics = 20, n_doc_passes = 5, seed_value = 172, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:46:36.194000] current convex_hull shape = (2216, 1460)
# [2017-02-04 14:46:36.194000] ********** iteration = 74 / 150
# name = model_20_m1_iter_73, n_topics = 20, n_doc_passes = 5, seed_value = 173, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:47:10.215000] current convex_hull shape = (2216, 1480)
# [2017-02-04 14:47:10.216000] ********** iteration = 75 / 150
# name = model_20_m1_iter_74, n_topics = 20, n_doc_passes = 5, seed_value = 174, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:47:45.202000] current convex_hull shape = (2216, 1500)
# [2017-02-04 14:47:45.202000] ********** iteration = 76 / 150
# name = model_20_m1_iter_75, n_topics = 20, n_doc_passes = 5, seed_value = 175, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:48:16.169000] current convex_hull shape = (2216, 1520)
# [2017-02-04 14:48:16.169000] ********** iteration = 77 / 150
# name = model_20_m1_iter_76, n_topics = 20, n_doc_passes = 5, seed_value = 176, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:49:07.715000] current convex_hull shape = (2216, 1540)
# [2017-02-04 14:49:07.716000] ********** iteration = 78 / 150
# name = model_20_m1_iter_77, n_topics = 20, n_doc_passes = 5, seed_value = 177, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:49:40.766000] current convex_hull shape = (2216, 1560)
# [2017-02-04 14:49:40.767000] ********** iteration = 79 / 150
# name = model_20_m1_iter_78, n_topics = 20, n_doc_passes = 5, seed_value = 178, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:50:15.545000] current convex_hull shape = (2216, 1580)
# [2017-02-04 14:50:15.545000] ********** iteration = 80 / 150
# name = model_20_m1_iter_79, n_topics = 20, n_doc_passes = 5, seed_value = 179, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:50:46.665000] current convex_hull shape = (2216, 1600)
# [2017-02-04 14:50:46.665000] ********** iteration = 81 / 150
# name = model_20_m1_iter_80, n_topics = 20, n_doc_passes = 5, seed_value = 180, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:51:21.640000] current convex_hull shape = (2216, 1620)
# [2017-02-04 14:51:21.641000] ********** iteration = 82 / 150
# name = model_20_m1_iter_81, n_topics = 20, n_doc_passes = 5, seed_value = 181, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:51:53.930000] current convex_hull shape = (2216, 1640)
# [2017-02-04 14:51:53.930000] ********** iteration = 83 / 150
# name = model_20_m1_iter_82, n_topics = 20, n_doc_passes = 5, seed_value = 182, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:52:32.015000] current convex_hull shape = (2216, 1660)
# [2017-02-04 14:52:32.016000] ********** iteration = 84 / 150
# name = model_20_m1_iter_83, n_topics = 20, n_doc_passes = 5, seed_value = 183, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:53:18.817000] current convex_hull shape = (2216, 1680)
# [2017-02-04 14:53:18.817000] ********** iteration = 85 / 150
# name = model_20_m1_iter_84, n_topics = 20, n_doc_passes = 5, seed_value = 184, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:53:53.986000] current convex_hull shape = (2216, 1700)
# [2017-02-04 14:53:53.986000] ********** iteration = 86 / 150
# name = model_20_m1_iter_85, n_topics = 20, n_doc_passes = 5, seed_value = 185, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:54:28.698000] current convex_hull shape = (2216, 1720)
# [2017-02-04 14:54:28.698000] ********** iteration = 87 / 150
# name = model_20_m1_iter_86, n_topics = 20, n_doc_passes = 5, seed_value = 186, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:55:01.654000] current convex_hull shape = (2216, 1740)
# [2017-02-04 14:55:01.655000] ********** iteration = 88 / 150
# name = model_20_m1_iter_87, n_topics = 20, n_doc_passes = 5, seed_value = 187, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:55:34.128000] current convex_hull shape = (2216, 1760)
# [2017-02-04 14:55:34.129000] ********** iteration = 89 / 150
# name = model_20_m1_iter_88, n_topics = 20, n_doc_passes = 5, seed_value = 188, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:56:09.444000] current convex_hull shape = (2216, 1780)
# [2017-02-04 14:56:09.445000] ********** iteration = 90 / 150
# name = model_20_m1_iter_89, n_topics = 20, n_doc_passes = 5, seed_value = 189, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:56:42.111000] current convex_hull shape = (2216, 1800)
# [2017-02-04 14:56:42.111000] ********** iteration = 91 / 150
# name = model_20_m1_iter_90, n_topics = 20, n_doc_passes = 5, seed_value = 190, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:57:19.541000] current convex_hull shape = (2216, 1820)
# [2017-02-04 14:57:19.541000] ********** iteration = 92 / 150
# name = model_20_m1_iter_91, n_topics = 20, n_doc_passes = 5, seed_value = 191, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:58:06.858000] current convex_hull shape = (2216, 1840)
# [2017-02-04 14:58:06.859000] ********** iteration = 93 / 150
# name = model_20_m1_iter_92, n_topics = 20, n_doc_passes = 5, seed_value = 192, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:58:40.166000] current convex_hull shape = (2216, 1860)
# [2017-02-04 14:58:40.167000] ********** iteration = 94 / 150
# name = model_20_m1_iter_93, n_topics = 20, n_doc_passes = 5, seed_value = 193, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:59:14.964000] current convex_hull shape = (2216, 1880)
# [2017-02-04 14:59:14.965000] ********** iteration = 95 / 150
# name = model_20_m1_iter_94, n_topics = 20, n_doc_passes = 5, seed_value = 194, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 14:59:49.643000] current convex_hull shape = (2216, 1900)
# [2017-02-04 14:59:49.643000] ********** iteration = 96 / 150
# name = model_20_m1_iter_95, n_topics = 20, n_doc_passes = 5, seed_value = 195, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:00:25.892000] current convex_hull shape = (2216, 1920)
# [2017-02-04 15:00:25.893000] ********** iteration = 97 / 150
# name = model_20_m1_iter_96, n_topics = 20, n_doc_passes = 5, seed_value = 196, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:00:59.820000] current convex_hull shape = (2216, 1940)
# [2017-02-04 15:00:59.821000] ********** iteration = 98 / 150
# name = model_20_m1_iter_97, n_topics = 20, n_doc_passes = 5, seed_value = 197, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:01:32.498000] current convex_hull shape = (2216, 1960)
# [2017-02-04 15:01:32.498000] ********** iteration = 99 / 150
# name = model_20_m1_iter_98, n_topics = 20, n_doc_passes = 5, seed_value = 198, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:02:07.792000] current convex_hull shape = (2216, 1980)
# [2017-02-04 15:02:07.793000] ********** iteration = 100 / 150
# name = model_20_m1_iter_99, n_topics = 20, n_doc_passes = 5, seed_value = 199, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:02:58.269000] current convex_hull shape = (2216, 2000)
# [2017-02-04 15:02:58.270000] ********** iteration = 101 / 150
# name = model_20_m1_iter_100, n_topics = 20, n_doc_passes = 5, seed_value = 200, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:03:30.024000] current convex_hull shape = (2216, 2020)
# [2017-02-04 15:03:30.024000] ********** iteration = 102 / 150
# name = model_20_m1_iter_101, n_topics = 20, n_doc_passes = 5, seed_value = 201, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:04:04.998000] current convex_hull shape = (2216, 2040)
# [2017-02-04 15:04:04.998000] ********** iteration = 103 / 150
# name = model_20_m1_iter_102, n_topics = 20, n_doc_passes = 5, seed_value = 202, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:04:39.159000] current convex_hull shape = (2216, 2060)
# [2017-02-04 15:04:39.159000] ********** iteration = 104 / 150
# name = model_20_m1_iter_103, n_topics = 20, n_doc_passes = 5, seed_value = 203, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:05:12.103000] current convex_hull shape = (2216, 2080)
# [2017-02-04 15:05:12.103000] ********** iteration = 105 / 150
# name = model_20_m1_iter_104, n_topics = 20, n_doc_passes = 5, seed_value = 204, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:05:46.030000] current convex_hull shape = (2216, 2100)
# [2017-02-04 15:05:46.031000] ********** iteration = 106 / 150
# name = model_20_m1_iter_105, n_topics = 20, n_doc_passes = 5, seed_value = 205, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:06:25.073000] current convex_hull shape = (2216, 2120)
# [2017-02-04 15:06:25.074000] ********** iteration = 107 / 150
# name = model_20_m1_iter_106, n_topics = 20, n_doc_passes = 5, seed_value = 206, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:07:14.398000] current convex_hull shape = (2216, 2140)
# [2017-02-04 15:07:14.400000] ********** iteration = 108 / 150
# name = model_20_m1_iter_107, n_topics = 20, n_doc_passes = 5, seed_value = 207, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:07:57.501000] current convex_hull shape = (2216, 2160)
# [2017-02-04 15:07:57.502000] ********** iteration = 109 / 150
# name = model_20_m1_iter_108, n_topics = 20, n_doc_passes = 5, seed_value = 208, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:08:34.936000] current convex_hull shape = (2216, 2180)
# [2017-02-04 15:08:34.936000] ********** iteration = 110 / 150
# name = model_20_m1_iter_109, n_topics = 20, n_doc_passes = 5, seed_value = 209, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:09:09.913000] current convex_hull shape = (2216, 2200)
# [2017-02-04 15:09:09.914000] ********** iteration = 111 / 150
# name = model_20_m1_iter_110, n_topics = 20, n_doc_passes = 5, seed_value = 210, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:09:45.702000] current convex_hull shape = (2216, 2220)
# [2017-02-04 15:09:45.703000] ********** iteration = 112 / 150
# name = model_20_m1_iter_111, n_topics = 20, n_doc_passes = 5, seed_value = 211, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:10:18.929000] current convex_hull shape = (2216, 2240)
# [2017-02-04 15:10:18.929000] ********** iteration = 113 / 150
# name = model_20_m1_iter_112, n_topics = 20, n_doc_passes = 5, seed_value = 212, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:10:50.158000] current convex_hull shape = (2216, 2260)
# [2017-02-04 15:10:50.159000] ********** iteration = 114 / 150
# name = model_20_m1_iter_113, n_topics = 20, n_doc_passes = 5, seed_value = 213, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:11:16.319000] current convex_hull shape = (2216, 2280)
# [2017-02-04 15:11:16.319000] ********** iteration = 115 / 150
# name = model_20_m1_iter_114, n_topics = 20, n_doc_passes = 5, seed_value = 214, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:11:45.123000] current convex_hull shape = (2216, 2300)
# [2017-02-04 15:11:45.124000] ********** iteration = 116 / 150
# name = model_20_m1_iter_115, n_topics = 20, n_doc_passes = 5, seed_value = 215, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:12:12.895000] current convex_hull shape = (2216, 2320)
# [2017-02-04 15:12:12.895000] ********** iteration = 117 / 150
# name = model_20_m1_iter_116, n_topics = 20, n_doc_passes = 5, seed_value = 216, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:12:40.501000] current convex_hull shape = (2216, 2340)
# [2017-02-04 15:12:40.502000] ********** iteration = 118 / 150
# name = model_20_m1_iter_117, n_topics = 20, n_doc_passes = 5, seed_value = 217, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:13:09.323000] current convex_hull shape = (2216, 2360)
# [2017-02-04 15:13:09.323000] ********** iteration = 119 / 150
# name = model_20_m1_iter_118, n_topics = 20, n_doc_passes = 5, seed_value = 218, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:13:38.245000] current convex_hull shape = (2216, 2380)
# [2017-02-04 15:13:38.245000] ********** iteration = 120 / 150
# name = model_20_m1_iter_119, n_topics = 20, n_doc_passes = 5, seed_value = 219, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:14:05.762000] current convex_hull shape = (2216, 2400)
# [2017-02-04 15:14:05.763000] ********** iteration = 121 / 150
# name = model_20_m1_iter_120, n_topics = 20, n_doc_passes = 5, seed_value = 220, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:14:33.926000] current convex_hull shape = (2216, 2420)
# [2017-02-04 15:14:33.926000] ********** iteration = 122 / 150
# name = model_20_m1_iter_121, n_topics = 20, n_doc_passes = 5, seed_value = 221, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:15:01.706000] current convex_hull shape = (2216, 2440)
# [2017-02-04 15:15:01.706000] ********** iteration = 123 / 150
# name = model_20_m1_iter_122, n_topics = 20, n_doc_passes = 5, seed_value = 222, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:15:30.454000] current convex_hull shape = (2216, 2460)
# [2017-02-04 15:15:30.454000] ********** iteration = 124 / 150
# name = model_20_m1_iter_123, n_topics = 20, n_doc_passes = 5, seed_value = 223, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:15:58.105000] current convex_hull shape = (2216, 2480)
# [2017-02-04 15:15:58.105000] ********** iteration = 125 / 150
# name = model_20_m1_iter_124, n_topics = 20, n_doc_passes = 5, seed_value = 224, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:16:24.079000] current convex_hull shape = (2216, 2500)
# [2017-02-04 15:16:24.080000] ********** iteration = 126 / 150
# name = model_20_m1_iter_125, n_topics = 20, n_doc_passes = 5, seed_value = 225, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:16:52.387000] current convex_hull shape = (2216, 2520)
# [2017-02-04 15:16:52.388000] ********** iteration = 127 / 150
# name = model_20_m1_iter_126, n_topics = 20, n_doc_passes = 5, seed_value = 226, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:17:20.373000] current convex_hull shape = (2216, 2540)
# [2017-02-04 15:17:20.373000] ********** iteration = 128 / 150
# name = model_20_m1_iter_127, n_topics = 20, n_doc_passes = 5, seed_value = 227, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:17:48.470000] current convex_hull shape = (2216, 2560)
# [2017-02-04 15:17:48.471000] ********** iteration = 129 / 150
# name = model_20_m1_iter_128, n_topics = 20, n_doc_passes = 5, seed_value = 228, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:18:16.471000] current convex_hull shape = (2216, 2580)
# [2017-02-04 15:18:16.471000] ********** iteration = 130 / 150
# name = model_20_m1_iter_129, n_topics = 20, n_doc_passes = 5, seed_value = 229, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:18:43.958000] current convex_hull shape = (2216, 2600)
# [2017-02-04 15:18:43.958000] ********** iteration = 131 / 150
# name = model_20_m1_iter_130, n_topics = 20, n_doc_passes = 5, seed_value = 230, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:19:11.780000] current convex_hull shape = (2216, 2620)
# [2017-02-04 15:19:11.780000] ********** iteration = 132 / 150
# name = model_20_m1_iter_131, n_topics = 20, n_doc_passes = 5, seed_value = 231, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:19:39.276000] current convex_hull shape = (2216, 2640)
# [2017-02-04 15:19:39.276000] ********** iteration = 133 / 150
# name = model_20_m1_iter_132, n_topics = 20, n_doc_passes = 5, seed_value = 232, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:20:08.554000] current convex_hull shape = (2216, 2660)
# [2017-02-04 15:20:08.554000] ********** iteration = 134 / 150
# name = model_20_m1_iter_133, n_topics = 20, n_doc_passes = 5, seed_value = 233, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:20:34.484000] current convex_hull shape = (2216, 2680)
# [2017-02-04 15:20:34.485000] ********** iteration = 135 / 150
# name = model_20_m1_iter_134, n_topics = 20, n_doc_passes = 5, seed_value = 234, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:21:02.107000] current convex_hull shape = (2216, 2700)
# [2017-02-04 15:21:02.107000] ********** iteration = 136 / 150
# name = model_20_m1_iter_135, n_topics = 20, n_doc_passes = 5, seed_value = 235, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:21:27.991000] current convex_hull shape = (2216, 2720)
# [2017-02-04 15:21:27.992000] ********** iteration = 137 / 150
# name = model_20_m1_iter_136, n_topics = 20, n_doc_passes = 5, seed_value = 236, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:21:55.432000] current convex_hull shape = (2216, 2740)
# [2017-02-04 15:21:55.432000] ********** iteration = 138 / 150
# name = model_20_m1_iter_137, n_topics = 20, n_doc_passes = 5, seed_value = 237, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:22:23.005000] current convex_hull shape = (2216, 2760)
# [2017-02-04 15:22:23.005000] ********** iteration = 139 / 150
# name = model_20_m1_iter_138, n_topics = 20, n_doc_passes = 5, seed_value = 238, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:22:50.396000] current convex_hull shape = (2216, 2780)
# [2017-02-04 15:22:50.396000] ********** iteration = 140 / 150
# name = model_20_m1_iter_139, n_topics = 20, n_doc_passes = 5, seed_value = 239, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:23:16.441000] current convex_hull shape = (2216, 2800)
# [2017-02-04 15:23:16.442000] ********** iteration = 141 / 150
# name = model_20_m1_iter_140, n_topics = 20, n_doc_passes = 5, seed_value = 240, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:23:44.798000] current convex_hull shape = (2216, 2820)
# [2017-02-04 15:23:44.798000] ********** iteration = 142 / 150
# name = model_20_m1_iter_141, n_topics = 20, n_doc_passes = 5, seed_value = 241, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:24:12.225000] current convex_hull shape = (2216, 2840)
# [2017-02-04 15:24:12.226000] ********** iteration = 143 / 150
# name = model_20_m1_iter_142, n_topics = 20, n_doc_passes = 5, seed_value = 242, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:24:39.507000] current convex_hull shape = (2216, 2860)
# [2017-02-04 15:24:39.507000] ********** iteration = 144 / 150
# name = model_20_m1_iter_143, n_topics = 20, n_doc_passes = 5, seed_value = 243, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:25:07.001000] current convex_hull shape = (2216, 2880)
# [2017-02-04 15:25:07.001000] ********** iteration = 145 / 150
# name = model_20_m1_iter_144, n_topics = 20, n_doc_passes = 5, seed_value = 244, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:25:34.662000] current convex_hull shape = (2216, 2900)
# [2017-02-04 15:25:34.662000] ********** iteration = 146 / 150
# name = model_20_m1_iter_145, n_topics = 20, n_doc_passes = 5, seed_value = 245, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:26:02.138000] current convex_hull shape = (2216, 2920)
# [2017-02-04 15:26:02.139000] ********** iteration = 147 / 150
# name = model_20_m1_iter_146, n_topics = 20, n_doc_passes = 5, seed_value = 246, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:26:29.522000] current convex_hull shape = (2216, 2940)
# [2017-02-04 15:26:29.522000] ********** iteration = 148 / 150
# name = model_20_m1_iter_147, n_topics = 20, n_doc_passes = 5, seed_value = 247, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:26:56.901000] current convex_hull shape = (2216, 2960)
# [2017-02-04 15:26:56.902000] ********** iteration = 149 / 150
# name = model_20_m1_iter_148, n_topics = 20, n_doc_passes = 5, seed_value = 248, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:27:23.166000] current convex_hull shape = (2216, 2980)
# [2017-02-04 15:27:23.166000] ********** iteration = 150 / 150
# name = model_20_m1_iter_149, n_topics = 20, n_doc_passes = 5, seed_value = 249, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 15:27:50.574000] current convex_hull shape = (2216, 3000)
# [2017-02-04 19:05:07.243000] filtering iteration = 1 / 150
# [2017-02-04 19:29:08.735000] 408 topics to remove, 2579 not_removed_topics_count because close topics, current convex_hull shape = (2216, 2592)
# [2017-02-04 19:29:09.584000] filtering iteration = 2 / 150
# [2017-02-04 19:45:31.420000] 358 topics to remove, 2219 not_removed_topics_count because close topics, current convex_hull shape = (2216, 2234)
# [2017-02-04 19:45:31.876000] filtering iteration = 3 / 150
# [2017-02-04 20:02:38.780000] 310 topics to remove, 1909 not_removed_topics_count because close topics, current convex_hull shape = (2216, 1924)
# [2017-02-04 20:02:39.224000] filtering iteration = 4 / 150
# [2017-02-04 20:12:18.561000] 266 topics to remove, 1641 not_removed_topics_count because close topics, current convex_hull shape = (2216, 1658)
# [2017-02-04 20:12:18.562000] filtering iteration = 5 / 150
# [2017-02-04 20:19:24.958000] 218 topics to remove, 1415 not_removed_topics_count because close topics, current convex_hull shape = (2216, 1440)
# [2017-02-04 20:19:24.978000] filtering iteration = 6 / 150
# [2017-02-04 20:24:47.098000] 184 topics to remove, 1228 not_removed_topics_count because close topics, current convex_hull shape = (2216, 1256)
# [2017-02-04 20:24:47.099000] filtering iteration = 7 / 150
# [2017-02-04 20:29:06.845000] 157 topics to remove, 1071 not_removed_topics_count because close topics, current convex_hull shape = (2216, 1099)
# [2017-02-04 20:29:06.845000] filtering iteration = 8 / 150
# [2017-02-04 20:32:40.825000] 138 topics to remove, 931 not_removed_topics_count because close topics, current convex_hull shape = (2216, 961)
# [2017-02-04 20:32:40.825000] filtering iteration = 9 / 150
# [2017-02-04 20:35:48.959000] 118 topics to remove, 815 not_removed_topics_count because close topics, current convex_hull shape = (2216, 843)
# [2017-02-04 20:35:48.960000] filtering iteration = 10 / 150
# [2017-02-04 20:38:22.891000] 100 topics to remove, 714 not_removed_topics_count because close topics, current convex_hull shape = (2216, 743)
# [2017-02-04 20:38:22.892000] filtering iteration = 11 / 150
# [2017-02-04 20:40:31.872000] 81 topics to remove, 627 not_removed_topics_count because close topics, current convex_hull shape = (2216, 662)
# [2017-02-04 20:40:31.873000] filtering iteration = 12 / 150
# [2017-02-04 20:42:25.228000] 82 topics to remove, 543 not_removed_topics_count because close topics, current convex_hull shape = (2216, 580)
# [2017-02-04 20:42:25.228000] filtering iteration = 13 / 150
# [2017-02-04 20:44:00.293000] 62 topics to remove, 479 not_removed_topics_count because close topics, current convex_hull shape = (2216, 518)
# [2017-02-04 20:44:00.293000] filtering iteration = 14 / 150
# [2017-02-04 20:45:22.606000] 61 topics to remove, 420 not_removed_topics_count because close topics, current convex_hull shape = (2216, 457)
# [2017-02-04 20:45:22.607000] filtering iteration = 15 / 150
# [2017-02-04 20:46:36.799000] 52 topics to remove, 368 not_removed_topics_count because close topics, current convex_hull shape = (2216, 405)
# [2017-02-04 20:46:36.800000] filtering iteration = 16 / 150
# [2017-02-04 20:47:38.255000] 39 topics to remove, 327 not_removed_topics_count because close topics, current convex_hull shape = (2216, 366)
# [2017-02-04 20:47:38.255000] filtering iteration = 17 / 150
# [2017-02-04 20:48:34.970000] 39 topics to remove, 291 not_removed_topics_count because close topics, current convex_hull shape = (2216, 327)
# [2017-02-04 20:48:34.970000] filtering iteration = 18 / 150
# [2017-02-04 20:49:27.701000] 34 topics to remove, 257 not_removed_topics_count because close topics, current convex_hull shape = (2216, 293)
# [2017-02-04 20:49:27.719000] filtering iteration = 19 / 150
# [2017-02-04 20:50:12.238000] 29 topics to remove, 224 not_removed_topics_count because close topics, current convex_hull shape = (2216, 264)
# [2017-02-04 20:50:12.239000] filtering iteration = 20 / 150
# [2017-02-04 20:50:53.061000] 28 topics to remove, 198 not_removed_topics_count because close topics, current convex_hull shape = (2216, 236)
# [2017-02-04 20:50:53.062000] filtering iteration = 21 / 150
# [2017-02-04 20:51:28.803000] 25 topics to remove, 176 not_removed_topics_count because close topics, current convex_hull shape = (2216, 211)
# [2017-02-04 20:51:28.803000] filtering iteration = 22 / 150
# [2017-02-04 20:52:00.208000] 20 topics to remove, 155 not_removed_topics_count because close topics, current convex_hull shape = (2216, 191)
# [2017-02-04 20:52:00.209000] filtering iteration = 23 / 150
# [2017-02-04 20:52:27.747000] 16 topics to remove, 136 not_removed_topics_count because close topics, current convex_hull shape = (2216, 175)
# [2017-02-04 20:52:27.747000] filtering iteration = 24 / 150
# [2017-02-04 20:52:54.036000] 14 topics to remove, 121 not_removed_topics_count because close topics, current convex_hull shape = (2216, 161)
# [2017-02-04 20:52:54.037000] filtering iteration = 25 / 150
# [2017-02-04 20:53:19.092000] 16 topics to remove, 103 not_removed_topics_count because close topics, current convex_hull shape = (2216, 145)
# [2017-02-04 20:53:19.092000] filtering iteration = 26 / 150
# [2017-02-04 20:53:41.740000] 15 topics to remove, 88 not_removed_topics_count because close topics, current convex_hull shape = (2216, 130)
# [2017-02-04 20:53:41.740000] filtering iteration = 27 / 150
# [2017-02-04 20:54:01.954000] 15 topics to remove, 72 not_removed_topics_count because close topics, current convex_hull shape = (2216, 115)
# [2017-02-04 20:54:01.954000] filtering iteration = 28 / 150
# [2017-02-04 20:54:18.853000] 12 topics to remove, 60 not_removed_topics_count because close topics, current convex_hull shape = (2216, 103)
# [2017-02-04 20:54:18.854000] filtering iteration = 29 / 150
# [2017-02-04 20:54:34.730000] 9 topics to remove, 55 not_removed_topics_count because close topics, current convex_hull shape = (2216, 94)
# [2017-02-04 20:54:34.731000] filtering iteration = 30 / 150
# [2017-02-04 20:54:50.614000] 9 topics to remove, 44 not_removed_topics_count because close topics, current convex_hull shape = (2216, 85)
# [2017-02-04 20:54:50.615000] filtering iteration = 31 / 150
# [2017-02-04 20:55:04.789000] 7 topics to remove, 35 not_removed_topics_count because close topics, current convex_hull shape = (2216, 78)
# [2017-02-04 20:55:04.790000] filtering iteration = 32 / 150
# [2017-02-04 20:55:17.294000] 6 topics to remove, 29 not_removed_topics_count because close topics, current convex_hull shape = (2216, 72)
# [2017-02-04 20:55:17.294000] filtering iteration = 33 / 150
# [2017-02-04 20:55:27.860000] 6 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-04 20:55:27.860000] filtering iteration = 34 / 150
# [2017-02-04 20:55:38.717000] 5 topics to remove, 18 not_removed_topics_count because close topics, current convex_hull shape = (2216, 61)
# [2017-02-04 20:55:38.717000] filtering iteration = 35 / 150
# [2017-02-04 20:55:48.121000] 5 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-04 20:55:48.122000] filtering iteration = 36 / 150
# [2017-02-04 20:55:56.828000] 4 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 20:55:56.829000] filtering iteration = 37 / 150
# [2017-02-04 20:56:04.283000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 20:56:04.284000] filtering iteration = 38 / 150
# [2017-02-04 20:56:12.751000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 20:56:12.752000] filtering iteration = 39 / 150
# [2017-02-04 20:56:21.241000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 20:56:21.270000] topics to remove not increasing, breaking the for loop

# %%
plot_convex_hull_topics_iterations_distribution(phi_convex_hull_1)
# Out:
# [(1, 1, 0.0196078431372549), (2, 1, 0.0196078431372549), (131, 2, 0.0392156862745098), (132, 1, 0.0196078431372549), (7, 1, 0.0196078431372549), (145, 1, 0.0196078431372549), (9, 2, 0.0392156862745098), (139, 1, 0.0196078431372549), (14, 2, 0.0392156862745098), (144, 1, 0.0196078431372549), (17, 1, 0.0196078431372549), (146, 2, 0.0392156862745098), (20, 1, 0.0196078431372549), (25, 1, 0.0196078431372549), (129, 1, 0.0196078431372549), (46, 1, 0.0196078431372549), (48, 1, 0.0196078431372549), (51, 1, 0.0196078431372549), (54, 1, 0.0196078431372549), (56, 1, 0.0196078431372549), (67, 3, 0.058823529411764705), (76, 2, 0.0392156862745098), (77, 1, 0.0196078431372549), (78, 1, 0.0196078431372549), (79, 1, 0.0196078431372549), (86, 1, 0.0196078431372549), (89, 1, 0.0196078431372549), (93, 1, 0.0196078431372549), (94, 1, 0.0196078431372549), (95, 1, 0.0196078431372549), (99, 1, 0.0196078431372549), (101, 1, 0.0196078431372549), (103, 1, 0.0196078431372549), (105, 1, 0.0196078431372549), (108, 2, 0.0392156862745098), (109, 1, 0.0196078431372549), (115, 2, 0.0392156862745098), (116, 1, 0.0196078431372549), (117, 1, 0.0196078431372549), (118, 1, 0.0196078431372549), (125, 1, 0.0196078431372549), (127, 1, 0.0196078431372549)]

# %%
save_pickle_file(iterations_info_1, 'iterations_info_1')

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_3, iterations_info_3 = build_convex_hull_delayed_filtering(create_model_fn_2, get_topics_to_remove_by_opt_fun_and_distance, 
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=150)
plot_convex_hull_topics_iterations_distribution(phi_convex_hull_3)
# save_pickle_file(iterations_info_3, 'iterations_info_3')
# Out:
# [2017-02-06 08:09:01.554000] ********** iteration = 1 / 150
# name = model_100_m2_iter_0, n_topics = 100, n_doc_passes = 5, seed_value = 100, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:09:58.716000] current convex_hull shape = (2216, 100)
# [2017-02-06 08:09:58.716000] ********** iteration = 2 / 150
# name = model_100_m2_iter_1, n_topics = 100, n_doc_passes = 5, seed_value = 101, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:11:01.618000] current convex_hull shape = (2216, 200)
# [2017-02-06 08:11:01.618000] ********** iteration = 3 / 150
# name = model_100_m2_iter_2, n_topics = 100, n_doc_passes = 5, seed_value = 102, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:11:56.648000] current convex_hull shape = (2216, 300)
# [2017-02-06 08:11:56.648000] ********** iteration = 4 / 150
# name = model_100_m2_iter_3, n_topics = 100, n_doc_passes = 5, seed_value = 103, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:12:49.823000] current convex_hull shape = (2216, 400)
# [2017-02-06 08:12:49.823000] ********** iteration = 5 / 150
# name = model_100_m2_iter_4, n_topics = 100, n_doc_passes = 5, seed_value = 104, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:13:42.222000] current convex_hull shape = (2216, 500)
# [2017-02-06 08:13:42.222000] ********** iteration = 6 / 150
# name = model_100_m2_iter_5, n_topics = 100, n_doc_passes = 5, seed_value = 105, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:14:34.530000] current convex_hull shape = (2216, 600)
# [2017-02-06 08:14:34.530000] ********** iteration = 7 / 150
# name = model_100_m2_iter_6, n_topics = 100, n_doc_passes = 5, seed_value = 106, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:15:31.856000] current convex_hull shape = (2216, 700)
# [2017-02-06 08:15:31.856000] ********** iteration = 8 / 150
# name = model_100_m2_iter_7, n_topics = 100, n_doc_passes = 5, seed_value = 107, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:16:26.804000] current convex_hull shape = (2216, 800)
# [2017-02-06 08:16:26.804000] ********** iteration = 9 / 150
# name = model_100_m2_iter_8, n_topics = 100, n_doc_passes = 5, seed_value = 108, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:17:25.622000] current convex_hull shape = (2216, 900)
# [2017-02-06 08:17:25.622000] ********** iteration = 10 / 150
# name = model_100_m2_iter_9, n_topics = 100, n_doc_passes = 5, seed_value = 109, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:18:25.355000] current convex_hull shape = (2216, 1000)
# [2017-02-06 08:18:25.355000] ********** iteration = 11 / 150
# name = model_100_m2_iter_10, n_topics = 100, n_doc_passes = 5, seed_value = 110, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:19:24.798000] current convex_hull shape = (2216, 1100)
# [2017-02-06 08:19:24.798000] ********** iteration = 12 / 150
# name = model_100_m2_iter_11, n_topics = 100, n_doc_passes = 5, seed_value = 111, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:20:27.647000] current convex_hull shape = (2216, 1200)
# [2017-02-06 08:20:27.647000] ********** iteration = 13 / 150
# name = model_100_m2_iter_12, n_topics = 100, n_doc_passes = 5, seed_value = 112, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:21:27.143000] current convex_hull shape = (2216, 1300)
# [2017-02-06 08:21:27.143000] ********** iteration = 14 / 150
# name = model_100_m2_iter_13, n_topics = 100, n_doc_passes = 5, seed_value = 113, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:22:28.242000] current convex_hull shape = (2216, 1400)
# [2017-02-06 08:22:28.242000] ********** iteration = 15 / 150
# name = model_100_m2_iter_14, n_topics = 100, n_doc_passes = 5, seed_value = 114, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:23:28.057000] current convex_hull shape = (2216, 1500)
# [2017-02-06 08:23:28.057000] ********** iteration = 16 / 150
# name = model_100_m2_iter_15, n_topics = 100, n_doc_passes = 5, seed_value = 115, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:24:29.631000] current convex_hull shape = (2216, 1600)
# [2017-02-06 08:24:29.631000] ********** iteration = 17 / 150
# name = model_100_m2_iter_16, n_topics = 100, n_doc_passes = 5, seed_value = 116, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:25:31.004000] current convex_hull shape = (2216, 1700)
# [2017-02-06 08:25:31.004000] ********** iteration = 18 / 150
# name = model_100_m2_iter_17, n_topics = 100, n_doc_passes = 5, seed_value = 117, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:26:30.224000] current convex_hull shape = (2216, 1800)
# [2017-02-06 08:26:30.224000] ********** iteration = 19 / 150
# name = model_100_m2_iter_18, n_topics = 100, n_doc_passes = 5, seed_value = 118, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:27:32.025000] current convex_hull shape = (2216, 1900)
# [2017-02-06 08:27:32.025000] ********** iteration = 20 / 150
# name = model_100_m2_iter_19, n_topics = 100, n_doc_passes = 5, seed_value = 119, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:28:34.389000] current convex_hull shape = (2216, 2000)
# [2017-02-06 08:28:34.389000] ********** iteration = 21 / 150
# name = model_100_m2_iter_20, n_topics = 100, n_doc_passes = 5, seed_value = 120, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:29:37.506000] current convex_hull shape = (2216, 2100)
# [2017-02-06 08:29:37.506000] ********** iteration = 22 / 150
# name = model_100_m2_iter_21, n_topics = 100, n_doc_passes = 5, seed_value = 121, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:30:40.721000] current convex_hull shape = (2216, 2200)
# [2017-02-06 08:30:40.721000] ********** iteration = 23 / 150
# name = model_100_m2_iter_22, n_topics = 100, n_doc_passes = 5, seed_value = 122, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:31:43.531000] current convex_hull shape = (2216, 2300)
# [2017-02-06 08:31:43.531000] ********** iteration = 24 / 150
# name = model_100_m2_iter_23, n_topics = 100, n_doc_passes = 5, seed_value = 123, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:32:46.201000] current convex_hull shape = (2216, 2400)
# [2017-02-06 08:32:46.201000] ********** iteration = 25 / 150
# name = model_100_m2_iter_24, n_topics = 100, n_doc_passes = 5, seed_value = 124, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:33:49.060000] current convex_hull shape = (2216, 2500)
# [2017-02-06 08:33:49.060000] ********** iteration = 26 / 150
# name = model_100_m2_iter_25, n_topics = 100, n_doc_passes = 5, seed_value = 125, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:34:51.387000] current convex_hull shape = (2216, 2600)
# [2017-02-06 08:34:51.387000] ********** iteration = 27 / 150
# name = model_100_m2_iter_26, n_topics = 100, n_doc_passes = 5, seed_value = 126, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:35:52.530000] current convex_hull shape = (2216, 2700)
# [2017-02-06 08:35:52.530000] ********** iteration = 28 / 150
# name = model_100_m2_iter_27, n_topics = 100, n_doc_passes = 5, seed_value = 127, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:36:54.936000] current convex_hull shape = (2216, 2800)
# [2017-02-06 08:36:54.936000] ********** iteration = 29 / 150
# name = model_100_m2_iter_28, n_topics = 100, n_doc_passes = 5, seed_value = 128, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:37:58.257000] current convex_hull shape = (2216, 2900)
# [2017-02-06 08:37:58.257000] ********** iteration = 30 / 150
# name = model_100_m2_iter_29, n_topics = 100, n_doc_passes = 5, seed_value = 129, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:39:01.083000] current convex_hull shape = (2216, 3000)
# [2017-02-06 08:39:01.083000] ********** iteration = 31 / 150
# name = model_100_m2_iter_30, n_topics = 100, n_doc_passes = 5, seed_value = 130, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:40:03.727000] current convex_hull shape = (2216, 3100)
# [2017-02-06 08:40:03.727000] ********** iteration = 32 / 150
# name = model_100_m2_iter_31, n_topics = 100, n_doc_passes = 5, seed_value = 131, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:41:06.359000] current convex_hull shape = (2216, 3200)
# [2017-02-06 08:41:06.359000] ********** iteration = 33 / 150
# name = model_100_m2_iter_32, n_topics = 100, n_doc_passes = 5, seed_value = 132, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:42:09.143000] current convex_hull shape = (2216, 3300)
# [2017-02-06 08:42:09.143000] ********** iteration = 34 / 150
# name = model_100_m2_iter_33, n_topics = 100, n_doc_passes = 5, seed_value = 133, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:43:16.947000] current convex_hull shape = (2216, 3400)
# [2017-02-06 08:43:16.947000] ********** iteration = 35 / 150
# name = model_100_m2_iter_34, n_topics = 100, n_doc_passes = 5, seed_value = 134, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:44:25.457000] current convex_hull shape = (2216, 3500)
# [2017-02-06 08:44:25.457000] ********** iteration = 36 / 150
# name = model_100_m2_iter_35, n_topics = 100, n_doc_passes = 5, seed_value = 135, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:45:30.841000] current convex_hull shape = (2216, 3600)
# [2017-02-06 08:45:30.841000] ********** iteration = 37 / 150
# name = model_100_m2_iter_36, n_topics = 100, n_doc_passes = 5, seed_value = 136, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:46:36.189000] current convex_hull shape = (2216, 3700)
# [2017-02-06 08:46:36.189000] ********** iteration = 38 / 150
# name = model_100_m2_iter_37, n_topics = 100, n_doc_passes = 5, seed_value = 137, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:47:42.914000] current convex_hull shape = (2216, 3800)
# [2017-02-06 08:47:42.914000] ********** iteration = 39 / 150
# name = model_100_m2_iter_38, n_topics = 100, n_doc_passes = 5, seed_value = 138, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:48:48.533000] current convex_hull shape = (2216, 3900)
# [2017-02-06 08:48:48.533000] ********** iteration = 40 / 150
# name = model_100_m2_iter_39, n_topics = 100, n_doc_passes = 5, seed_value = 139, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:49:50.969000] current convex_hull shape = (2216, 4000)
# [2017-02-06 08:49:50.969000] ********** iteration = 41 / 150
# name = model_100_m2_iter_40, n_topics = 100, n_doc_passes = 5, seed_value = 140, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:50:52.990000] current convex_hull shape = (2216, 4100)
# [2017-02-06 08:50:52.990000] ********** iteration = 42 / 150
# name = model_100_m2_iter_41, n_topics = 100, n_doc_passes = 5, seed_value = 141, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:51:53.645000] current convex_hull shape = (2216, 4200)
# [2017-02-06 08:51:53.645000] ********** iteration = 43 / 150
# name = model_100_m2_iter_42, n_topics = 100, n_doc_passes = 5, seed_value = 142, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:52:55.823000] current convex_hull shape = (2216, 4300)
# [2017-02-06 08:52:55.823000] ********** iteration = 44 / 150
# name = model_100_m2_iter_43, n_topics = 100, n_doc_passes = 5, seed_value = 143, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:53:58.531000] current convex_hull shape = (2216, 4400)
# [2017-02-06 08:53:58.531000] ********** iteration = 45 / 150
# name = model_100_m2_iter_44, n_topics = 100, n_doc_passes = 5, seed_value = 144, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:55:00.411000] current convex_hull shape = (2216, 4500)
# [2017-02-06 08:55:00.411000] ********** iteration = 46 / 150
# name = model_100_m2_iter_45, n_topics = 100, n_doc_passes = 5, seed_value = 145, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:56:02.305000] current convex_hull shape = (2216, 4600)
# [2017-02-06 08:56:02.305000] ********** iteration = 47 / 150
# name = model_100_m2_iter_46, n_topics = 100, n_doc_passes = 5, seed_value = 146, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:57:04.224000] current convex_hull shape = (2216, 4700)
# [2017-02-06 08:57:04.224000] ********** iteration = 48 / 150
# name = model_100_m2_iter_47, n_topics = 100, n_doc_passes = 5, seed_value = 147, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:58:05.577000] current convex_hull shape = (2216, 4800)
# [2017-02-06 08:58:05.577000] ********** iteration = 49 / 150
# name = model_100_m2_iter_48, n_topics = 100, n_doc_passes = 5, seed_value = 148, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 08:59:07.975000] current convex_hull shape = (2216, 4900)
# [2017-02-06 08:59:07.991000] ********** iteration = 50 / 150
# name = model_100_m2_iter_49, n_topics = 100, n_doc_passes = 5, seed_value = 149, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:00:13.171000] current convex_hull shape = (2216, 5000)
# [2017-02-06 09:00:13.171000] ********** iteration = 51 / 150
# name = model_100_m2_iter_50, n_topics = 100, n_doc_passes = 5, seed_value = 150, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:01:17.255000] current convex_hull shape = (2216, 5100)
# [2017-02-06 09:01:17.255000] ********** iteration = 52 / 150
# name = model_100_m2_iter_51, n_topics = 100, n_doc_passes = 5, seed_value = 151, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:02:17.840000] current convex_hull shape = (2216, 5200)
# [2017-02-06 09:02:17.840000] ********** iteration = 53 / 150
# name = model_100_m2_iter_52, n_topics = 100, n_doc_passes = 5, seed_value = 152, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:03:21.907000] current convex_hull shape = (2216, 5300)
# [2017-02-06 09:03:21.907000] ********** iteration = 54 / 150
# name = model_100_m2_iter_53, n_topics = 100, n_doc_passes = 5, seed_value = 153, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:04:24.481000] current convex_hull shape = (2216, 5400)
# [2017-02-06 09:04:24.481000] ********** iteration = 55 / 150
# name = model_100_m2_iter_54, n_topics = 100, n_doc_passes = 5, seed_value = 154, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:05:26.873000] current convex_hull shape = (2216, 5500)
# [2017-02-06 09:05:26.873000] ********** iteration = 56 / 150
# name = model_100_m2_iter_55, n_topics = 100, n_doc_passes = 5, seed_value = 155, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:06:28.719000] current convex_hull shape = (2216, 5600)
# [2017-02-06 09:06:28.719000] ********** iteration = 57 / 150
# name = model_100_m2_iter_56, n_topics = 100, n_doc_passes = 5, seed_value = 156, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:07:32.683000] current convex_hull shape = (2216, 5700)
# [2017-02-06 09:07:32.683000] ********** iteration = 58 / 150
# name = model_100_m2_iter_57, n_topics = 100, n_doc_passes = 5, seed_value = 157, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:08:33.321000] current convex_hull shape = (2216, 5800)
# [2017-02-06 09:08:33.321000] ********** iteration = 59 / 150
# name = model_100_m2_iter_58, n_topics = 100, n_doc_passes = 5, seed_value = 158, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:09:35.858000] current convex_hull shape = (2216, 5900)
# [2017-02-06 09:09:35.858000] ********** iteration = 60 / 150
# name = model_100_m2_iter_59, n_topics = 100, n_doc_passes = 5, seed_value = 159, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:10:38.065000] current convex_hull shape = (2216, 6000)
# [2017-02-06 09:10:38.065000] ********** iteration = 61 / 150
# name = model_100_m2_iter_60, n_topics = 100, n_doc_passes = 5, seed_value = 160, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:11:41.847000] current convex_hull shape = (2216, 6100)
# [2017-02-06 09:11:41.847000] ********** iteration = 62 / 150
# name = model_100_m2_iter_61, n_topics = 100, n_doc_passes = 5, seed_value = 161, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:12:42.549000] current convex_hull shape = (2216, 6200)
# [2017-02-06 09:12:42.549000] ********** iteration = 63 / 150
# name = model_100_m2_iter_62, n_topics = 100, n_doc_passes = 5, seed_value = 162, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:13:44.974000] current convex_hull shape = (2216, 6300)
# [2017-02-06 09:13:44.974000] ********** iteration = 64 / 150
# name = model_100_m2_iter_63, n_topics = 100, n_doc_passes = 5, seed_value = 163, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:14:47.465000] current convex_hull shape = (2216, 6400)
# [2017-02-06 09:14:47.465000] ********** iteration = 65 / 150
# name = model_100_m2_iter_64, n_topics = 100, n_doc_passes = 5, seed_value = 164, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:15:51.494000] current convex_hull shape = (2216, 6500)
# [2017-02-06 09:15:51.494000] ********** iteration = 66 / 150
# name = model_100_m2_iter_65, n_topics = 100, n_doc_passes = 5, seed_value = 165, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:16:52.850000] current convex_hull shape = (2216, 6600)
# [2017-02-06 09:16:52.850000] ********** iteration = 67 / 150
# name = model_100_m2_iter_66, n_topics = 100, n_doc_passes = 5, seed_value = 166, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:17:55.251000] current convex_hull shape = (2216, 6700)
# [2017-02-06 09:17:55.267000] ********** iteration = 68 / 150
# name = model_100_m2_iter_67, n_topics = 100, n_doc_passes = 5, seed_value = 167, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:18:57.776000] current convex_hull shape = (2216, 6800)
# [2017-02-06 09:18:57.776000] ********** iteration = 69 / 150
# name = model_100_m2_iter_68, n_topics = 100, n_doc_passes = 5, seed_value = 168, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:19:59.804000] current convex_hull shape = (2216, 6900)
# [2017-02-06 09:19:59.804000] ********** iteration = 70 / 150
# name = model_100_m2_iter_69, n_topics = 100, n_doc_passes = 5, seed_value = 169, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:21:01.787000] current convex_hull shape = (2216, 7000)
# [2017-02-06 09:21:01.787000] ********** iteration = 71 / 150
# name = model_100_m2_iter_70, n_topics = 100, n_doc_passes = 5, seed_value = 170, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:22:04.037000] current convex_hull shape = (2216, 7100)
# [2017-02-06 09:22:04.037000] ********** iteration = 72 / 150
# name = model_100_m2_iter_71, n_topics = 100, n_doc_passes = 5, seed_value = 171, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:23:06.298000] current convex_hull shape = (2216, 7200)
# [2017-02-06 09:23:06.298000] ********** iteration = 73 / 150
# name = model_100_m2_iter_72, n_topics = 100, n_doc_passes = 5, seed_value = 172, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:24:09.046000] current convex_hull shape = (2216, 7300)
# [2017-02-06 09:24:09.046000] ********** iteration = 74 / 150
# name = model_100_m2_iter_73, n_topics = 100, n_doc_passes = 5, seed_value = 173, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:25:11.195000] current convex_hull shape = (2216, 7400)
# [2017-02-06 09:25:11.195000] ********** iteration = 75 / 150
# name = model_100_m2_iter_74, n_topics = 100, n_doc_passes = 5, seed_value = 174, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:26:13.410000] current convex_hull shape = (2216, 7500)
# [2017-02-06 09:26:13.410000] ********** iteration = 76 / 150
# name = model_100_m2_iter_75, n_topics = 100, n_doc_passes = 5, seed_value = 175, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:27:15.806000] current convex_hull shape = (2216, 7600)
# [2017-02-06 09:27:15.806000] ********** iteration = 77 / 150
# name = model_100_m2_iter_76, n_topics = 100, n_doc_passes = 5, seed_value = 176, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:28:18.087000] current convex_hull shape = (2216, 7700)
# [2017-02-06 09:28:18.087000] ********** iteration = 78 / 150
# name = model_100_m2_iter_77, n_topics = 100, n_doc_passes = 5, seed_value = 177, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:29:20.335000] current convex_hull shape = (2216, 7800)
# [2017-02-06 09:29:20.335000] ********** iteration = 79 / 150
# name = model_100_m2_iter_78, n_topics = 100, n_doc_passes = 5, seed_value = 178, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:30:24.458000] current convex_hull shape = (2216, 7900)
# [2017-02-06 09:30:24.458000] ********** iteration = 80 / 150
# name = model_100_m2_iter_79, n_topics = 100, n_doc_passes = 5, seed_value = 179, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:31:26.826000] current convex_hull shape = (2216, 8000)
# [2017-02-06 09:31:26.826000] ********** iteration = 81 / 150
# name = model_100_m2_iter_80, n_topics = 100, n_doc_passes = 5, seed_value = 180, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:32:29.171000] current convex_hull shape = (2216, 8100)
# [2017-02-06 09:32:29.187000] ********** iteration = 82 / 150
# name = model_100_m2_iter_81, n_topics = 100, n_doc_passes = 5, seed_value = 181, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:33:31.578000] current convex_hull shape = (2216, 8200)
# [2017-02-06 09:33:31.594000] ********** iteration = 83 / 150
# name = model_100_m2_iter_82, n_topics = 100, n_doc_passes = 5, seed_value = 182, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:34:33.892000] current convex_hull shape = (2216, 8300)
# [2017-02-06 09:34:33.892000] ********** iteration = 84 / 150
# name = model_100_m2_iter_83, n_topics = 100, n_doc_passes = 5, seed_value = 183, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:35:36.175000] current convex_hull shape = (2216, 8400)
# [2017-02-06 09:35:36.175000] ********** iteration = 85 / 150
# name = model_100_m2_iter_84, n_topics = 100, n_doc_passes = 5, seed_value = 184, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:36:37.951000] current convex_hull shape = (2216, 8500)
# [2017-02-06 09:36:37.951000] ********** iteration = 86 / 150
# name = model_100_m2_iter_85, n_topics = 100, n_doc_passes = 5, seed_value = 185, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:37:40.410000] current convex_hull shape = (2216, 8600)
# [2017-02-06 09:37:40.410000] ********** iteration = 87 / 150
# name = model_100_m2_iter_86, n_topics = 100, n_doc_passes = 5, seed_value = 186, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:38:42.617000] current convex_hull shape = (2216, 8700)
# [2017-02-06 09:38:42.617000] ********** iteration = 88 / 150
# name = model_100_m2_iter_87, n_topics = 100, n_doc_passes = 5, seed_value = 187, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:39:45.221000] current convex_hull shape = (2216, 8800)
# [2017-02-06 09:39:45.221000] ********** iteration = 89 / 150
# name = model_100_m2_iter_88, n_topics = 100, n_doc_passes = 5, seed_value = 188, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:40:45.495000] current convex_hull shape = (2216, 8900)
# [2017-02-06 09:40:45.495000] ********** iteration = 90 / 150
# name = model_100_m2_iter_89, n_topics = 100, n_doc_passes = 5, seed_value = 189, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:41:47.674000] current convex_hull shape = (2216, 9000)
# [2017-02-06 09:41:47.674000] ********** iteration = 91 / 150
# name = model_100_m2_iter_90, n_topics = 100, n_doc_passes = 5, seed_value = 190, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:42:49.635000] current convex_hull shape = (2216, 9100)
# [2017-02-06 09:42:49.635000] ********** iteration = 92 / 150
# name = model_100_m2_iter_91, n_topics = 100, n_doc_passes = 5, seed_value = 191, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:43:52.117000] current convex_hull shape = (2216, 9200)
# [2017-02-06 09:43:52.117000] ********** iteration = 93 / 150
# name = model_100_m2_iter_92, n_topics = 100, n_doc_passes = 5, seed_value = 192, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:44:54.364000] current convex_hull shape = (2216, 9300)
# [2017-02-06 09:44:54.364000] ********** iteration = 94 / 150
# name = model_100_m2_iter_93, n_topics = 100, n_doc_passes = 5, seed_value = 193, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:45:56.481000] current convex_hull shape = (2216, 9400)
# [2017-02-06 09:45:56.481000] ********** iteration = 95 / 150
# name = model_100_m2_iter_94, n_topics = 100, n_doc_passes = 5, seed_value = 194, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:46:58.411000] current convex_hull shape = (2216, 9500)
# [2017-02-06 09:46:58.411000] ********** iteration = 96 / 150
# name = model_100_m2_iter_95, n_topics = 100, n_doc_passes = 5, seed_value = 195, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:48:00.391000] current convex_hull shape = (2216, 9600)
# [2017-02-06 09:48:00.391000] ********** iteration = 97 / 150
# name = model_100_m2_iter_96, n_topics = 100, n_doc_passes = 5, seed_value = 196, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:49:02.716000] current convex_hull shape = (2216, 9700)
# [2017-02-06 09:49:02.716000] ********** iteration = 98 / 150
# name = model_100_m2_iter_97, n_topics = 100, n_doc_passes = 5, seed_value = 197, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:50:04.563000] current convex_hull shape = (2216, 9800)
# [2017-02-06 09:50:04.563000] ********** iteration = 99 / 150
# name = model_100_m2_iter_98, n_topics = 100, n_doc_passes = 5, seed_value = 198, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:51:06.411000] current convex_hull shape = (2216, 9900)
# [2017-02-06 09:51:06.411000] ********** iteration = 100 / 150
# name = model_100_m2_iter_99, n_topics = 100, n_doc_passes = 5, seed_value = 199, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:52:08.442000] current convex_hull shape = (2216, 10000)
# [2017-02-06 09:52:08.442000] ********** iteration = 101 / 150
# name = model_100_m2_iter_100, n_topics = 100, n_doc_passes = 5, seed_value = 200, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:53:10.479000] current convex_hull shape = (2216, 10100)
# [2017-02-06 09:53:10.479000] ********** iteration = 102 / 150
# name = model_100_m2_iter_101, n_topics = 100, n_doc_passes = 5, seed_value = 201, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:54:12.929000] current convex_hull shape = (2216, 10200)
# [2017-02-06 09:54:12.929000] ********** iteration = 103 / 150
# name = model_100_m2_iter_102, n_topics = 100, n_doc_passes = 5, seed_value = 202, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:55:14.674000] current convex_hull shape = (2216, 10300)
# [2017-02-06 09:55:14.674000] ********** iteration = 104 / 150
# name = model_100_m2_iter_103, n_topics = 100, n_doc_passes = 5, seed_value = 203, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:56:16.853000] current convex_hull shape = (2216, 10400)
# [2017-02-06 09:56:16.853000] ********** iteration = 105 / 150
# name = model_100_m2_iter_104, n_topics = 100, n_doc_passes = 5, seed_value = 204, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:57:18.862000] current convex_hull shape = (2216, 10500)
# [2017-02-06 09:57:18.862000] ********** iteration = 106 / 150
# name = model_100_m2_iter_105, n_topics = 100, n_doc_passes = 5, seed_value = 205, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:58:19.482000] current convex_hull shape = (2216, 10600)
# [2017-02-06 09:58:19.482000] ********** iteration = 107 / 150
# name = model_100_m2_iter_106, n_topics = 100, n_doc_passes = 5, seed_value = 206, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 09:59:23.184000] current convex_hull shape = (2216, 10700)
# [2017-02-06 09:59:23.184000] ********** iteration = 108 / 150
# name = model_100_m2_iter_107, n_topics = 100, n_doc_passes = 5, seed_value = 207, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:00:25.669000] current convex_hull shape = (2216, 10800)
# [2017-02-06 10:00:25.669000] ********** iteration = 109 / 150
# name = model_100_m2_iter_108, n_topics = 100, n_doc_passes = 5, seed_value = 208, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:01:27.900000] current convex_hull shape = (2216, 10900)
# [2017-02-06 10:01:27.900000] ********** iteration = 110 / 150
# name = model_100_m2_iter_109, n_topics = 100, n_doc_passes = 5, seed_value = 209, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:02:28.501000] current convex_hull shape = (2216, 11000)
# [2017-02-06 10:02:28.505000] ********** iteration = 111 / 150
# name = model_100_m2_iter_110, n_topics = 100, n_doc_passes = 5, seed_value = 210, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:03:32.258000] current convex_hull shape = (2216, 11100)
# [2017-02-06 10:03:32.258000] ********** iteration = 112 / 150
# name = model_100_m2_iter_111, n_topics = 100, n_doc_passes = 5, seed_value = 211, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:04:34.549000] current convex_hull shape = (2216, 11200)
# [2017-02-06 10:04:34.549000] ********** iteration = 113 / 150
# name = model_100_m2_iter_112, n_topics = 100, n_doc_passes = 5, seed_value = 212, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:05:36.793000] current convex_hull shape = (2216, 11300)
# [2017-02-06 10:05:36.793000] ********** iteration = 114 / 150
# name = model_100_m2_iter_113, n_topics = 100, n_doc_passes = 5, seed_value = 213, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:06:38.141000] current convex_hull shape = (2216, 11400)
# [2017-02-06 10:06:38.141000] ********** iteration = 115 / 150
# name = model_100_m2_iter_114, n_topics = 100, n_doc_passes = 5, seed_value = 214, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:07:40.705000] current convex_hull shape = (2216, 11500)
# [2017-02-06 10:07:40.705000] ********** iteration = 116 / 150
# name = model_100_m2_iter_115, n_topics = 100, n_doc_passes = 5, seed_value = 215, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:08:42.592000] current convex_hull shape = (2216, 11600)
# [2017-02-06 10:08:42.592000] ********** iteration = 117 / 150
# name = model_100_m2_iter_116, n_topics = 100, n_doc_passes = 5, seed_value = 216, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:09:45.408000] current convex_hull shape = (2216, 11700)
# [2017-02-06 10:09:45.408000] ********** iteration = 118 / 150
# name = model_100_m2_iter_117, n_topics = 100, n_doc_passes = 5, seed_value = 217, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:10:47.810000] current convex_hull shape = (2216, 11800)
# [2017-02-06 10:10:47.810000] ********** iteration = 119 / 150
# name = model_100_m2_iter_118, n_topics = 100, n_doc_passes = 5, seed_value = 218, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:11:49.885000] current convex_hull shape = (2216, 11900)
# [2017-02-06 10:11:49.885000] ********** iteration = 120 / 150
# name = model_100_m2_iter_119, n_topics = 100, n_doc_passes = 5, seed_value = 219, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:12:51.986000] current convex_hull shape = (2216, 12000)
# [2017-02-06 10:12:51.986000] ********** iteration = 121 / 150
# name = model_100_m2_iter_120, n_topics = 100, n_doc_passes = 5, seed_value = 220, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:13:54.445000] current convex_hull shape = (2216, 12100)
# [2017-02-06 10:13:54.445000] ********** iteration = 122 / 150
# name = model_100_m2_iter_121, n_topics = 100, n_doc_passes = 5, seed_value = 221, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:14:56.575000] current convex_hull shape = (2216, 12200)
# [2017-02-06 10:14:56.575000] ********** iteration = 123 / 150
# name = model_100_m2_iter_122, n_topics = 100, n_doc_passes = 5, seed_value = 222, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:15:58.803000] current convex_hull shape = (2216, 12300)
# [2017-02-06 10:15:58.803000] ********** iteration = 124 / 150
# name = model_100_m2_iter_123, n_topics = 100, n_doc_passes = 5, seed_value = 223, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:17:00.959000] current convex_hull shape = (2216, 12400)
# [2017-02-06 10:17:00.959000] ********** iteration = 125 / 150
# name = model_100_m2_iter_124, n_topics = 100, n_doc_passes = 5, seed_value = 224, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:18:04.608000] current convex_hull shape = (2216, 12500)
# [2017-02-06 10:18:04.608000] ********** iteration = 126 / 150
# name = model_100_m2_iter_125, n_topics = 100, n_doc_passes = 5, seed_value = 225, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:19:06.888000] current convex_hull shape = (2216, 12600)
# [2017-02-06 10:19:06.888000] ********** iteration = 127 / 150
# name = model_100_m2_iter_126, n_topics = 100, n_doc_passes = 5, seed_value = 226, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:20:08.955000] current convex_hull shape = (2216, 12700)
# [2017-02-06 10:20:08.955000] ********** iteration = 128 / 150
# name = model_100_m2_iter_127, n_topics = 100, n_doc_passes = 5, seed_value = 227, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:21:11.202000] current convex_hull shape = (2216, 12800)
# [2017-02-06 10:21:11.202000] ********** iteration = 129 / 150
# name = model_100_m2_iter_128, n_topics = 100, n_doc_passes = 5, seed_value = 228, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:22:11.769000] current convex_hull shape = (2216, 12900)
# [2017-02-06 10:22:11.769000] ********** iteration = 130 / 150
# name = model_100_m2_iter_129, n_topics = 100, n_doc_passes = 5, seed_value = 229, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:23:13.834000] current convex_hull shape = (2216, 13000)
# [2017-02-06 10:23:13.834000] ********** iteration = 131 / 150
# name = model_100_m2_iter_130, n_topics = 100, n_doc_passes = 5, seed_value = 230, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:24:17.101000] current convex_hull shape = (2216, 13100)
# [2017-02-06 10:24:17.102000] ********** iteration = 132 / 150
# name = model_100_m2_iter_131, n_topics = 100, n_doc_passes = 5, seed_value = 231, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:25:30.283000] current convex_hull shape = (2216, 13200)
# [2017-02-06 10:25:30.284000] ********** iteration = 133 / 150
# name = model_100_m2_iter_132, n_topics = 100, n_doc_passes = 5, seed_value = 232, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:26:55.576000] current convex_hull shape = (2216, 13300)
# [2017-02-06 10:26:55.576000] ********** iteration = 134 / 150
# name = model_100_m2_iter_133, n_topics = 100, n_doc_passes = 5, seed_value = 233, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:28:07.939000] current convex_hull shape = (2216, 13400)
# [2017-02-06 10:28:07.940000] ********** iteration = 135 / 150
# name = model_100_m2_iter_134, n_topics = 100, n_doc_passes = 5, seed_value = 234, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:29:18.892000] current convex_hull shape = (2216, 13500)
# [2017-02-06 10:29:18.892000] ********** iteration = 136 / 150
# name = model_100_m2_iter_135, n_topics = 100, n_doc_passes = 5, seed_value = 235, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:30:26.904000] current convex_hull shape = (2216, 13600)
# [2017-02-06 10:30:26.905000] ********** iteration = 137 / 150
# name = model_100_m2_iter_136, n_topics = 100, n_doc_passes = 5, seed_value = 236, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:31:36.259000] current convex_hull shape = (2216, 13700)
# [2017-02-06 10:31:36.259000] ********** iteration = 138 / 150
# name = model_100_m2_iter_137, n_topics = 100, n_doc_passes = 5, seed_value = 237, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:32:44.159000] current convex_hull shape = (2216, 13800)
# [2017-02-06 10:32:44.159000] ********** iteration = 139 / 150
# name = model_100_m2_iter_138, n_topics = 100, n_doc_passes = 5, seed_value = 238, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:33:54.122000] current convex_hull shape = (2216, 13900)
# [2017-02-06 10:33:54.122000] ********** iteration = 140 / 150
# name = model_100_m2_iter_139, n_topics = 100, n_doc_passes = 5, seed_value = 239, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:35:02.017000] current convex_hull shape = (2216, 14000)
# [2017-02-06 10:35:02.017000] ********** iteration = 141 / 150
# name = model_100_m2_iter_140, n_topics = 100, n_doc_passes = 5, seed_value = 240, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:36:10.116000] current convex_hull shape = (2216, 14100)
# [2017-02-06 10:36:10.116000] ********** iteration = 142 / 150
# name = model_100_m2_iter_141, n_topics = 100, n_doc_passes = 5, seed_value = 241, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:37:18.582000] current convex_hull shape = (2216, 14200)
# [2017-02-06 10:37:18.582000] ********** iteration = 143 / 150
# name = model_100_m2_iter_142, n_topics = 100, n_doc_passes = 5, seed_value = 242, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:38:26.399000] current convex_hull shape = (2216, 14300)
# [2017-02-06 10:38:26.400000] ********** iteration = 144 / 150
# name = model_100_m2_iter_143, n_topics = 100, n_doc_passes = 5, seed_value = 243, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:39:34.342000] current convex_hull shape = (2216, 14400)
# [2017-02-06 10:39:34.343000] ********** iteration = 145 / 150
# name = model_100_m2_iter_144, n_topics = 100, n_doc_passes = 5, seed_value = 244, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:40:41.882000] current convex_hull shape = (2216, 14500)
# [2017-02-06 10:40:41.882000] ********** iteration = 146 / 150
# name = model_100_m2_iter_145, n_topics = 100, n_doc_passes = 5, seed_value = 245, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:41:48.597000] current convex_hull shape = (2216, 14600)
# [2017-02-06 10:41:48.599000] ********** iteration = 147 / 150
# name = model_100_m2_iter_146, n_topics = 100, n_doc_passes = 5, seed_value = 246, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:42:56.618000] current convex_hull shape = (2216, 14700)
# [2017-02-06 10:42:56.618000] ********** iteration = 148 / 150
# name = model_100_m2_iter_147, n_topics = 100, n_doc_passes = 5, seed_value = 247, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:44:06.064000] current convex_hull shape = (2216, 14800)
# [2017-02-06 10:44:06.065000] ********** iteration = 149 / 150
# name = model_100_m2_iter_148, n_topics = 100, n_doc_passes = 5, seed_value = 248, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:45:15.627000] current convex_hull shape = (2216, 14900)
# [2017-02-06 10:45:15.628000] ********** iteration = 150 / 150
# name = model_100_m2_iter_149, n_topics = 100, n_doc_passes = 5, seed_value = 249, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-06 10:46:23.335000] current convex_hull shape = (2216, 15000)

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_4, iterations_info_4 = build_convex_hull_delayed_filtering(create_model_fn_3, get_topics_to_remove_by_opt_fun_and_distance, 
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=150)
plot_convex_hull_topics_iterations_distribution(phi_convex_hull_4)
# save_pickle_file(iterations_info_4, 'iterations_info_4')

# %% [markdown]
# # build_convex_hull_with_filtering

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_2, iterations_info_2 = build_convex_hull_with_filtering(create_model_fn_1, get_topics_to_remove_by_opt_fun_and_distance, 
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=150)
# Out:
# [2017-02-04 21:06:38.782000] ********** iteration = 1 / 150
# name = model_20_m1_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:07:06.886000] filtering iteration = 1 / 15
# [2017-02-04 21:07:10.418000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-02-04 21:07:10.418000] filtering iteration = 2 / 15
# [2017-02-04 21:07:14.288000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-02-04 21:07:14.288000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:07:14.288000] current convex_hull shape = (2216, 20)
# [2017-02-04 21:07:14.289000] ********** iteration = 2 / 150
# name = model_20_m1_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:07:38.740000] filtering iteration = 1 / 15
# [2017-02-04 21:07:44.816000] 5 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 35)
# [2017-02-04 21:07:44.817000] filtering iteration = 2 / 15
# [2017-02-04 21:07:49.385000] 5 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 30)
# [2017-02-04 21:07:49.385000] filtering iteration = 3 / 15
# [2017-02-04 21:07:54.943000] 3 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 27)
# [2017-02-04 21:07:54.943000] filtering iteration = 4 / 15
# [2017-02-04 21:07:59.269000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 27)
# [2017-02-04 21:07:59.269000] filtering iteration = 5 / 15
# [2017-02-04 21:08:05.039000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 27)
# [2017-02-04 21:08:05.039000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:08:05.040000] current convex_hull shape = (2216, 27)
# [2017-02-04 21:08:05.040000] ********** iteration = 3 / 150
# name = model_20_m1_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:08:29.882000] filtering iteration = 1 / 15
# [2017-02-04 21:08:37.665000] 8 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:08:37.665000] filtering iteration = 2 / 15
# [2017-02-04 21:08:43.634000] 5 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 34)
# [2017-02-04 21:08:43.634000] filtering iteration = 3 / 15
# [2017-02-04 21:08:50.506000] 2 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-02-04 21:08:50.506000] filtering iteration = 4 / 15
# [2017-02-04 21:08:55.547000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-02-04 21:08:55.547000] filtering iteration = 5 / 15
# [2017-02-04 21:09:00.461000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-02-04 21:09:00.461000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:09:00.461000] current convex_hull shape = (2216, 32)
# [2017-02-04 21:09:00.461000] ********** iteration = 4 / 150
# name = model_20_m1_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:09:26.170000] filtering iteration = 1 / 15
# [2017-02-04 21:09:33.512000] 7 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-04 21:09:33.512000] filtering iteration = 2 / 15
# [2017-02-04 21:09:42.676000] 7 topics to remove, 13 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-02-04 21:09:42.676000] filtering iteration = 3 / 15
# [2017-02-04 21:09:49.832000] 5 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 33)
# [2017-02-04 21:09:49.833000] filtering iteration = 4 / 15
# [2017-02-04 21:09:55.308000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-02-04 21:09:55.309000] filtering iteration = 5 / 15
# [2017-02-04 21:10:00.897000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-02-04 21:10:00.898000] filtering iteration = 6 / 15
# [2017-02-04 21:10:05.996000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 32)
# [2017-02-04 21:10:05.996000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:10:05.996000] current convex_hull shape = (2216, 32)
# [2017-02-04 21:10:05.996000] ********** iteration = 5 / 150
# name = model_20_m1_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:10:31.190000] filtering iteration = 1 / 15
# [2017-02-04 21:10:39.092000] 7 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-04 21:10:39.093000] filtering iteration = 2 / 15
# [2017-02-04 21:10:45.565000] 6 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:10:45.565000] filtering iteration = 3 / 15
# [2017-02-04 21:10:51.406000] 2 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-02-04 21:10:51.406000] filtering iteration = 4 / 15
# [2017-02-04 21:10:57.720000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-02-04 21:10:57.720000] filtering iteration = 5 / 15
# [2017-02-04 21:11:04.261000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-02-04 21:11:04.261000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:11:04.261000] current convex_hull shape = (2216, 37)
# [2017-02-04 21:11:04.261000] ********** iteration = 6 / 150
# name = model_20_m1_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:11:29.988000] filtering iteration = 1 / 15
# [2017-02-04 21:11:39.619000] 9 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 48)
# [2017-02-04 21:11:39.619000] filtering iteration = 2 / 15
# [2017-02-04 21:11:48.204000] 7 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-02-04 21:11:48.205000] filtering iteration = 3 / 15
# [2017-02-04 21:11:55.741000] 3 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-02-04 21:11:55.741000] filtering iteration = 4 / 15
# [2017-02-04 21:12:01.201000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-02-04 21:12:01.201000] filtering iteration = 5 / 15
# [2017-02-04 21:12:07.519000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-02-04 21:12:07.519000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:12:07.519000] current convex_hull shape = (2216, 38)
# [2017-02-04 21:12:07.520000] ********** iteration = 7 / 150
# name = model_20_m1_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:12:33.143000] filtering iteration = 1 / 15
# [2017-02-04 21:12:42.280000] 11 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 47)
# [2017-02-04 21:12:42.280000] filtering iteration = 2 / 15
# [2017-02-04 21:12:49.182000] 5 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 42)
# [2017-02-04 21:12:49.182000] filtering iteration = 3 / 15
# [2017-02-04 21:12:55.290000] 2 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 40)
# [2017-02-04 21:12:55.290000] filtering iteration = 4 / 15
# [2017-02-04 21:13:00.633000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:13:00.633000] filtering iteration = 5 / 15
# [2017-02-04 21:13:06.760000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:13:06.761000] filtering iteration = 6 / 15
# [2017-02-04 21:13:12.358000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:13:12.359000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:13:12.359000] current convex_hull shape = (2216, 39)
# [2017-02-04 21:13:12.359000] ********** iteration = 8 / 150
# name = model_20_m1_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:13:38.330000] filtering iteration = 1 / 15
# [2017-02-04 21:13:47.967000] 12 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 47)
# [2017-02-04 21:13:47.968000] filtering iteration = 2 / 15
# [2017-02-04 21:13:54.902000] 8 topics to remove, 8 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:13:54.903000] filtering iteration = 3 / 15
# [2017-02-04 21:14:00.133000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-02-04 21:14:00.133000] filtering iteration = 4 / 15
# [2017-02-04 21:14:05.802000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-02-04 21:14:05.803000] filtering iteration = 5 / 15
# [2017-02-04 21:14:10.508000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-02-04 21:14:10.508000] filtering iteration = 6 / 15
# [2017-02-04 21:14:15.514000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 37)
# [2017-02-04 21:14:15.514000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:14:15.515000] current convex_hull shape = (2216, 37)
# [2017-02-04 21:14:15.515000] ********** iteration = 9 / 150
# name = model_20_m1_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:14:40.970000] filtering iteration = 1 / 15
# [2017-02-04 21:14:49.379000] 8 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 49)
# [2017-02-04 21:14:49.379000] filtering iteration = 2 / 15
# [2017-02-04 21:14:56.096000] 4 topics to remove, 14 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-04 21:14:56.096000] filtering iteration = 3 / 15
# [2017-02-04 21:15:03.140000] 5 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 40)
# [2017-02-04 21:15:03.140000] filtering iteration = 4 / 15
# [2017-02-04 21:15:10.233000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:15:10.233000] filtering iteration = 5 / 15
# [2017-02-04 21:15:15.848000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:15:15.848000] filtering iteration = 6 / 15
# [2017-02-04 21:15:21.789000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 39)
# [2017-02-04 21:15:21.790000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:15:21.790000] current convex_hull shape = (2216, 39)
# [2017-02-04 21:15:21.790000] ********** iteration = 10 / 150
# name = model_20_m1_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:15:47.647000] filtering iteration = 1 / 15
# [2017-02-04 21:15:55.921000] 10 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 49)
# [2017-02-04 21:15:55.921000] filtering iteration = 2 / 15
# [2017-02-04 21:16:02.655000] 6 topics to remove, 4 not_removed_topics_count because close topics, current convex_hull shape = (2216, 43)
# [2017-02-04 21:16:02.656000] filtering iteration = 3 / 15
# [2017-02-04 21:16:09.505000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 42)
# [2017-02-04 21:16:09.505000] filtering iteration = 4 / 15
# [2017-02-04 21:16:16.114000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-02-04 21:16:16.114000] filtering iteration = 5 / 15
# [2017-02-04 21:16:22.413000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-02-04 21:16:22.413000] filtering iteration = 6 / 15
# [2017-02-04 21:16:28.835000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 41)
# [2017-02-04 21:16:28.836000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:16:28.836000] current convex_hull shape = (2216, 41)
# [2017-02-04 21:16:28.836000] ********** iteration = 11 / 150
# name = model_20_m1_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:16:54.544000] filtering iteration = 1 / 15
# [2017-02-04 21:17:04.426000] 9 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:17:04.426000] filtering iteration = 2 / 15
# [2017-02-04 21:17:12.785000] 4 topics to remove, 8 not_removed_topics_count because close topics, current convex_hull shape = (2216, 48)
# [2017-02-04 21:17:12.786000] filtering iteration = 3 / 15
# [2017-02-04 21:17:20.114000] 3 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 45)
# [2017-02-04 21:17:20.114000] filtering iteration = 4 / 15
# [2017-02-04 21:17:27.999000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 44)
# [2017-02-04 21:17:27.999000] filtering iteration = 5 / 15
# [2017-02-04 21:17:35.414000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 44)
# [2017-02-04 21:17:35.414000] filtering iteration = 6 / 15
# [2017-02-04 21:17:42.083000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 44)
# [2017-02-04 21:17:42.083000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:17:42.083000] current convex_hull shape = (2216, 44)
# [2017-02-04 21:17:42.083000] ********** iteration = 12 / 150
# name = model_20_m1_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:18:08.537000] filtering iteration = 1 / 15
# [2017-02-04 21:18:17.820000] 8 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-04 21:18:17.821000] filtering iteration = 2 / 15
# [2017-02-04 21:18:26.368000] 6 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:18:26.368000] filtering iteration = 3 / 15
# [2017-02-04 21:18:33.751000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 47)
# [2017-02-04 21:18:33.751000] filtering iteration = 4 / 15
# [2017-02-04 21:18:41.572000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 46)
# [2017-02-04 21:18:41.573000] filtering iteration = 5 / 15
# [2017-02-04 21:18:49.339000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 46)
# [2017-02-04 21:18:49.339000] filtering iteration = 6 / 15
# [2017-02-04 21:18:56.554000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 46)
# [2017-02-04 21:18:56.554000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:18:56.555000] current convex_hull shape = (2216, 46)
# [2017-02-04 21:18:56.555000] ********** iteration = 13 / 150
# name = model_20_m1_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:19:23.185000] filtering iteration = 1 / 15
# [2017-02-04 21:19:33.525000] 11 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-04 21:19:33.526000] filtering iteration = 2 / 15
# [2017-02-04 21:19:42.935000] 4 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:19:42.935000] filtering iteration = 3 / 15
# [2017-02-04 21:19:50.318000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:19:50.319000] filtering iteration = 4 / 15
# [2017-02-04 21:19:58.537000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:19:58.537000] filtering iteration = 5 / 15
# [2017-02-04 21:20:06.749000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:20:06.749000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:20:06.750000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:20:06.750000] ********** iteration = 14 / 150
# name = model_20_m1_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:20:33.797000] filtering iteration = 1 / 15
# [2017-02-04 21:20:44.123000] 9 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 61)
# [2017-02-04 21:20:44.123000] filtering iteration = 2 / 15
# [2017-02-04 21:20:54.022000] 8 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:20:54.022000] filtering iteration = 3 / 15
# [2017-02-04 21:21:02.994000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:21:02.994000] filtering iteration = 4 / 15
# [2017-02-04 21:21:10.216000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:21:10.217000] filtering iteration = 5 / 15
# [2017-02-04 21:21:18.769000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:21:18.769000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:21:18.769000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:21:18.769000] ********** iteration = 15 / 150
# name = model_20_m1_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:21:45.452000] filtering iteration = 1 / 15
# [2017-02-04 21:21:55.586000] 12 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-04 21:21:55.587000] filtering iteration = 2 / 15
# [2017-02-04 21:22:04.727000] 5 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:22:04.728000] filtering iteration = 3 / 15
# [2017-02-04 21:22:13.392000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:22:13.392000] filtering iteration = 4 / 15
# [2017-02-04 21:22:21.257000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:22:21.257000] filtering iteration = 5 / 15
# [2017-02-04 21:22:29.492000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:22:29.492000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:22:29.492000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:22:29.492000] ********** iteration = 16 / 150
# name = model_20_m1_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:22:56.495000] filtering iteration = 1 / 15
# [2017-02-04 21:23:08.115000] 9 topics to remove, 30 not_removed_topics_count because close topics, current convex_hull shape = (2216, 61)
# [2017-02-04 21:23:08.115000] filtering iteration = 2 / 15
# [2017-02-04 21:23:17.357000] 8 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:23:17.358000] filtering iteration = 3 / 15
# [2017-02-04 21:23:24.716000] 3 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:23:24.717000] filtering iteration = 4 / 15
# [2017-02-04 21:23:31.950000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:23:31.951000] filtering iteration = 5 / 15
# [2017-02-04 21:23:40.802000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:23:40.802000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:23:40.802000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:23:40.802000] ********** iteration = 17 / 150
# name = model_20_m1_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:24:07.797000] filtering iteration = 1 / 15
# [2017-02-04 21:24:18.374000] 13 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-04 21:24:18.374000] filtering iteration = 2 / 15
# [2017-02-04 21:24:26.886000] 5 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:24:26.886000] filtering iteration = 3 / 15
# [2017-02-04 21:24:35.123000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:24:35.123000] filtering iteration = 4 / 15
# [2017-02-04 21:24:42.962000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:24:42.963000] filtering iteration = 5 / 15
# [2017-02-04 21:24:51.597000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:24:51.597000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:24:51.597000] current convex_hull shape = (2216, 51)
# [2017-02-04 21:24:51.597000] ********** iteration = 18 / 150
# name = model_20_m1_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:25:18.717000] filtering iteration = 1 / 15
# [2017-02-04 21:25:29.781000] 12 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 59)
# [2017-02-04 21:25:29.781000] filtering iteration = 2 / 15
# [2017-02-04 21:25:38.268000] 6 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:25:38.268000] filtering iteration = 3 / 15
# [2017-02-04 21:25:46.155000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:25:46.155000] filtering iteration = 4 / 15
# [2017-02-04 21:25:53.955000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:25:53.955000] filtering iteration = 5 / 15
# [2017-02-04 21:26:02.379000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:26:02.380000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:26:02.380000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:26:02.380000] ********** iteration = 19 / 150
# name = model_20_m1_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:26:29.059000] filtering iteration = 1 / 15
# [2017-02-04 21:26:38.846000] 9 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 61)
# [2017-02-04 21:26:38.847000] filtering iteration = 2 / 15
# [2017-02-04 21:26:48.002000] 7 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:26:48.002000] filtering iteration = 3 / 15
# [2017-02-04 21:26:56.787000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:26:56.788000] filtering iteration = 4 / 15
# [2017-02-04 21:27:04.028000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:27:04.028000] filtering iteration = 5 / 15
# [2017-02-04 21:27:12.735000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:27:12.735000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:27:12.736000] current convex_hull shape = (2216, 52)
# [2017-02-04 21:27:12.736000] ********** iteration = 20 / 150
# name = model_20_m1_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:27:39.635000] filtering iteration = 1 / 15
# [2017-02-04 21:27:50.631000] 13 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 59)
# [2017-02-04 21:27:50.632000] filtering iteration = 2 / 15
# [2017-02-04 21:27:58.989000] 6 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:27:58.989000] filtering iteration = 3 / 15
# [2017-02-04 21:28:06.461000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:28:06.461000] filtering iteration = 4 / 15
# [2017-02-04 21:28:14.075000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:28:14.075000] filtering iteration = 5 / 15
# [2017-02-04 21:28:22.146000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:28:22.146000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:28:22.146000] current convex_hull shape = (2216, 52)
# [2017-02-04 21:28:22.147000] ********** iteration = 21 / 150
# name = model_20_m1_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:28:49.320000] filtering iteration = 1 / 15
# [2017-02-04 21:29:02.055000] 14 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-04 21:29:02.055000] filtering iteration = 2 / 15
# [2017-02-04 21:29:10.707000] 5 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:29:10.708000] filtering iteration = 3 / 15
# [2017-02-04 21:29:18.855000] 3 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:29:18.855000] filtering iteration = 4 / 15
# [2017-02-04 21:29:26.418000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:29:26.419000] filtering iteration = 5 / 15
# [2017-02-04 21:29:34.127000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:29:34.127000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:29:34.127000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:29:34.127000] ********** iteration = 22 / 150
# name = model_20_m1_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:30:00.840000] filtering iteration = 1 / 15
# [2017-02-04 21:30:09.589000] 14 topics to remove, 20 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-04 21:30:09.589000] filtering iteration = 2 / 15
# [2017-02-04 21:30:18.090000] 5 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:30:18.090000] filtering iteration = 3 / 15
# [2017-02-04 21:30:26.411000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:30:26.411000] filtering iteration = 4 / 15
# [2017-02-04 21:30:34.433000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:30:34.433000] filtering iteration = 5 / 15
# [2017-02-04 21:30:41.771000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:30:41.772000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:30:41.772000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:30:41.772000] ********** iteration = 23 / 150
# name = model_20_m1_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:31:08.371000] filtering iteration = 1 / 15
# [2017-02-04 21:31:18.260000] 12 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-04 21:31:18.261000] filtering iteration = 2 / 15
# [2017-02-04 21:31:28.355000] 6 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:31:28.355000] filtering iteration = 3 / 15
# [2017-02-04 21:31:35.593000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:31:35.593000] filtering iteration = 4 / 15
# [2017-02-04 21:31:43.027000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:31:43.028000] filtering iteration = 5 / 15
# [2017-02-04 21:31:50.953000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:31:50.953000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:31:50.953000] current convex_hull shape = (2216, 51)
# [2017-02-04 21:31:50.954000] ********** iteration = 24 / 150
# name = model_20_m1_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:32:18.318000] filtering iteration = 1 / 15
# [2017-02-04 21:32:28.659000] 11 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-04 21:32:28.660000] filtering iteration = 2 / 15
# [2017-02-04 21:32:37.663000] 7 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:32:37.663000] filtering iteration = 3 / 15
# [2017-02-04 21:32:45.277000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:32:45.277000] filtering iteration = 4 / 15
# [2017-02-04 21:32:53.583000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:32:53.583000] filtering iteration = 5 / 15
# [2017-02-04 21:33:01.099000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:33:01.100000] filtering iteration = 6 / 15
# [2017-02-04 21:33:08.060000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:33:08.061000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:33:08.061000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:33:08.061000] ********** iteration = 25 / 150
# name = model_20_m1_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:33:34.695000] filtering iteration = 1 / 15
# [2017-02-04 21:33:45.219000] 12 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-04 21:33:45.220000] filtering iteration = 2 / 15
# [2017-02-04 21:33:53.884000] 5 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:33:53.885000] filtering iteration = 3 / 15
# [2017-02-04 21:34:01.119000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:34:01.119000] filtering iteration = 4 / 15
# [2017-02-04 21:34:08.749000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:34:08.749000] filtering iteration = 5 / 15
# [2017-02-04 21:34:16.161000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:34:16.161000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:34:16.162000] current convex_hull shape = (2216, 51)
# [2017-02-04 21:34:16.162000] ********** iteration = 26 / 150
# name = model_20_m1_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:34:43.294000] filtering iteration = 1 / 15
# [2017-02-04 21:34:53.421000] 11 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-04 21:34:53.421000] filtering iteration = 2 / 15
# [2017-02-04 21:35:03.055000] 6 topics to remove, 8 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:35:03.056000] filtering iteration = 3 / 15
# [2017-02-04 21:35:11.115000] 3 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:35:11.116000] filtering iteration = 4 / 15
# [2017-02-04 21:35:19.001000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:35:19.001000] filtering iteration = 5 / 15
# [2017-02-04 21:35:26.609000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:35:26.610000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:35:26.610000] current convex_hull shape = (2216, 51)
# [2017-02-04 21:35:26.610000] ********** iteration = 27 / 150
# name = model_20_m1_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:35:53.330000] filtering iteration = 1 / 15
# [2017-02-04 21:36:03.198000] 14 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-04 21:36:03.198000] filtering iteration = 2 / 15
# [2017-02-04 21:36:11.852000] 5 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:36:11.853000] filtering iteration = 3 / 15
# [2017-02-04 21:36:19.283000] 2 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:36:19.283000] filtering iteration = 4 / 15
# [2017-02-04 21:36:26.271000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:36:26.271000] filtering iteration = 5 / 15
# [2017-02-04 21:36:32.698000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 50)
# [2017-02-04 21:36:32.699000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:36:32.699000] current convex_hull shape = (2216, 50)
# [2017-02-04 21:36:32.699000] ********** iteration = 28 / 150
# name = model_20_m1_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:36:59.320000] filtering iteration = 1 / 15
# [2017-02-04 21:37:10.141000] 12 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-04 21:37:10.141000] filtering iteration = 2 / 15
# [2017-02-04 21:37:18.332000] 4 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:37:18.333000] filtering iteration = 3 / 15
# [2017-02-04 21:37:25.901000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:37:25.901000] filtering iteration = 4 / 15
# [2017-02-04 21:37:34.033000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:37:34.033000] filtering iteration = 5 / 15
# [2017-02-04 21:37:41.259000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:37:41.260000] filtering iteration = 6 / 15
# [2017-02-04 21:37:48.349000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:37:48.350000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:37:48.350000] current convex_hull shape = (2216, 51)
# [2017-02-04 21:37:48.350000] ********** iteration = 29 / 150
# name = model_20_m1_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:38:15.049000] filtering iteration = 1 / 15
# [2017-02-04 21:38:27.794000] 13 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-04 21:38:27.794000] filtering iteration = 2 / 15
# [2017-02-04 21:38:36.796000] 4 topics to remove, 6 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:38:36.796000] filtering iteration = 3 / 15
# [2017-02-04 21:38:44.599000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:38:44.599000] filtering iteration = 4 / 15
# [2017-02-04 21:38:52.017000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:38:52.017000] filtering iteration = 5 / 15
# [2017-02-04 21:39:00.193000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:39:00.194000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:39:00.194000] current convex_hull shape = (2216, 52)
# [2017-02-04 21:39:00.194000] ********** iteration = 30 / 150
# name = model_20_m1_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:39:27.734000] filtering iteration = 1 / 15
# [2017-02-04 21:39:39.132000] 12 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-04 21:39:39.132000] filtering iteration = 2 / 15
# [2017-02-04 21:39:47.394000] 5 topics to remove, 5 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-04 21:39:47.394000] filtering iteration = 3 / 15
# [2017-02-04 21:39:55.281000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:39:55.281000] filtering iteration = 4 / 15
# [2017-02-04 21:40:03.831000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:40:03.831000] filtering iteration = 5 / 15
# [2017-02-04 21:40:11.131000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:40:11.132000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:40:11.132000] current convex_hull shape = (2216, 54)
# [2017-02-04 21:40:11.132000] ********** iteration = 31 / 150
# name = model_20_m1_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:40:38.342000] filtering iteration = 1 / 15
# [2017-02-04 21:40:50.956000] 12 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 62)
# [2017-02-04 21:40:50.956000] filtering iteration = 2 / 15
# [2017-02-04 21:41:00.864000] 8 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:41:00.864000] filtering iteration = 3 / 15
# [2017-02-04 21:41:09.498000] 2 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 52)
# [2017-02-04 21:41:09.498000] filtering iteration = 4 / 15
# [2017-02-04 21:41:17.519000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:41:17.519000] filtering iteration = 5 / 15
# [2017-02-04 21:41:25.610000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:41:25.611000] filtering iteration = 6 / 15
# [2017-02-04 21:41:33.383000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 51)
# [2017-02-04 21:41:33.383000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:41:33.384000] current convex_hull shape = (2216, 51)
# [2017-02-04 21:41:33.384000] ********** iteration = 32 / 150
# name = model_20_m1_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:42:00.092000] filtering iteration = 1 / 15
# [2017-02-04 21:42:12.810000] 11 topics to remove, 16 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-04 21:42:12.811000] filtering iteration = 2 / 15
# [2017-02-04 21:42:21.156000] 4 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-04 21:42:21.156000] filtering iteration = 3 / 15
# [2017-02-04 21:42:30.547000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-04 21:42:30.547000] filtering iteration = 4 / 15
# [2017-02-04 21:42:38.778000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-04 21:42:38.778000] filtering iteration = 5 / 15
# [2017-02-04 21:42:46.160000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-04 21:42:46.160000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:42:46.160000] current convex_hull shape = (2216, 55)
# [2017-02-04 21:42:46.160000] ********** iteration = 33 / 150
# name = model_20_m1_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:43:13.778000] filtering iteration = 1 / 15
# [2017-02-04 21:43:24.577000] 9 topics to remove, 34 not_removed_topics_count because close topics, current convex_hull shape = (2216, 66)
# [2017-02-04 21:43:24.578000] filtering iteration = 2 / 15
# [2017-02-04 21:43:33.591000] 8 topics to remove, 14 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-04 21:43:33.591000] filtering iteration = 3 / 15
# [2017-02-04 21:43:43.221000] 5 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:43:43.221000] filtering iteration = 4 / 15
# [2017-02-04 21:43:51.331000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:43:51.331000] filtering iteration = 5 / 15
# [2017-02-04 21:43:59.823000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:43:59.823000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:43:59.824000] current convex_hull shape = (2216, 53)
# [2017-02-04 21:43:59.824000] ********** iteration = 34 / 150
# name = model_20_m1_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:44:26.862000] filtering iteration = 1 / 15
# [2017-02-04 21:44:38.081000] 10 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 63)
# [2017-02-04 21:44:38.081000] filtering iteration = 2 / 15
# [2017-02-04 21:44:47.334000] 6 topics to remove, 11 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-04 21:44:47.334000] filtering iteration = 3 / 15
# [2017-02-04 21:44:55.346000] 3 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 54)
# [2017-02-04 21:44:55.346000] filtering iteration = 4 / 15
# [2017-02-04 21:45:03.982000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:45:03.983000] filtering iteration = 5 / 15
# [2017-02-04 21:45:11.906000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:45:11.906000] filtering iteration = 6 / 15
# [2017-02-04 21:45:20.120000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:45:20.121000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:45:20.121000] current convex_hull shape = (2216, 53)
# [2017-02-04 21:45:20.121000] ********** iteration = 35 / 150
# name = model_20_m1_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-04 21:45:47.137000] filtering iteration = 1 / 15
# [2017-02-04 21:45:58.798000] 13 topics to remove, 22 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-04 21:45:58.798000] filtering iteration = 2 / 15
# [2017-02-04 21:46:06.696000] 5 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-04 21:46:06.697000] filtering iteration = 3 / 15
# [2017-02-04 21:46:14.282000] 2 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:46:14.282000] filtering iteration = 4 / 15
# [2017-02-04 21:46:21.613000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:46:21.613000] filtering iteration = 5 / 15
# [2017-02-04 21:46:29.477000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 53)
# [2017-02-04 21:46:29.478000] topics to remove not increasing, breaking the for loop
# [2017-02-04 21:46:29.478000] current convex_hull shape = (2216, 53)
# ...
# [2017-02-05 00:00:48.127000] filtering iteration = 5 / 15
# [2017-02-05 00:00:56.031000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-02-05 00:00:56.031000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:00:56.031000] current convex_hull shape = (2216, 55)
# [2017-02-05 00:00:56.031000] ********** iteration = 139 / 150
# name = model_20_m1_iter_138, n_topics = 20, n_doc_passes = 5, seed_value = 238, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:01:23.413000] filtering iteration = 1 / 15
# [2017-02-05 00:01:35.537000] 14 topics to remove, 18 not_removed_topics_count because close topics, current convex_hull shape = (2216, 61)
# [2017-02-05 00:01:35.537000] filtering iteration = 2 / 15
# [2017-02-05 00:01:45.003000] 4 topics to remove, 3 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:01:45.003000] filtering iteration = 3 / 15
# [2017-02-05 00:01:53.778000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:01:53.779000] filtering iteration = 4 / 15
# [2017-02-05 00:02:02.459000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:02:02.459000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:02:02.459000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:02:02.459000] ********** iteration = 140 / 150
# name = model_20_m1_iter_139, n_topics = 20, n_doc_passes = 5, seed_value = 239, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:02:30.113000] filtering iteration = 1 / 15
# [2017-02-05 00:02:42.825000] 12 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-05 00:02:42.825000] filtering iteration = 2 / 15
# [2017-02-05 00:02:54.194000] 5 topics to remove, 12 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-05 00:02:54.195000] filtering iteration = 3 / 15
# [2017-02-05 00:03:04.182000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:03:04.183000] filtering iteration = 4 / 15
# [2017-02-05 00:03:12.712000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:03:12.712000] filtering iteration = 5 / 15
# [2017-02-05 00:03:22.160000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:03:22.160000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:03:22.161000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:03:22.161000] ********** iteration = 141 / 150
# name = model_20_m1_iter_140, n_topics = 20, n_doc_passes = 5, seed_value = 240, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:03:49.884000] filtering iteration = 1 / 15
# [2017-02-05 00:04:01.898000] 13 topics to remove, 25 not_removed_topics_count because close topics, current convex_hull shape = (2216, 64)
# [2017-02-05 00:04:01.899000] filtering iteration = 2 / 15
# [2017-02-05 00:04:12.848000] 5 topics to remove, 5 not_removed_topics_count because close topics, current convex_hull shape = (2216, 59)
# [2017-02-05 00:04:12.848000] filtering iteration = 3 / 15
# [2017-02-05 00:04:21.773000] 2 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:04:21.773000] filtering iteration = 4 / 15
# [2017-02-05 00:04:30.576000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:04:30.576000] filtering iteration = 5 / 15
# [2017-02-05 00:04:40.057000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:04:40.057000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:04:40.058000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:04:40.058000] ********** iteration = 142 / 150
# name = model_20_m1_iter_141, n_topics = 20, n_doc_passes = 5, seed_value = 241, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:05:07.714000] filtering iteration = 1 / 15
# [2017-02-05 00:05:20.095000] 12 topics to remove, 29 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-05 00:05:20.095000] filtering iteration = 2 / 15
# [2017-02-05 00:05:31.321000] 7 topics to remove, 9 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:05:31.322000] filtering iteration = 3 / 15
# [2017-02-05 00:05:40.239000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:05:40.239000] filtering iteration = 4 / 15
# [2017-02-05 00:05:49.570000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:05:49.570000] filtering iteration = 5 / 15
# [2017-02-05 00:05:59.356000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:05:59.357000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:05:59.357000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:05:59.357000] ********** iteration = 143 / 150
# name = model_20_m1_iter_142, n_topics = 20, n_doc_passes = 5, seed_value = 242, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:06:26.986000] filtering iteration = 1 / 15
# [2017-02-05 00:06:38.928000] 16 topics to remove, 24 not_removed_topics_count because close topics, current convex_hull shape = (2216, 61)
# [2017-02-05 00:06:38.929000] filtering iteration = 2 / 15
# [2017-02-05 00:06:48.088000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:06:48.088000] filtering iteration = 3 / 15
# [2017-02-05 00:06:58.321000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:06:58.321000] filtering iteration = 4 / 15
# [2017-02-05 00:07:06.609000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:07:06.609000] filtering iteration = 5 / 15
# [2017-02-05 00:07:15.442000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:07:15.442000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:07:15.442000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:07:15.443000] ********** iteration = 144 / 150
# name = model_20_m1_iter_143, n_topics = 20, n_doc_passes = 5, seed_value = 243, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:07:43.318000] filtering iteration = 1 / 15
# [2017-02-05 00:07:54.915000] 13 topics to remove, 28 not_removed_topics_count because close topics, current convex_hull shape = (2216, 64)
# [2017-02-05 00:07:54.915000] filtering iteration = 2 / 15
# [2017-02-05 00:08:05.001000] 6 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:08:05.001000] filtering iteration = 3 / 15
# [2017-02-05 00:08:14.479000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-05 00:08:14.479000] filtering iteration = 4 / 15
# [2017-02-05 00:08:23.736000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-05 00:08:23.736000] filtering iteration = 5 / 15
# [2017-02-05 00:08:32.814000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-05 00:08:32.814000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:08:32.814000] current convex_hull shape = (2216, 56)
# [2017-02-05 00:08:32.815000] ********** iteration = 145 / 150
# name = model_20_m1_iter_144, n_topics = 20, n_doc_passes = 5, seed_value = 244, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:09:01.042000] filtering iteration = 1 / 15
# [2017-02-05 00:09:12.317000] 15 topics to remove, 21 not_removed_topics_count because close topics, current convex_hull shape = (2216, 61)
# [2017-02-05 00:09:12.318000] filtering iteration = 2 / 15
# [2017-02-05 00:09:22.270000] 4 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:09:22.270000] filtering iteration = 3 / 15
# [2017-02-05 00:09:31.479000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-05 00:09:31.480000] filtering iteration = 4 / 15
# [2017-02-05 00:09:40.065000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-05 00:09:40.065000] filtering iteration = 5 / 15
# [2017-02-05 00:09:50.111000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 56)
# [2017-02-05 00:09:50.111000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:09:50.111000] current convex_hull shape = (2216, 56)
# [2017-02-05 00:09:50.111000] ********** iteration = 146 / 150
# name = model_20_m1_iter_145, n_topics = 20, n_doc_passes = 5, seed_value = 245, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:10:17.685000] filtering iteration = 1 / 15
# [2017-02-05 00:10:28.346000] 13 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 63)
# [2017-02-05 00:10:28.346000] filtering iteration = 2 / 15
# [2017-02-05 00:10:38.372000] 5 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:10:38.372000] filtering iteration = 3 / 15
# [2017-02-05 00:10:46.686000] 1 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:10:46.686000] filtering iteration = 4 / 15
# [2017-02-05 00:10:56.244000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:10:56.244000] filtering iteration = 5 / 15
# [2017-02-05 00:11:05.040000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:11:05.041000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:11:05.041000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:11:05.041000] ********** iteration = 147 / 150
# name = model_20_m1_iter_146, n_topics = 20, n_doc_passes = 5, seed_value = 246, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:11:32.675000] filtering iteration = 1 / 15
# [2017-02-05 00:11:45.017000] 12 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-05 00:11:45.017000] filtering iteration = 2 / 15
# [2017-02-05 00:11:54.595000] 6 topics to remove, 7 not_removed_topics_count because close topics, current convex_hull shape = (2216, 59)
# [2017-02-05 00:11:54.595000] filtering iteration = 3 / 15
# [2017-02-05 00:12:05.252000] 2 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:12:05.252000] filtering iteration = 4 / 15
# [2017-02-05 00:12:14.231000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:12:14.231000] filtering iteration = 5 / 15
# [2017-02-05 00:12:24.237000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:12:24.237000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:12:24.237000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:12:24.237000] ********** iteration = 148 / 150
# name = model_20_m1_iter_147, n_topics = 20, n_doc_passes = 5, seed_value = 247, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:12:52.144000] filtering iteration = 1 / 15
# [2017-02-05 00:13:05.247000] 12 topics to remove, 27 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-05 00:13:05.247000] filtering iteration = 2 / 15
# [2017-02-05 00:13:15.349000] 5 topics to remove, 10 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-05 00:13:15.349000] filtering iteration = 3 / 15
# [2017-02-05 00:13:25.072000] 3 topics to remove, 2 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:13:25.073000] filtering iteration = 4 / 15
# [2017-02-05 00:13:33.732000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:13:33.732000] filtering iteration = 5 / 15
# [2017-02-05 00:13:42.555000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 57)
# [2017-02-05 00:13:42.555000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:13:42.556000] current convex_hull shape = (2216, 57)
# [2017-02-05 00:13:42.556000] ********** iteration = 149 / 150
# name = model_20_m1_iter_148, n_topics = 20, n_doc_passes = 5, seed_value = 248, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:14:10.951000] filtering iteration = 1 / 15
# [2017-02-05 00:14:22.093000] 13 topics to remove, 23 not_removed_topics_count because close topics, current convex_hull shape = (2216, 64)
# [2017-02-05 00:14:22.094000] filtering iteration = 2 / 15
# [2017-02-05 00:14:32.047000] 6 topics to remove, 5 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:14:32.048000] filtering iteration = 3 / 15
# [2017-02-05 00:14:41.284000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:14:41.285000] filtering iteration = 4 / 15
# [2017-02-05 00:14:50.778000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:14:50.778000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:14:50.778000] current convex_hull shape = (2216, 58)
# [2017-02-05 00:14:50.778000] ********** iteration = 150 / 150
# name = model_20_m1_iter_149, n_topics = 20, n_doc_passes = 5, seed_value = 249, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-02-05 00:15:20.445000] filtering iteration = 1 / 15
# [2017-02-05 00:15:32.909000] 13 topics to remove, 26 not_removed_topics_count because close topics, current convex_hull shape = (2216, 65)
# [2017-02-05 00:15:32.909000] filtering iteration = 2 / 15
# [2017-02-05 00:15:42.730000] 5 topics to remove, 8 not_removed_topics_count because close topics, current convex_hull shape = (2216, 60)
# [2017-02-05 00:15:42.730000] filtering iteration = 3 / 15
# [2017-02-05 00:15:51.809000] 2 topics to remove, 1 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:15:51.810000] filtering iteration = 4 / 15
# [2017-02-05 00:16:01.272000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:16:01.272000] filtering iteration = 5 / 15
# [2017-02-05 00:16:10.742000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 58)
# [2017-02-05 00:16:10.742000] topics to remove not increasing, breaking the for loop
# [2017-02-05 00:16:10.742000] current convex_hull shape = (2216, 58)

# %%
plot_convex_hull_topics_iterations_distribution(phi_convex_hull_2)
plot_convex_hull_columns_change(iterations_info_2)
# Out:
# [(129, 1, 0.017241379310344827), (2, 1, 0.017241379310344827), (131, 1, 0.017241379310344827), (7, 1, 0.017241379310344827), (136, 1, 0.017241379310344827), (10, 1, 0.017241379310344827), (139, 2, 0.034482758620689655), (141, 1, 0.017241379310344827), (14, 1, 0.017241379310344827), (143, 2, 0.034482758620689655), (144, 2, 0.034482758620689655), (145, 3, 0.05172413793103448), (147, 1, 0.017241379310344827), (20, 1, 0.017241379310344827), (149, 2, 0.034482758620689655), (25, 1, 0.017241379310344827), (31, 1, 0.017241379310344827), (34, 1, 0.017241379310344827), (35, 1, 0.017241379310344827), (40, 1, 0.017241379310344827), (45, 1, 0.017241379310344827), (138, 1, 0.017241379310344827), (62, 1, 0.017241379310344827), (65, 1, 0.017241379310344827), (67, 1, 0.017241379310344827), (68, 1, 0.017241379310344827), (73, 1, 0.017241379310344827), (76, 1, 0.017241379310344827), (78, 1, 0.017241379310344827), (142, 1, 0.017241379310344827), (86, 1, 0.017241379310344827), (89, 1, 0.017241379310344827), (90, 1, 0.017241379310344827), (93, 1, 0.017241379310344827), (94, 1, 0.017241379310344827), (96, 2, 0.034482758620689655), (98, 1, 0.017241379310344827), (100, 1, 0.017241379310344827), (108, 2, 0.034482758620689655), (110, 1, 0.017241379310344827), (111, 1, 0.017241379310344827), (115, 1, 0.017241379310344827), (116, 1, 0.017241379310344827), (118, 1, 0.017241379310344827), (120, 1, 0.017241379310344827), (148, 3, 0.05172413793103448), (123, 1, 0.017241379310344827), (125, 1, 0.017241379310344827)]

# %%
save_pickle_file(iterations_info_2, 'iterations_info_2')

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_5, iterations_info_5 = build_convex_hull_with_filtering(create_model_fn_2, get_topics_to_remove_by_opt_fun_and_distance, 
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=150)
plot_convex_hull_topics_iterations_distribution(phi_convex_hull_5)
plot_convex_hull_columns_change(iterations_info_5)
# save_pickle_file(iterations_info_5, 'iterations_info_5')

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_6, iterations_info_6 = build_convex_hull_with_filtering(create_model_fn_3, get_topics_to_remove_by_opt_fun_and_distance, 
                                                     phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=150)
plot_convex_hull_topics_iterations_distribution(phi_convex_hull_6)
plot_convex_hull_columns_change(iterations_info_6)
# save_pickle_file(iterations_info_6, 'iterations_info_6')

# %%
save_pickle_file(phi_convex_hull_2, 'phi_convex_hull_2')
save_pickle_file(phi_convex_hull_3, 'phi_convex_hull_3')
save_pickle_file(phi_convex_hull_4, 'phi_convex_hull_4')
save_pickle_file(phi_convex_hull_5, 'phi_convex_hull_5')
save_pickle_file(phi_convex_hull_6, 'phi_convex_hull_6')

# %%
# to do : save phi_convex on each iteration,
# make plot each iteration , save it
# разобраться почему 
# заодно сразу стабильность мерить
# спроектировать конечный результат на оригинальную
# Out:
# [0, 2, 4, 6, 4, 9, 8, 7, 12, 7, 8, 9, 10, 10, 11, 15, 13, 13, 11, 13, 11, 15, 9, 13, 15, 15, 7, 11, 16, 8, 12, 11, 11, 18, 6, 10, 12, 11, 12, 13, 17, 15, 16, 11, 15, 12, 15, 14, 13, 15]
