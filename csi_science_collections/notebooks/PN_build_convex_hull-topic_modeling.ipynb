# %%
import pickle
import sys
import numpy as np
import pandas as pd
import artm
import seaborn as sns
import matplotlib.pyplot as plt
print artm.version()

from os import path, mkdir
from datetime import datetime
sys.path.insert(0, '..\\modules\\helpers')

import distances_helper as dh 
import print_helper as ph
import create_model_helper as cmh
import build_convex_hull_helper as bchh
import different_models as dm

from plot_helper import PlotMaker
from config_helper import ConfigPaths
from scipy.optimize import minimize
# Out:
# 0.8.1

# %%
config = ConfigPaths('config_sample_m3.cfg')
print config.models_file_name
models_file = open(config.models_file_name, 'a')

plot_maker = PlotMaker()

batch_vectorizer = artm.BatchVectorizer(data_path=config.output_batches_path,
                                        data_format='batches')
dictionary = artm.Dictionary()
dictionary.load(dictionary_path=config.dictionary_path + '.dict')
# Out:
# Q:\\topic_modeling\\csi_science_collections.git\experiments\pn_model3\np_24_02_kl\models.txt

# %%
# permutations
def get_optimization_result_opt(dist_fn, phi_permuted, _phi_original, n_closest_topics_count):
    distances = bchh.calculate_distances(dist_fn, phi_permuted, _phi_original)
    opt_res_convex_hull = bchh.get_optimization_result(dist_fn, None, phi_permuted, _phi_original,
                                                             distances, n_closest_topics_count)
    return opt_res_convex_hull

def test_permutation_optimization(_phi_original, dist_fn, n_closest_topics_count, 
                                  get_optimization_result_fn, _debug_print=False):
    _phi_original = phi_original
    n_topics = _phi_original.shape[1]
    indices = np.random.choice(n_topics, n_topics, replace=False)
    phi_permuted = _phi_original.iloc[:, indices]
    opt_res_convex_hull = get_optimization_result_fn(dist_fn, phi_permuted, _phi_original, n_closest_topics_count)
    if _debug_print:
        for _, item in opt_res_convex_hull.items():
             print item['optimized_column'], item['fun'], item['x'][0:2], item['column_names'][0:2]
    matched_columns_count = 0
    good_x_coefficient_count = 0
    for _, item in opt_res_convex_hull.items():
        x_and_names = zip(item['x'], item['column_names'])
        x_and_names.sort(key=lambda x: x[0], reverse=True)
#         print x_and_names
        matched_columns_count += item['optimized_column'] == x_and_names[0][1]
        good_x_coefficient_count += x_and_names[0][0] > 0.98
    matched_columns = 100.0 * matched_columns_count / n_topics
    good_x_coefficient = 100.0 * good_x_coefficient_count / n_topics
    print 'matched_columns = {}%, good_x_coefficient = {}%'.format(matched_columns, good_x_coefficient)
    return matched_columns, good_x_coefficient

def test_combination_optimization(_phi_original, dist_fn, n_closest_topics_count, 
                                  get_optimization_result_fn, n_runs, _debug_print=False):
    _eps = 0.15
    not_found_count_list, matched_coeffs_count_list = [], []
    for n_iter in range(n_runs):               
        word_count, topics_count = phi_original.shape
        combination_count = np.random.randint(2, 7)
        combination_indices = np.random.choice(topics_count, combination_count, replace=False)
        phi_combination = phi_original.iloc[:, combination_indices]
        single_combination_weights = np.random.uniform(0, 1, combination_count)
        single_combination_weights = single_combination_weights / sum(single_combination_weights)
        combination_weights = np.array([single_combination_weights] * word_count)
        combination_weights = pd.DataFrame(data=combination_weights, index=phi_combination.index,
                                           columns=phi_combination.columns)
        phi_combination = phi_combination.multiply(combination_weights)
        phi_combination = pd.DataFrame(phi_combination.sum(axis=1), index=phi_combination.index, columns=['combination_0'])

        opt_res_convex_hull = get_optimization_result_fn(dist_fn, phi_combination, _phi_original, n_closest_topics_count)
        
        results = []
        for idx, col_name in enumerate(phi_original.columns[combination_indices]):
            opt_cols_names = list(opt_res_convex_hull['combination_0']['column_names'])
            col_name_opt_idx = opt_cols_names.index(col_name) if col_name in opt_cols_names else -1
            col_name_opt_x = opt_res_convex_hull['combination_0']['x'][col_name_opt_idx] if col_name_opt_idx != -1 else 0
            col_name_opt_idx = col_name_opt_idx if col_name_opt_idx != -1 else \
                               (0 if single_combination_weights[idx] < 0.1 else -1)
            results.append((col_name, single_combination_weights[idx], col_name_opt_x))           
        not_found_count = len([res for res in results if res[2] == -1]) * 100.0 / combination_count
        matched_coeffs_count = 100.0 * len([res for res in results if abs(res[1] - res[2]) < _eps]) / combination_count
        if _debug_print or not_found_count != 0 or matched_coeffs_count != 100: 
            print('it = {} / {} not_found_columns_count = {}%, matched_coeffs_count = {}%'.format(n_iter + 1, n_runs, 
                                                                            not_found_count, matched_coeffs_count))
            for r in results:
                print r
        not_found_count_list.append(not_found_count)
        matched_coeffs_count_list.append(matched_coeffs_count)
    total_not_found_count = sum(not_found_count_list) / n_runs
    total_matched_coeffs_count = sum(matched_coeffs_count_list) / n_runs
    print('total not_found_columns_count = {}%, matched_coeffs_count = {}%'.format(total_not_found_count,
                                                                                   total_matched_coeffs_count))
    return total_not_found_count, total_matched_coeffs_count

# %% [markdown]
# Загрузим оригинальный sample датасет (от model3), до этого скопировав в папку с batches нужные pickle файлы модели.
# Сначала провизуалируем по одной итерации каждой новой модели, а потом будем итерационно строить выпуклую оболочку для каждой модели по отдельности и затем сравнивать их.

# %%
phi_original, theta_original, saved_top_tokens_original, distances_hellinger_model_original = load_model_pickle('model3', 'distances_hellinger_model3', config.output_batches_path)
print phi_original.shape, theta_original.shape
# Out:
# (2216, 100) (100, 3446)

# %% [markdown]
# Запустить несколько раз с разным рандомом. Следить за тем, чтобы накапливались только независимые темы. Каждый раз смотреть. как проектируется на оригинальную матрицу.

# %% [markdown]
# # topic_modeling_coefficient

# %%
# %matplotlib inline

# %%
#init model with phi
_debug_print = False
tm_model = cmh.create_model(current_dictionary=dictionary, n_topics=100, n_doc_passes=5, seed_value=100,
                            n_top_tokens=15, p_mass_threshold=0.25)
(_, phi_ref) = tm_model.master.attach_model(model=tm_model.model_pwt)
if _debug_print:
    for model_description in tm_model.info.model:
        print model_description
np.copyto(phi_ref, phi_original.values)

# %%
# test data
n_topics = phi_original.shape[1]
# indices = np.random.choice(n_topics, n_topics, replace=False)
# phi_permuted = phi_original.iloc[:, indices]
phi_permuted = phi_original
phi_permuted = phi_permuted.iloc[:, 0:10]

# %%
# create batch_vectorizer
vocabulary = {idx: word for idx, word in enumerate(phi_permuted.index)}
phi_values = np.array(phi_permuted.values, dtype=np.float)
test_batch_vectorizer = artm.BatchVectorizer(data_format='bow_n_wd',
                                             n_wd=phi_values,
                                             vocabulary=vocabulary)
# transform
theta_test = tm_model.transform(batch_vectorizer=test_batch_vectorizer)

# %%
X = phi_permuted

# %%
word_count, topics_count = phi_original.shape
combination_count = np.random.randint(2, 7)
combination_indices = np.random.choice(topics_count, combination_count, replace=False)
phi_combination = phi_original.iloc[:, combination_indices]
single_combination_weights = np.random.uniform(0, 1, combination_count)
single_combination_weights = single_combination_weights / sum(single_combination_weights)
combination_weights = np.array([single_combination_weights]*word_count)
combination_weights = pd.DataFrame(data=combination_weights, index=phi_combination.index, columns=phi_combination.columns)
phi_combination = phi_combination.multiply(combination_weights)
phi_combination = pd.DataFrame(phi_combination.sum(axis=1), index=phi_combination.index, columns=['combination_0'])

# %%
X = phi_combination

# %%
#init model with phi
_debug_print = False
tm_model = cmh.create_model(current_dictionary=dictionary, n_topics=100, n_doc_passes=5, seed_value=100,
                            n_top_tokens=15, p_mass_threshold=0.25)
(_, phi_ref) = tm_model.master.attach_model(model=tm_model.model_pwt)
if _debug_print:
    for model_description in tm_model.info.model:
        print model_description
np.copyto(phi_ref, phi_original.values) 

# test data
print X.shape, np.all(X.index == phi_original.index)

# create batch_vectorizer
vocabulary = {idx: word for idx, word in enumerate(X.index)}
X_values = np.array(X.values, dtype=np.float)
test_batch_vectorizer = artm.BatchVectorizer(data_format='bow_n_wd',
                                             n_wd=X_values,
                                             vocabulary=vocabulary)

# transform
theta_test = tm_model.transform(batch_vectorizer=test_batch_vectorizer)
# Out:
# (2216, 1) True

# %%
print theta_test.shape
idx = 0
X_col = X.iloc[:, idx]
theta_test_col = theta_test.iloc[:, idx]
X_col_restated = phi_original.dot(theta_test_col)
print 'phi_orig = {}, theta_test_col = {}, X_restated = {}'.format(phi_original.shape, theta_test_col.shape, X_col_restated.shape)
is_close = np.all(abs(X_col_restated - X_col) < 1e-2)
print is_close, np.sum(abs(X_col_restated - X_col))

# %%
np.all(phi_original.columns == theta_test.index)
# Out:
# True

# %%
X_restated = phi_original.dot(theta_test)
print np.all(X_restated.index == X.index) 
print phi_original.shape, theta_test.shape, X_restated.shape, X.shape
is_close = np.all(abs(X_restated.values - X.values) < 0.001)
print is_close, np.sum(np.sum(abs(X_restated.values - X.values)))
# Out:
# True
# (2216, 100) (100, 10) (2216, 10) (2216, 10)
# False 18.3953

# %% [markdown]
# ## inverse

# %%
# X = PHI_ORIGINAL * THETA
from numpy.linalg import inv, lstsq

# %%
def get_lsrsq_result(dist_fn, phi, phi_other, n_closest_topics_count):
    r = lstsq(phi_other, phi)
    x_values = r[0]
    res = {col: {'optimized_column': col, 'fun': dist_fn(phi[col], phi_other.dot(x_values[:, idx])), 
                 'column_names': phi_other.columns,
                 'x': x_values[:, idx]} for idx, col in enumerate(phi.columns)}
    return res

# %%
distance_fns = [dh.hellinger_dist, dh.kl_dist, dh.jaccard_dist, dh.cos_dist]
for dist_fn in distance_fns:
    print('Processing distance fn = {}'.format(dist_fn))
    _,_ = test_permutation_optimization(phi_original, dist_fn, n_closest_topics_count=5, 
                                        get_optimization_result_fn=get_lsrsq_result)
    _,_ = test_combination_optimization(phi_original, dist_fn, n_closest_topics_count=5, 
                                        get_optimization_result_fn=get_lsrsq_result,
                                        n_runs=100, _debug_print=False)
# Out:
# Processing distance fn = <function hellinger_dist at 0x000000000C457438>
# ..\modules\helpers\distances_helper.py:50: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.sum((np.sqrt(p) - np.sqrt(q)) ** 2)) / np.sqrt(2)
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# Processing distance fn = <function kl_dist at 0x000000000C3DF438>
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# Processing distance fn = <function jaccard_dist at 0x000000000C457208>
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# Processing distance fn = <function cos_dist at 0x000000000C457358>
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%

# %% [markdown]
# # em

# %%
EPS = 1e-30
INF = 1e+10
PERPLEXITY_EPS = 1.0

import time
import numpy.matlib as npm

def __init_matrix(height, width):
    result = np.random.rand(height, width)
    return result / np.sum(result, 0)

def count_perplexity(n_dw, Phi, Theta):
    value = 0.0
    for w in xrange(n_dw.shape[0]):
        p_wd = np.dot(Phi[w, :], Theta)
        value += np.sum(np.multiply(n_dw[w, :], np.nan_to_num(np.log(p_wd))))
    return np.exp(-1.0 / np.sum(np.sum(n_dw)) * value)

def plsa_em_vectorized_fixed_phi(n_dw, num_topics, Phi_init, max_iter=100, Theta_init=None, avoid_print=False):
    num_tokens, num_docs = n_dw.shape
    Phi = Phi_init
    Theta = Theta_init if not Theta_init is None else __init_matrix(num_topics, num_docs)

    old_perplexity_value = INF

    for i in xrange(max_iter):
        time_start = time.time()
        n_wt = np.zeros([num_tokens, num_topics]);
        Theta_new = np.copy(Theta)
        Z = np.dot(Phi, Theta)
        Z[Z == 0.0] = INF
        n_d = np.sum(n_dw, 0)
        n_d[n_d == 0.0] = INF
        Theta_new = np.divide(np.multiply(Theta, np.dot(np.transpose(Phi), np.divide(n_dw, Z))), npm.repmat(n_d, num_topics, 1))
        Theta = Theta_new

        perplexity_value = count_perplexity(n_dw, Phi, Theta)
        if not avoid_print:
            print 'Iter# {}, perplexity value: {}, elapsed time: {}'.format(i, perplexity_value,
                                                                            time.time() - time_start)
        if abs(perplexity_value - old_perplexity_value) < PERPLEXITY_EPS or i == (max_iter - 1):
            return Phi, Theta
        else:
            old_perplexity_value = perplexity_value

def get_em_result(dist_fn, phi, phi_other, n_closest_topics_count, _debug_print=False):
    phi_1, x_values = plsa_em_vectorized_fixed_phi(phi.values, num_topics=phi_other.shape[1], max_iter=40,
                                                  Phi_init=phi_other.values, Theta_init=None, avoid_print=True)
    X_restated = phi_other.values.dot(x_values)
    if _debug_print:
#         print X_restated.shape, phi_1.shape, phi_other.shape, phi.shape
        print 'phi close {}, is nan {}, restated close {} '.format(np.all(abs(phi_1 - phi_other) < 1e-4), 
                                            np.any(np.isnan(x_values)), 
                                            np.all(abs(X_restated - phi) < 1e-2), \
                                            np.sum(np.sum(abs(X_restated - phi))))
    res = {col: {'optimized_column': col, 'fun': dist_fn(phi[col], phi_other.dot(x_values[:, idx])), 
                 'column_names': phi_other.columns,
                 'x': x_values[:, idx]} for idx, col in enumerate(phi.columns)}
    return res

# %%
phi_3, theta_3 = plsa_em_vectorized_fixed_phi(phi_permuted.values, num_topics=100, max_iter=10,
                                    Phi_init=phi_original.values, Theta_init=None, avoid_print=False)
X_restated = phi_original.values.dot(theta_3)
print np.all(abs(phi_3 - phi_original) < 1e-4), np.any(np.isnan(theta_3)), np.all(abs(X_restated - phi_permuted) < 1e-2), \
np.sum(np.sum(abs(X_restated - phi_permuted)))

# %%
# actually doesn't depend on metrics !!! (faster)
distance_fns = [dh.hellinger_dist, dh.kl_dist, dh.jaccard_dist, dh.cos_dist]
for dist_fn in distance_fns:
    print('Processing distance fn = {}'.format(dist_fn))
    _,_ = test_permutation_optimization(phi_original, dist_fn, n_closest_topics_count=5, 
                                        get_optimization_result_fn=get_em_result)
    print("-------------------------------------------------------")
    _,_ = test_combination_optimization(phi_original, dist_fn, n_closest_topics_count=5, 
                                        get_optimization_result_fn=get_em_result,
                                        n_runs=100, _debug_print=False)
    print("=======================================================")
# Out:
# Processing distance fn = <function hellinger_dist at 0x000000000C457438>
# C:\Users\Sheldon\Anaconda2\lib\site-packages\ipykernel\__main__.py:16: RuntimeWarning: divide by zero encountered in log
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# -------------------------------------------------------
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# =======================================================
# Processing distance fn = <function kl_dist at 0x000000000C3DF438>
# matched_columns = 100.0%, good_x_coefficient = 99.0%
# -------------------------------------------------------
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# =======================================================
# Processing distance fn = <function jaccard_dist at 0x000000000C457208>
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# -------------------------------------------------------
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# =======================================================
# Processing distance fn = <function cos_dist at 0x000000000C457358>
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# -------------------------------------------------------
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# =======================================================

# %%
p = phi_original.iloc[:, 1]
q = phi_original.iloc[:, 2]
print dh.cos_dist(p, q), dh.kl_dist(p, q), dh.kl_sym_dist(p, q), dh.jaccard_dist(p, q)

# %% [markdown]
# # opt

# %%
def get_optimization(dist_fn, phi, phi_other, n_closest_topics_count):
    distances = bchh.calculate_distances(dist_fn, phi, phi_other)
    opt_res_convex_hull = bchh.get_optimization_result(dist_fn, None, phi, phi_other,
                                                       distances, n_closest_topics_count)
    return opt_res_convex_hull

# %%
distance_fns = [dh.hellinger_dist, dh.kl_dist, dh.jaccard_dist, dh.cos_dist]
for dist_fn in distance_fns:
    print('Processing distance fn = {}'.format(dist_fn))
    _,_ = test_permutation_optimization(phi_original, dist_fn, n_closest_topics_count=15, 
                                        get_optimization_result_fn=get_optimization)
    print("-------------------------------------------------------")
    _,_ = test_combination_optimization(phi_original, dist_fn, n_closest_topics_count=15, 
                                        get_optimization_result_fn=get_optimization,
                                        n_runs=100, _debug_print=False)
    print("=======================================================")
# Out:
# Processing distance fn = <function hellinger_dist at 0x000000000C457438>
# Column topic_88 not optimized
# Column topic_5 not optimized
# Column topic_48 not optimized
# Column topic_51 not optimized
# Column topic_22 not optimized
# Column topic_72 not optimized
# Column topic_1 not optimized
# Column topic_20 not optimized
# Column topic_34 not optimized
# Column topic_8 not optimized
# Column topic_55 not optimized
# Column topic_83 not optimized
# Column topic_54 not optimized
# Column topic_87 not optimized
# Column topic_91 not optimized
# Column topic_13 not optimized
# Column topic_46 not optimized
# Column topic_68 not optimized
# Column topic_14 not optimized
# Column topic_57 not optimized
# Column topic_89 not optimized
# Column topic_29 not optimized
# Column topic_95 not optimized
# Column topic_32 not optimized
# Column topic_9 not optimized
# Column topic_28 not optimized
# Column topic_0 not optimized
# Column topic_96 not optimized
# Column topic_25 not optimized
# Column topic_58 not optimized
# Column topic_17 not optimized
# Column topic_6 not optimized
# Column topic_35 not optimized
# Column topic_7 not optimized
# Column topic_79 not optimized
# Column topic_49 not optimized
# Column topic_71 not optimized
# Column topic_53 not optimized
# Column topic_33 not optimized
# Column topic_99 not optimized
# Column topic_80 not optimized
# Column topic_15 not optimized
# Column topic_75 not optimized
# Column topic_43 not optimized
# Column topic_73 not optimized
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# -------------------------------------------------------
# Column combination_0 not optimized
# it = 73 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_83', 0.0015234460698700164, 0)
# (u'topic_98', 0.21880014983859916, 0.37800244428234725)
# (u'topic_46', 0.77967640409153083, 0.62172264883046457)
# it = 82 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 75.0%
# (u'topic_49', 0.24125768735414341, 0.27535835758732635)
# (u'topic_66', 0.21584588679253772, 0.025236281866472372)
# (u'topic_81', 0.13662742491759497, 0.16537058494369494)
# (u'topic_48', 0.40626900093572382, 0.4632268445711677)
# it = 85 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 75.0%
# (u'topic_10', 0.26719350498184313, 0.30010285696345934)
# (u'topic_94', 0.2854931145920851, 0.31741377830239242)
# (u'topic_45', 0.2675472915689413, 0.2977545939902177)
# (u'topic_12', 0.17976608885713052, 0.025365585419202887)
# it = 91 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 80.0%
# (u'topic_36', 0.063410816911868881, 0.003899109635839876)
# (u'topic_27', 0.14853490535205194, 0.210420285780519)
# (u'topic_85', 0.21429116685309293, 0.00022640352955605609)
# (u'topic_82', 0.2998925372273179, 0.41598330090072722)
# (u'topic_54', 0.27387057365566825, 0.35414054879337453)
# total not_found_columns_count = 0.0%, matched_coeffs_count = 98.6333333333%
# =======================================================
# Processing distance fn = <function kl_dist at 0x000000000C3DF438>
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# -------------------------------------------------------
# Column combination_0 not optimized
# it = 1 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_50', 0.096712252185317635, 0)
# (u'topic_28', 0.25896778078068949, 0)
# (u'topic_63', 0.49289227897940374, nan)
# (u'topic_10', 0.15142768805458917, 0)
# Column combination_0 not optimized
# it = 2 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_2', 0.24852860847128599, 0)
# (u'topic_78', 0.75147139152871389, 0)
# Column combination_0 not optimized
# it = 3 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_63', 0.68719096159117088, nan)
# (u'topic_30', 0.31280903840882912, 0)
# Column combination_0 not optimized
# it = 4 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_56', 0.71784146184165398, 0)
# (u'topic_79', 0.28215853815834602, 0)
# Column combination_0 not optimized
# it = 5 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_56', 0.081046149347313412, 0)
# (u'topic_52', 0.17567695778327252, 0)
# (u'topic_32', 0.2297457580461654, 0)
# (u'topic_28', 0.056804166397490134, 0)
# (u'topic_0', 0.34619246514877083, nan)
# (u'topic_92', 0.11053450327698765, 0)
# Column combination_0 not optimized
# it = 6 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_92', 0.26130901469291845, 0)
# (u'topic_93', 0.46500389776444517, 0)
# (u'topic_80', 0.27368708754263632, 0)
# Column combination_0 not optimized
# it = 7 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_42', 0.10174866990454656, 0)
# (u'topic_59', 0.36866906263007432, nan)
# (u'topic_22', 0.35253824162711234, 0)
# (u'topic_33', 0.013950222341791616, 0)
# (u'topic_20', 0.0050763297603792354, 0)
# (u'topic_68', 0.15801747373609581, nan)
# Column combination_0 not optimized
# it = 8 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_5', 0.0013369309507157798, 0)
# (u'topic_6', 0.081141144626157236, 0)
# (u'topic_40', 0.34052677291272021, 0)
# (u'topic_23', 0.22419233504936192, 0)
# (u'topic_45', 0.10534482927072467, 0)
# (u'topic_4', 0.24745798719032, 0)
# Column combination_0 not optimized
# it = 9 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_88', 0.51278434039802001, 0)
# (u'topic_28', 0.48721565960197993, 0)
# Column combination_0 not optimized
# it = 10 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 16.6666666667%
# (u'topic_16', 0.15795731002003105, 0)
# (u'topic_7', 0.088253012658812593, 0)
# (u'topic_36', 0.25818228316740699, 0)
# (u'topic_66', 0.087664954058548003, nan)
# (u'topic_47', 0.18248283931792805, 0)
# (u'topic_67', 0.22545960077727328, nan)
# Column combination_0 not optimized
# it = 11 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_48', 0.24060928348291308, 0)
# (u'topic_64', 0.35300191688177507, nan)
# (u'topic_62', 0.40638879963531183, nan)
# Column combination_0 not optimized
# it = 12 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_6', 0.21933587727869377, 0)
# (u'topic_41', 0.017783170882897045, 0)
# (u'topic_13', 0.045545072732389918, 0)
# (u'topic_77', 0.32195869148412143, 0)
# (u'topic_93', 0.081847656518870215, 0)
# (u'topic_9', 0.31352953110302767, 0)
# Column combination_0 not optimized
# it = 13 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_53', 0.17596109753272152, 0)
# (u'topic_65', 0.24791671396040524, nan)
# (u'topic_0', 0.2300325434240639, nan)
# (u'topic_43', 0.18550568984341437, 0)
# (u'topic_48', 0.16058395523939495, 0)
# Column combination_0 not optimized
# it = 14 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_68', 0.25435634337119117, nan)
# (u'topic_83', 0.74564365662880872, 0)
# Column combination_0 not optimized
# it = 15 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 16.6666666667%
# (u'topic_45', 0.20993218905599367, 0)
# (u'topic_44', 0.16009872748938289, 0)
# (u'topic_99', 0.23507568847769786, 0)
# (u'topic_17', 0.0083713779043915141, 0)
# (u'topic_89', 0.20433928536582757, 0)
# (u'topic_40', 0.18218273170670646, 0)
# Column combination_0 not optimized
# it = 16 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_31', 0.13376449617178962, 0)
# (u'topic_13', 0.43749752326936359, 0)
# (u'topic_33', 0.25865142360708993, 0)
# (u'topic_36', 0.17008655695175692, 0)
# Column combination_0 not optimized
# it = 17 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_60', 0.28457075583102032, nan)
# (u'topic_5', 0.01072486182066585, 0)
# (u'topic_77', 0.43601953330235993, 0)
# (u'topic_58', 0.2242567494098156, 0)
# (u'topic_55', 0.044428099636138224, 0)
# Column combination_0 not optimized
# it = 18 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_18', 0.25885440153178202, 0)
# (u'topic_75', 0.0044461303739203369, 0)
# (u'topic_46', 0.46980025235446127, 0)
# (u'topic_44', 0.26689921573983633, 0)
# Column combination_0 not optimized
# it = 19 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_36', 0.045079640828161766, 0)
# (u'topic_46', 0.24671573774846461, 0)
# (u'topic_1', 0.29483677876993697, 0)
# (u'topic_43', 0.011996282935474882, 0)
# (u'topic_3', 0.31136505336430631, 0)
# (u'topic_23', 0.090006506353655272, 0)
# Column combination_0 not optimized
# it = 20 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_41', 0.020798529657150251, 0)
# (u'topic_86', 0.20797425984688972, 0)
# (u'topic_63', 0.19077368573052345, nan)
# (u'topic_66', 0.276514268321783, nan)
# (u'topic_73', 0.098173483808898135, 0)
# (u'topic_10', 0.20576577263475554, 0)
# Column combination_0 not optimized
# it = 21 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_69', 0.47143729775416376, nan)
# (u'topic_58', 0.04576505936487138, 0)
# (u'topic_83', 0.48279764288096488, 0)
# Column combination_0 not optimized
# it = 22 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_12', 0.18715629788302443, 0)
# (u'topic_96', 0.48392009367482586, 0)
# (u'topic_56', 0.32892360844214974, 0)
# Column combination_0 not optimized
# it = 23 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_59', 0.66874740130368637, nan)
# (u'topic_64', 0.20523859119399646, nan)
# (u'topic_19', 0.12601400750231734, 0)
# Column combination_0 not optimized
# it = 24 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_58', 0.12663699368813119, 0)
# (u'topic_64', 0.53120506585682614, nan)
# (u'topic_88', 0.34215794045504277, 0)
# Column combination_0 not optimized
# it = 25 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_52', 0.19529662392148509, 0)
# (u'topic_60', 0.80470337607851494, nan)
# Column combination_0 not optimized
# it = 26 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_66', 0.10550413328880701, nan)
# (u'topic_90', 0.080478531175226853, 0)
# (u'topic_56', 0.49991132088874024, 0)
# (u'topic_84', 0.064882217318553509, 0)
# (u'topic_1', 0.24922379732867223, 0)
# Column combination_0 not optimized
# it = 27 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_16', 0.11934386615568286, 0)
# (u'topic_23', 0.27564492699673182, 0)
# (u'topic_56', 0.50540873807953346, 0)
# (u'topic_30', 0.076372852520187065, 0)
# (u'topic_95', 0.023229616247864703, 0)
# Column combination_0 not optimized
# it = 28 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_72', 0.47635729946381017, nan)
# (u'topic_57', 0.52364270053618989, 0)
# Column combination_0 not optimized
# it = 29 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_46', 0.65591025752520482, 0)
# (u'topic_85', 0.34408974247479518, 0)
# Column combination_0 not optimized
# it = 30 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 16.6666666667%
# (u'topic_31', 0.023053803326344217, 0)
# (u'topic_79', 0.20390960666672156, 0)
# (u'topic_88', 0.28496920595392222, 0)
# (u'topic_82', 0.32013061815014621, 0)
# (u'topic_64', 0.090557471406375212, nan)
# (u'topic_65', 0.077379294496490628, nan)
# Column combination_0 not optimized
# it = 31 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_46', 0.47262086467865067, 0)
# (u'topic_39', 0.4356034657907667, 0)
# (u'topic_71', 0.091775669530582596, nan)
# Column combination_0 not optimized
# it = 32 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_58', 0.20578194785105336, 0)
# (u'topic_17', 0.44842867442658002, 0)
# (u'topic_31', 0.061804823823468427, 0)
# (u'topic_59', 0.28398455389889821, nan)
# Column combination_0 not optimized
# it = 33 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_93', 0.16304105153142545, 0)
# (u'topic_36', 0.024112982255437961, 0)
# (u'topic_82', 0.11033557140322299, 0)
# (u'topic_46', 0.30698110312113236, 0)
# (u'topic_50', 0.35202427100392608, 0)
# (u'topic_39', 0.043505020684855157, 0)
# Column combination_0 not optimized
# it = 34 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_20', 0.18297835940553245, 0)
# (u'topic_97', 0.020147863120823818, 0)
# (u'topic_70', 0.50885671301884405, nan)
# (u'topic_80', 0.28801706445479974, 0)
# Column combination_0 not optimized
# it = 35 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_23', 0.27681816759810496, 0)
# (u'topic_20', 0.13784448677081179, 0)
# (u'topic_68', 0.44863756589219717, nan)
# (u'topic_43', 0.13669977973888611, 0)
# Column combination_0 not optimized
# it = 36 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_78', 0.18021848019080788, 0)
# (u'topic_96', 0.21004043347349777, 0)
# (u'topic_15', 0.016794930864810622, 0)
# (u'topic_88', 0.055761119538850351, 0)
# (u'topic_67', 0.22317369898252071, nan)
# (u'topic_32', 0.31401133694951272, 0)
# Column combination_0 not optimized
# it = 37 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_64', 0.38407645349173186, nan)
# (u'topic_85', 0.61592354650826819, 0)
# Column combination_0 not optimized
# it = 38 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_42', 0.51785202168510525, 0)
# (u'topic_5', 0.48214797831489487, 0)
# Column combination_0 not optimized
# it = 39 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_26', 0.31564338362377242, 0)
# (u'topic_82', 0.31889609203212527, 0)
# (u'topic_93', 0.36546052434410231, 0)
# Column combination_0 not optimized
# it = 40 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_46', 0.36158116657954015, 0)
# (u'topic_87', 0.056692822801468826, 0)
# (u'topic_84', 0.19091958531029482, 0)
# (u'topic_42', 0.39080642530869619, 0)
# Column combination_0 not optimized
# it = 41 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 20.0%
# (u'topic_51', 0.2968474505250206, 0)
# (u'topic_88', 0.23834012280697456, 0)
# (u'topic_41', 0.1733810153135085, 0)
# (u'topic_82', 0.16759951052861435, 0)
# (u'topic_37', 0.12383190082588189, 0)
# Column combination_0 not optimized
# it = 42 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_3', 0.51716454665810574, 0)
# (u'topic_48', 0.48283545334189432, 0)
# Column combination_0 not optimized
# it = 43 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_74', 0.24055434438842896, 0)
# (u'topic_68', 0.23951395648021695, nan)
# (u'topic_92', 0.51993169913135406, 0)
# Column combination_0 not optimized
# it = 44 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_46', 0.37574756921708979, 0)
# (u'topic_94', 0.2365425677040868, 0)
# (u'topic_44', 0.049394388390679944, 0)
# (u'topic_17', 0.1289084947173525, 0)
# (u'topic_13', 0.20940697997079094, 0)
# Column combination_0 not optimized
# it = 45 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 20.0%
# (u'topic_83', 0.27918189542928301, 0)
# (u'topic_75', 0.15472366512632074, 0)
# (u'topic_39', 0.21104774962223327, 0)
# (u'topic_23', 0.096062479315963442, 0)
# (u'topic_33', 0.25898421050619946, 0)
# Column combination_0 not optimized
# it = 46 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_53', 0.31973147937897056, 0)
# (u'topic_95', 0.05954486624117452, 0)
# (u'topic_81', 0.23290312447915232, 0)
# (u'topic_8', 0.091869226463498876, 0)
# (u'topic_1', 0.29595130343720377, 0)
# Column combination_0 not optimized
# it = 47 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_69', 0.40451836285105625, nan)
# (u'topic_95', 0.19250809205438765, 0)
# (u'topic_66', 0.40297354509455602, nan)
# Column combination_0 not optimized
# it = 48 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_97', 0.012358839273055758, 0)
# (u'topic_49', 0.24876949212760283, 0)
# (u'topic_69', 0.3115647211363784, nan)
# (u'topic_3', 0.28901468584793472, 0)
# (u'topic_27', 0.13829226161502825, 0)
# Column combination_0 not optimized
# it = 49 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_84', 0.52679415919555062, 0)
# (u'topic_64', 0.3252222851537952, nan)
# (u'topic_46', 0.1083713008007669, 0)
# (u'topic_40', 0.039612254849887465, 0)
# Column combination_0 not optimized
# it = 50 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_35', 0.38497382577609174, 0)
# (u'topic_41', 0.032300505082488294, 0)
# (u'topic_9', 0.34591920836618467, 0)
# (u'topic_18', 0.013093592535983382, 0)
# (u'topic_52', 0.22371286823925191, 0)
# Column combination_0 not optimized
# it = 51 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_16', 0.23004626600521361, 0)
# (u'topic_12', 0.18862728375645124, 0)
# (u'topic_20', 0.38975046507213729, 0)
# (u'topic_96', 0.19157598516619798, 0)
# Column combination_0 not optimized
# it = 52 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_83', 0.083364540582249527, 0)
# (u'topic_86', 0.2408102211135896, 0)
# (u'topic_47', 0.3734641933175194, 0)
# (u'topic_6', 0.30236104498664151, 0)
# Column combination_0 not optimized
# it = 53 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 16.6666666667%
# (u'topic_16', 0.16871218572898883, 0)
# (u'topic_62', 0.09381394373047694, nan)
# (u'topic_14', 0.051608109552882107, 0)
# (u'topic_33', 0.22762322676553395, 0)
# (u'topic_73', 0.1799152759563114, 0)
# (u'topic_88', 0.27832725826580662, 0)
# Column combination_0 not optimized
# it = 54 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_79', 0.32550310324540871, 0)
# (u'topic_31', 0.13266050881625421, 0)
# (u'topic_36', 0.20994725983778398, 0)
# (u'topic_68', 0.3318891281005531, nan)
# Column combination_0 not optimized
# it = 55 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_26', 0.50112238994351133, 0)
# (u'topic_0', 0.49887761005648873, nan)
# Column combination_0 not optimized
# it = 56 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_95', 0.4934534903491557, 0)
# (u'topic_84', 0.50654650965084436, 0)
# Column combination_0 not optimized
# it = 57 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_29', 0.56104082686228041, 0)
# (u'topic_95', 0.43895917313771959, 0)
# Column combination_0 not optimized
# it = 58 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_17', 0.28699050828673051, 0)
# (u'topic_16', 0.02776669295338046, 0)
# (u'topic_39', 0.27041178752429185, 0)
# (u'topic_70', 0.41483101123559718, nan)
# Column combination_0 not optimized
# it = 59 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_31', 0.61744189910860003, 0)
# (u'topic_10', 0.38255810089139985, 0)
# Column combination_0 not optimized
# it = 60 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_33', 0.32429162980789206, 0)
# (u'topic_60', 0.11779584350643819, nan)
# (u'topic_77', 0.29768785113375518, 0)
# (u'topic_87', 0.2602246755519147, 0)
# Column combination_0 not optimized
# it = 61 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 20.0%
# (u'topic_62', 0.25493691728867235, nan)
# (u'topic_18', 0.22652275765999269, 0)
# (u'topic_76', 0.082231179222398379, 0)
# (u'topic_33', 0.2751271950178924, 0)
# (u'topic_68', 0.16118195081104422, nan)
# Column combination_0 not optimized
# it = 62 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_39', 0.63534047732270271, 0)
# (u'topic_45', 0.17614786793091969, 0)
# (u'topic_40', 0.18851165474637763, 0)
# Column combination_0 not optimized
# it = 63 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_99', 0.18081962902672849, 0)
# (u'topic_40', 0.31694005894702637, 0)
# (u'topic_56', 0.15650975320014368, 0)
# (u'topic_91', 0.016958429473331985, 0)
# (u'topic_14', 0.25340914526442909, 0)
# (u'topic_78', 0.075362984088340412, 0)
# Column combination_0 not optimized
# it = 64 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 20.0%
# (u'topic_44', 0.24295198413165686, 0)
# (u'topic_67', 0.28426604981081882, nan)
# (u'topic_27', 0.22185859468764998, 0)
# (u'topic_40', 0.089036897809053328, 0)
# (u'topic_90', 0.16188647356082106, 0)
# Column combination_0 not optimized
# it = 65 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_25', 0.17279527092566371, 0)
# (u'topic_93', 0.11050731262643158, 0)
# (u'topic_96', 0.21000162500072958, 0)
# (u'topic_29', 0.25176529146844867, 0)
# (u'topic_16', 0.036158623525660849, 0)
# (u'topic_38', 0.21877187645306545, 0)
# Column combination_0 not optimized
# it = 66 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 16.6666666667%
# (u'topic_36', 0.19862169164178842, 0)
# (u'topic_87', 0.036505906808791913, 0)
# (u'topic_86', 0.1938009038630179, 0)
# (u'topic_24', 0.16756331893484661, 0)
# (u'topic_66', 0.26156335171767359, nan)
# (u'topic_70', 0.14194482703388153, nan)
# Column combination_0 not optimized
# it = 67 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_54', 0.58842391038408259, 0)
# (u'topic_29', 0.41157608961591741, 0)
# Column combination_0 not optimized
# it = 68 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_44', 0.0051843344940091093, 0)
# (u'topic_86', 0.046372249566058205, 0)
# (u'topic_1', 0.044329178914182608, 0)
# (u'topic_74', 0.44332862134443335, 0)
# (u'topic_23', 0.16700890865044846, 0)
# (u'topic_17', 0.29377670703086822, 0)
# Column combination_0 not optimized
# it = 69 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_2', 0.20498481730447596, 0)
# (u'topic_60', 0.27623306275393089, nan)
# (u'topic_94', 0.12909113900125346, 0)
# (u'topic_49', 0.14737006315287429, 0)
# (u'topic_20', 0.19482860717422604, 0)
# (u'topic_81', 0.047492310613239427, 0)
# Column combination_0 not optimized
# it = 70 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_39', 0.58345118798643747, 0)
# (u'topic_84', 0.01275479497344521, 0)
# (u'topic_40', 0.24199262567993951, 0)
# (u'topic_92', 0.16180139136017788, 0)
# Column combination_0 not optimized
# it = 71 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_32', 0.17429239180465886, 0)
# (u'topic_47', 0.34738938831939964, 0)
# (u'topic_68', 0.2000165487940565, nan)
# (u'topic_78', 0.20873870733569197, 0)
# (u'topic_73', 0.016464284227631271, 0)
# (u'topic_76', 0.053098679518561814, 0)
# Column combination_0 not optimized
# it = 72 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_28', 0.59765132570236312, 0)
# (u'topic_74', 0.37251287622187124, 0)
# (u'topic_34', 0.029835798075765699, 0)
# Column combination_0 not optimized
# it = 73 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_37', 0.35277471319889181, 0)
# (u'topic_15', 0.64722528680110825, 0)
# Column combination_0 not optimized
# it = 74 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_21', 0.20669667849370749, 0)
# (u'topic_36', 0.2202756220239224, 0)
# (u'topic_60', 0.17599967929579635, nan)
# (u'topic_90', 0.19636659154814823, 0)
# (u'topic_81', 0.20066142863842551, 0)
# Column combination_0 not optimized
# it = 75 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_31', 0.14599102327383787, 0)
# (u'topic_38', 0.11684729690374437, 0)
# (u'topic_7', 0.19631948229772023, 0)
# (u'topic_20', 0.26163147051495766, 0)
# (u'topic_89', 0.065810128107677807, 0)
# (u'topic_11', 0.21340059890206192, 0)
# Column combination_0 not optimized
# it = 76 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 20.0%
# (u'topic_71', 0.1084684085698599, nan)
# (u'topic_18', 0.33158208280569196, 0)
# (u'topic_28', 0.3280625618613901, 0)
# (u'topic_64', 0.096148912439933149, nan)
# (u'topic_13', 0.1357380343231249, 0)
# Column combination_0 not optimized
# it = 77 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_89', 0.039192861389051772, 0)
# (u'topic_86', 0.96080713861094824, 0)
# Column combination_0 not optimized
# it = 78 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_69', 0.18952312133252611, nan)
# (u'topic_15', 0.30569149356732461, 0)
# (u'topic_60', 0.23890612925160118, nan)
# (u'topic_2', 0.26587925584854816, 0)
# Column combination_0 not optimized
# it = 79 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_42', 0.45568719547758568, 0)
# (u'topic_35', 0.087605454151730669, 0)
# (u'topic_95', 0.18048071863668563, 0)
# (u'topic_21', 0.12255596884075787, 0)
# (u'topic_97', 0.15367066289324008, 0)
# Column combination_0 not optimized
# it = 80 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_46', 0.32431137050456593, 0)
# (u'topic_59', 0.35086306252801835, nan)
# (u'topic_19', 0.32482556696741566, 0)
# Column combination_0 not optimized
# it = 81 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 20.0%
# (u'topic_72', 0.25321074426393031, nan)
# (u'topic_2', 0.29945527459132482, 0)
# (u'topic_4', 0.22112189380141367, 0)
# (u'topic_41', 0.025173637304314118, 0)
# (u'topic_49', 0.20103845003901724, 0)
# Column combination_0 not optimized
# it = 82 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_4', 0.57674706455604996, 0)
# (u'topic_60', 0.42325293544394998, nan)
# Column combination_0 not optimized
# it = 83 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_96', 0.026218995947003231, 0)
# (u'topic_98', 0.97378100405299672, 0)
# Column combination_0 not optimized
# it = 84 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_71', 0.15468242859664899, nan)
# (u'topic_24', 0.33697400490224383, 0)
# (u'topic_18', 0.27139136422724824, 0)
# (u'topic_90', 0.13830529483796872, 0)
# (u'topic_45', 0.098646907435890177, 0)
# Column combination_0 not optimized
# it = 85 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_52', 0.28139190659303687, 0)
# (u'topic_12', 0.10126915827999146, 0)
# (u'topic_41', 0.28628406137982726, 0)
# (u'topic_38', 0.33105487374714437, 0)
# Column combination_0 not optimized
# it = 86 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_65', 0.20751987976605699, nan)
# (u'topic_94', 0.0063575431851106388, 0)
# (u'topic_18', 0.40743062645165057, 0)
# (u'topic_42', 0.26342206762186787, 0)
# (u'topic_78', 0.11526988297531414, 0)
# Column combination_0 not optimized
# it = 87 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_51', 0.029917240512640084, 0)
# (u'topic_85', 0.29011433362502431, 0)
# (u'topic_49', 0.25895553468983173, 0)
# (u'topic_63', 0.4113414789912338, nan)
# (u'topic_84', 0.0096714121812699165, 0)
# Column combination_0 not optimized
# it = 88 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_10', 0.32389189101605986, 0)
# (u'topic_96', 0.67610810898394014, 0)
# Column combination_0 not optimized
# it = 89 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_94', 0.49716465365464496, 0)
# (u'topic_45', 0.50283534634535509, 0)
# Column combination_0 not optimized
# it = 90 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_59', 0.57523343450796183, nan)
# (u'topic_91', 0.30020327166547883, 0)
# (u'topic_21', 0.12456329382655944, 0)
# Column combination_0 not optimized
# it = 91 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_2', 0.48072013820988713, 0)
# (u'topic_90', 0.51927986179011287, 0)
# Column combination_0 not optimized
# it = 92 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_71', 0.31203494838365231, nan)
# (u'topic_18', 0.33440092646896352, 0)
# (u'topic_68', 0.35356412514738422, nan)
# Column combination_0 not optimized
# it = 93 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_84', 0.22220639440806544, 0)
# (u'topic_47', 0.77779360559193456, 0)
# Column combination_0 not optimized
# it = 94 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 16.6666666667%
# (u'topic_61', 0.0041933912447337388, nan)
# (u'topic_68', 0.22435842825910479, nan)
# (u'topic_65', 0.23292135782227036, nan)
# (u'topic_10', 0.20647007635598461, 0)
# (u'topic_55', 0.12829595204013983, 0)
# (u'topic_99', 0.20376079427776678, 0)
# Column combination_0 not optimized
# it = 95 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_32', 0.30679825864450933, 0)
# (u'topic_99', 0.32744533634573442, 0)
# (u'topic_52', 0.20307767953953906, 0)
# (u'topic_78', 0.16267872547021722, 0)
# Column combination_0 not optimized
# it = 96 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 20.0%
# (u'topic_76', 0.23355304445862365, 0)
# (u'topic_92', 0.28356434695065375, 0)
# (u'topic_49', 0.20668915723178707, 0)
# (u'topic_45', 0.19783935353765775, 0)
# (u'topic_8', 0.078354097821277793, 0)
# Column combination_0 not optimized
# it = 97 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_24', 0.65468891225398329, 0)
# (u'topic_78', 0.34531108774601671, 0)
# Column combination_0 not optimized
# it = 98 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_81', 0.019537338779668938, 0)
# (u'topic_70', 0.9804626612203311, nan)
# Column combination_0 not optimized
# it = 99 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_45', 0.52436447207293335, 0)
# (u'topic_38', 0.47563552792706665, 0)
# Column combination_0 not optimized
# it = 100 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_56', 0.33906849164483205, 0)
# (u'topic_43', 0.66093150835516801, 0)
# total not_found_columns_count = 0.0%, matched_coeffs_count = 20.0833333333%
# =======================================================
# Processing distance fn = <function jaccard_dist at 0x000000000C457208>
# matched_columns = 4.0%, good_x_coefficient = 0.0%
# -------------------------------------------------------
# it = 1 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_66', 0.27824008354159385, 0.037210280978727313)
# (u'topic_60', 0.21646135336416203, 0.033072354009875425)
# (u'topic_16', 0.18965845625291292, 0.082422919070129219)
# (u'topic_19', 0.018107133853363769, 0)
# (u'topic_79', 0.29753297298796749, 0.039275536746311013)
# it = 2 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_96', 0.12606684640086391, 0.090422250357411693)
# (u'topic_93', 0.28943800943771419, 0.1027106865872468)
# (u'topic_21', 0.33710198659215185, 0.072547706531350689)
# (u'topic_25', 0.24739315756927013, 0.03837134433007184)
# it = 3 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_72', 0.34588719803140733, 0.027075492195100557)
# (u'topic_50', 0.65411280196859256, 0.058879153250993001)
# it = 4 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_74', 0.28460503277200266, 0.025710119040282208)
# (u'topic_56', 0.23129529474402197, 0.10085181744560515)
# (u'topic_17', 0.25791645977570671, 0.056908566753193578)
# (u'topic_6', 0.22121852879932402, 0.14664263505813696)
# (u'topic_31', 0.0049646839089445439, 0)
# it = 5 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_93', 0.2871004708323045, 0.039369250752714351)
# (u'topic_82', 0.13239612574577705, 0.1041323481170536)
# (u'topic_9', 0.2939209476636665, 0.052600657775172026)
# (u'topic_58', 0.15070554339337613, 0.092032532318019986)
# (u'topic_8', 0.13587691236487576, 0)
# it = 6 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_55', 0.63926090797702817, 0.090533979050430799)
# (u'topic_93', 0.36073909202297183, 0.10572386179270048)
# it = 7 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_47', 0.93239651899933995, 0.026732561415277911)
# (u'topic_55', 0.067603481000660021, 0)
# it = 8 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_53', 0.19575569569371093, 0)
# (u'topic_14', 0.01716288758719485, 0)
# (u'topic_37', 0.78708141671909426, 0.093752935085539155)
# it = 9 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 83.3333333333%
# (u'topic_9', 0.21686729886693143, 0.13957737433997613)
# (u'topic_60', 0.070030672714968031, 0)
# (u'topic_7', 0.082944175596141048, 0)
# (u'topic_53', 0.080140928116708934, 0)
# (u'topic_58', 0.33120530216651972, 0.090750340221506715)
# (u'topic_44', 0.21881162253873088, 0.079592341463165031)
# it = 10 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_1', 0.35614059116336566, 0.12265977366028294)
# (u'topic_68', 0.27091737384819808, 0.047318753692326382)
# (u'topic_99', 0.1991269015160575, 0.0014547697045173115)
# (u'topic_72', 0.17381513347237865, 0.020265468129801525)
# it = 11 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 75.0%
# (u'topic_89', 0.16820973912572471, 0.059524730548790497)
# (u'topic_72', 0.076203989886548959, 0)
# (u'topic_61', 0.18298028799805555, 0.092537316137391759)
# (u'topic_57', 0.5726059829896708, 0.12975868886741052)
# it = 12 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_7', 0.013660488273040127, 0)
# (u'topic_91', 0.054068130821292422, 0.037815226053907705)
# (u'topic_98', 0.048573701297751598, 0.089152829090802646)
# (u'topic_9', 0.23964818895169007, 0.068940533861044831)
# (u'topic_2', 0.28655490686208435, 0.063696496425181742)
# (u'topic_22', 0.35749458379414151, 0.01973408756605179)
# it = 13 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_15', 0.33510696591817635, 0.10627799852702438)
# (u'topic_55', 0.20291178675412538, 0.092173451644752435)
# (u'topic_38', 0.46198124732769824, 0.033603765638589397)
# it = 14 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_51', 0.13632226210526596, 0)
# (u'topic_3', 0.24430259990657396, 0.076979176203396782)
# (u'topic_26', 0.021643763322618977, 0)
# (u'topic_99', 0.25764588466372684, 0.085811008310121714)
# (u'topic_68', 0.34008549000181432, 0.059928155016088204)
# it = 15 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_88', 0.31104536090291235, 0.050253730662351621)
# (u'topic_47', 0.68895463909708754, 0.069170297769702835)
# it = 16 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_95', 0.72940750923163755, 0.12916726592856309)
# (u'topic_69', 0.2705924907683625, 0.068676684954119702)
# it = 17 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_27', 0.14772056367965758, 0.068217176288030215)
# (u'topic_50', 0.18751213602082956, 0.090217208068840662)
# (u'topic_42', 0.32766315430015641, 0.049174716675712896)
# (u'topic_30', 0.044528965261811118, 0)
# (u'topic_29', 0.29257518073754551, 0.11006790937118013)
# it = 18 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_10', 0.32890746728899045, 0.061231556349884843)
# (u'topic_4', 0.079574543424004773, 0.06034061757843779)
# (u'topic_63', 0.3049380200549186, 0.033283197317406581)
# (u'topic_43', 0.080471307854918447, 0)
# (u'topic_21', 0.20610866137716774, 0.11257575368137514)
# it = 19 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_69', 0.35251141146406917, 0.015375199208204586)
# (u'topic_80', 0.49437343209928164, 0.09691256302240378)
# (u'topic_30', 0.12192337440065822, 0)
# (u'topic_45', 0.031191782035991048, 0)
# it = 20 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_22', 0.1554572622769958, 0.058058475407741748)
# (u'topic_58', 0.1705686354901437, 0.064305679629598919)
# (u'topic_12', 0.21665239328140418, 0)
# (u'topic_0', 0.28526010757701487, 0.11136864120666438)
# (u'topic_62', 0.17206160137444129, 0.083630550717914059)
# it = 21 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 83.3333333333%
# (u'topic_6', 0.063205564273321149, 0)
# (u'topic_85', 0.13700430246271733, 0.010574828826355107)
# (u'topic_45', 0.1850518458427704, 0.091989394994495099)
# (u'topic_10', 0.2363787482961737, 0.087541444959091719)
# (u'topic_19', 0.15310765769842033, 0.11123195761357052)
# (u'topic_65', 0.22525188142659708, 0.050521715905008729)
# it = 22 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 83.3333333333%
# (u'topic_90', 0.070769581815447888, 0)
# (u'topic_3', 0.28514785760278638, 0.1480663264145228)
# (u'topic_21', 0.19456629081990001, 0.10655559006104298)
# (u'topic_43', 0.038798864247312839, 0)
# (u'topic_67', 0.35315807491340068, 0.03608139411715916)
# (u'topic_6', 0.057559330601152051, 0)
# it = 23 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_29', 0.05579280402379945, 0.056257498078532524)
# (u'topic_64', 0.023086965524576321, 0)
# (u'topic_32', 0.35560206816213769, 0.041539472234311717)
# (u'topic_60', 0.31009076070451619, 0.11418772641447657)
# (u'topic_19', 0.13188376812167679, 0.0088558721574421642)
# (u'topic_22', 0.12354363346329372, 0.025241451748476203)
# it = 24 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_40', 0.33313315671860755, 0.09234576506714097)
# (u'topic_82', 0.27810433205013474, 0.070813630700418781)
# (u'topic_61', 0.14469145797621311, 0.0067861058628324129)
# (u'topic_39', 0.24407105325504452, 0.022615844056715441)
# it = 25 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_99', 0.18638148500767049, 0.073994826460522634)
# (u'topic_36', 0.21035659167294421, 0.017839609677219988)
# (u'topic_38', 0.26924631214791844, 0.075884465235554768)
# (u'topic_63', 0.33401561117146694, 0.12633871998855231)
# it = 26 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_3', 0.23271245189629108, 0.11292416110167473)
# (u'topic_64', 0.41841758755322062, 0.070628630928442029)
# (u'topic_87', 0.34886996055048836, 0.027944210146583642)
# it = 27 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_71', 0.12951711207822694, 0)
# (u'topic_81', 0.38937578834282593, 0.1354497246139359)
# (u'topic_42', 0.29994219941249906, 0.018581050763997672)
# (u'topic_19', 0.039000593492790239, 0)
# (u'topic_7', 0.14216430667365787, 0.0047402854332696765)
# it = 28 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_43', 0.49311924122502038, 0.11425054757905827)
# (u'topic_65', 0.22700973537996524, 0.036195732687218422)
# (u'topic_84', 0.017959583759496633, 0)
# (u'topic_59', 0.26191143963551766, 0.079975906803603378)
# it = 29 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_78', 0.088189554705774775, 0.11417980432557455)
# (u'topic_59', 0.34485814266660753, 0.075340431017022799)
# (u'topic_53', 0.23890260066028998, 0.073590372090667211)
# (u'topic_34', 0.13591681468577221, 0)
# (u'topic_21', 0.1903516916499173, 0.12945222990223412)
# (u'topic_44', 0.0017811956316382137, 0.07521079343292715)
# it = 30 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_62', 0.61083684680062511, 0.028400013600135568)
# (u'topic_46', 0.38916315319937472, 0.010834771105586663)
# it = 31 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_72', 0.05104496291000081, 0)
# (u'topic_68', 0.18976775223607029, 0.055416851337667807)
# (u'topic_40', 0.11246563165080947, 0.087509887823838506)
# (u'topic_10', 0.32054599789459204, 0.099138159620566074)
# (u'topic_82', 0.098652632018094516, 0)
# (u'topic_12', 0.22752302329043295, 0.077248076645304864)
# it = 32 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_52', 0.39729396710256221, 0.077324523356092079)
# (u'topic_21', 0.055864683346222292, 0.024885684872496122)
# (u'topic_73', 0.40893206670315752, 0.02980663046582277)
# (u'topic_63', 0.099464064953935616, 0.072805636426758774)
# (u'topic_97', 0.038445217894122218, 0)
# it = 33 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_32', 0.46505833785828821, 0.10014807331625107)
# (u'topic_10', 0.53494166214171179, 0.089846505902897236)
# it = 34 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_94', 0.25220793696548932, 0.084275570761926613)
# (u'topic_57', 0.2348847145989291, 0.11596823058769001)
# (u'topic_37', 0.08496673619993507, 0.030380919609509931)
# (u'topic_76', 0.26607825745967639, 0.083638038517718574)
# (u'topic_82', 0.16186235477597016, 0.10702770854285724)
# it = 35 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_80', 0.77322988896257994, 0.015523927713241008)
# (u'topic_15', 0.22677011103741995, 0.056045517513117926)
# it = 36 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_35', 0.17270466150041824, 0)
# (u'topic_60', 0.30124895644457506, 0.0077499559798137399)
# (u'topic_77', 0.21393978306853859, 0.1820039930276281)
# (u'topic_55', 0.18083772285373811, 0.030860276097734587)
# (u'topic_45', 0.064088526514743199, 0)
# (u'topic_76', 0.067180349617986787, 0.051017634455138801)
# it = 37 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_78', 0.061957084873894126, 0)
# (u'topic_87', 0.084650031896212993, 0.051052359108421458)
# (u'topic_26', 0.22362940731434111, 0.039201893197279652)
# (u'topic_13', 0.26445177645638274, 0.034756978066237336)
# (u'topic_98', 0.10395225590705613, 0)
# (u'topic_39', 0.26135944355211288, 0.060554825789515244)
# it = 38 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_31', 0.24962755273346171, 0.064015139065025511)
# (u'topic_29', 0.1768192545031356, 0.0677855122139326)
# (u'topic_11', 0.14982824277384998, 0)
# (u'topic_60', 0.42372494998955273, 0.045130126076476991)
# it = 39 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 83.3333333333%
# (u'topic_84', 0.2315180561351988, 0.12229587053252827)
# (u'topic_59', 0.0013150511222405009, 0)
# (u'topic_83', 0.29360764636244624, 0.0079946161575082941)
# (u'topic_61', 0.143684315029625, 0.11432865123707447)
# (u'topic_95', 0.13064593276005934, 0.095429575039647274)
# (u'topic_29', 0.19922899859043003, 0.056405077346904059)
# it = 40 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_59', 0.37642962476704622, 0.083423604672449733)
# (u'topic_77', 0.0019966326033186961, 0)
# (u'topic_30', 0.072073665127983549, 0)
# (u'topic_65', 0.18075396515029071, 0.05512518512568336)
# (u'topic_49', 0.3687461123513609, 0.0061108674840645036)
# it = 41 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_86', 0.071899711013529211, 0.064652428383230792)
# (u'topic_73', 0.10325550719807952, 0.0096272213200826809)
# (u'topic_82', 0.82484478178839116, 0.093846110434701896)
# it = 42 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_13', 0.34838914776346724, 0.069560607089242138)
# (u'topic_99', 0.16157302035991347, 0.097159693196612176)
# (u'topic_83', 0.49003783187661931, 0.09719195005223813)
# it = 43 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_27', 0.91826552645373127, 0.063456607024492365)
# (u'topic_23', 0.081734473546268685, 0)
# it = 44 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_59', 0.50310121542338671, 0.075897077298181709)
# (u'topic_18', 0.38042030887724887, 0.10910953177384342)
# (u'topic_61', 0.11647847569936444, 0.11751806138888625)
# it = 45 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_53', 0.23283589333539753, 0.039459719140902669)
# (u'topic_18', 0.38850275195633671, 0.051519704491895892)
# (u'topic_54', 0.26930126835929358, 0.028874594747119692)
# (u'topic_40', 0.028818153504097038, 0)
# (u'topic_82', 0.080541932844875291, 0.029336294066171872)
# it = 46 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_0', 0.116898689158834, 0.0094335732418466198)
# (u'topic_86', 0.25304504735941363, 0.066814267190566518)
# (u'topic_38', 0.11392955903045021, 0.039438199459510589)
# (u'topic_80', 0.24957700404106981, 0.025880806120235595)
# (u'topic_26', 0.26654970041023229, 0.036582308751392123)
# it = 47 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_81', 0.010686379133288572, 0)
# (u'topic_24', 0.15076991933331843, 0.015949018390467012)
# (u'topic_31', 0.4059811943323548, 0.010900890551824092)
# (u'topic_35', 0.43256250720103817, 0.11275316176407399)
# it = 48 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_68', 0.0019046789194405089, 0)
# (u'topic_79', 0.95118376825715778, 0.001652627578876393)
# (u'topic_35', 0.046911552823401717, 0)
# it = 49 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_52', 0.38979905401505666, 0.11623803799803074)
# (u'topic_29', 0.1473421174658783, 0.0044289711913758729)
# (u'topic_22', 0.34967473257208059, 0.004558668856830453)
# (u'topic_84', 0.034844744912560642, 0.15239637661011751)
# (u'topic_43', 0.078339351034423813, 0)
# it = 50 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_58', 0.20856060296429915, 0.01630833576302651)
# (u'topic_24', 0.2070033658131904, 0.08072068351419516)
# (u'topic_37', 0.10096184766304549, 0.087895491150127805)
# (u'topic_56', 0.014237341566896796, 0)
# (u'topic_35', 0.22053465721370019, 0.00021984779426898049)
# (u'topic_74', 0.24870218477886796, 0.055240086022899253)
# it = 51 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_58', 0.78310111457497755, 0.11277526818230095)
# (u'topic_27', 0.0060768178438321656, 0)
# (u'topic_73', 0.21082206758119035, 0.084233199929700034)
# it = 52 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_13', 0.3192062819931929, 0)
# (u'topic_20', 0.68079371800680721, 0.12263790959528216)
# it = 53 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_98', 0.21831375262623262, 0.014546123781838758)
# (u'topic_29', 0.31635070346905925, 0.023513531055072458)
# (u'topic_25', 0.30089435894270977, 0.13804830159457873)
# (u'topic_92', 0.16444118496199836, 0.044453669344820729)
# it = 54 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_88', 0.21550881483257786, 0.10327291675962576)
# (u'topic_74', 0.59846503199502421, 0.10274483436398979)
# (u'topic_40', 0.1860261531723979, 0.01991158913715212)
# it = 55 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_99', 0.28475216846036933, 0.069491667628443485)
# (u'topic_0', 0.24429096898738908, 0.073403592789209021)
# (u'topic_42', 0.22176243753542932, 0.10971182421455723)
# (u'topic_60', 0.24919442501681224, 0.043418334931250788)
# it = 56 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_52', 0.28534073664372772, 0.087112701166196474)
# (u'topic_47', 0.35127553962223756, 0.016902067468278242)
# (u'topic_56', 0.35564812438142601, 0.13207223306304083)
# (u'topic_35', 0.0077355993526085891, 0)
# it = 57 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_66', 0.035639013049642461, 0)
# (u'topic_61', 0.12268919512896363, 0.083096863257168585)
# (u'topic_7', 0.00023285810306396967, 0.19289606005604226)
# (u'topic_0', 0.44279779190044, 0.086482412295449104)
# (u'topic_44', 0.39864114181789001, 0.012449340514357041)
# it = 58 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_12', 0.29715561376181393, 0.046363711475647468)
# (u'topic_22', 0.012340904027869663, 0.10074457835544803)
# (u'topic_27', 0.07243855060925776, 0.052804840388227567)
# (u'topic_25', 0.23064699771764036, 0.011389538214192274)
# (u'topic_57', 0.24038987481031523, 0.12446159701721084)
# (u'topic_78', 0.14702805907310287, 0.03289953501676568)
# it = 59 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 80.0%
# (u'topic_32', 0.036542745355791183, 0)
# (u'topic_5', 0.25201412458090017, 0.10217419794102837)
# (u'topic_74', 0.10855450642516942, 0.032025238184238719)
# (u'topic_43', 0.37394931905200768, 0.10236518637451747)
# (u'topic_42', 0.22893930458613163, 0.095204827043863391)
# it = 60 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_81', 0.34144116567881561, 0.072568504697683486)
# (u'topic_53', 0.25152151079959273, 0.086365915251989625)
# (u'topic_51', 0.036506191871193874, 0)
# (u'topic_8', 0.29058053163867958, 0.11917995480161164)
# (u'topic_80', 0.079561701051578337, 0.13688405325459699)
# (u'topic_40', 0.00038889896013997847, 0)
# it = 61 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_7', 0.10356863309618716, 0.093852360353759823)
# (u'topic_39', 0.27144645705240333, 0.036473643943917819)
# (u'topic_65', 0.12020383660034767, 0.042727221419786569)
# (u'topic_8', 0.053195250085154272, 0)
# (u'topic_73', 0.194878688336866, 0.021738330905681641)
# (u'topic_72', 0.25670713482904156, 0.06911005953676716)
# it = 62 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_96', 0.29614008227771571, 0.089610483428126428)
# (u'topic_76', 0.060893904203566572, 0.10628199583657329)
# (u'topic_45', 0.044129284791180029, 0.095414308369339743)
# (u'topic_20', 0.15079302189735183, 0.11322285940284851)
# (u'topic_21', 0.14850876829473891, 0.060089027980440773)
# (u'topic_39', 0.29953493853544705, 0.0015608865023606993)
# it = 63 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_65', 0.20995042347167808, 0.0096915392519911128)
# (u'topic_58', 0.26138305934838402, 0.082630229598944019)
# (u'topic_85', 0.52866651717993796, 0.092523286028364446)
# it = 64 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_14', 0.16760385200844374, 0.12672892582416817)
# (u'topic_53', 0.35372949970355722, 0.022472539987996334)
# (u'topic_8', 0.47866664828799899, 0.088092725792434545)
# it = 65 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_69', 0.1186186613491625, 0.059273576568039978)
# (u'topic_98', 0.23501486375500036, 0.066090132640943669)
# (u'topic_90', 0.27185264823454774, 0.12192987969638559)
# (u'topic_45', 0.074923242347795335, 0)
# (u'topic_14', 0.18831409387397802, 0.025809271524200213)
# (u'topic_16', 0.11127649043951592, 0)
# it = 66 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_60', 0.56163956006071092, 0.097205147879770235)
# (u'topic_24', 0.43836043993928919, 0.1328440723651651)
# it = 67 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_92', 0.062515921942492253, 0)
# (u'topic_71', 0.28538703981225511, 0.020380747118614779)
# (u'topic_23', 0.35796537229540609, 0.060246059763675308)
# (u'topic_82', 0.29413166594984658, 0.084582769301224631)
# it = 68 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_50', 0.18064090955379339, 0.0026466754804193647)
# (u'topic_84', 0.32132801304236214, 0.070121757681095173)
# (u'topic_6', 0.39085038824442936, 0.067166599686241751)
# (u'topic_74', 0.027088350751430602, 0)
# (u'topic_49', 0.064154442544462439, 0)
# (u'topic_86', 0.015937895863522063, 0)
# it = 69 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_34', 0.2373012659580066, 0.024287719155050777)
# (u'topic_65', 0.22562230318511317, 0.077320592404826097)
# (u'topic_15', 0.094852127321586543, 0.026097042317233265)
# (u'topic_74', 0.075656419281375911, 0)
# (u'topic_43', 0.22981054376515783, 0.0060454014809580101)
# (u'topic_45', 0.13675734048875998, 0.088832566771649205)
# it = 70 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_19', 0.094132751717420929, 0)
# (u'topic_49', 0.83053258202163349, 0.046420914259541465)
# (u'topic_35', 0.075334666260945565, 0)
# it = 71 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_67', 0.05500181836525294, 0)
# (u'topic_39', 0.002817615314275804, 0.052781351973046543)
# (u'topic_88', 0.4143864928084397, 0.040886425085372428)
# (u'topic_35', 0.52779407351203156, 0.0085662797168222591)
# it = 72 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_90', 0.21218409465150101, 0.060840522872480041)
# (u'topic_53', 0.67437337199189262, 0.065533052702751157)
# (u'topic_86', 0.11344253335660633, 0.086873404987350508)
# it = 73 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_51', 0.18706922953617017, 0.046351303789226445)
# (u'topic_18', 0.11555091569886175, 0.030889115397149006)
# (u'topic_66', 0.24993859801817725, 0.0050489929056483111)
# (u'topic_57', 0.078706221242418703, 0.12412082104070352)
# (u'topic_65', 0.090504460729753849, 0.054120596648292219)
# (u'topic_49', 0.27823057477461816, 0.029182545841826477)
# it = 74 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_59', 0.40987634458587247, 0.047357997826966813)
# (u'topic_48', 0.18030928178111622, 0.12933596380627327)
# (u'topic_64', 0.40981437363301132, 0.1051044061810287)
# it = 75 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_94', 0.38072141710061991, 0.047759814262169242)
# (u'topic_9', 0.31282876194777914, 0.12738301643659466)
# (u'topic_72', 0.0085735122447018579, 0)
# (u'topic_95', 0.29787630870689896, 0.067820388445714599)
# it = 76 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_88', 0.24491055534739375, 0.044661028151086524)
# (u'topic_73', 0.29724672638220206, 0.072919633148266161)
# (u'topic_7', 0.068607228061370915, 0.05108694669900541)
# (u'topic_91', 0.14015990978065057, 0.053256781028020062)
# (u'topic_38', 0.24907558042838282, 0.063020951753660903)
# it = 77 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_99', 0.33576370218619833, 0.025435614787191974)
# (u'topic_18', 0.13754804972574758, 0)
# (u'topic_5', 0.19816636359639636, 0.10514016384813651)
# (u'topic_52', 0.25917495488453729, 0.050031590945413131)
# (u'topic_41', 0.069346929607120494, 0)
# it = 78 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_52', 0.18309168704334228, 0.11646865939890418)
# (u'topic_58', 0.0090869297572811064, 0)
# (u'topic_20', 0.25024242420045717, 0.066404864952348347)
# (u'topic_96', 0.2922181055411231, 0.014078339678295259)
# (u'topic_36', 0.26536085345779642, 0.10820063962527919)
# it = 79 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_29', 0.079909484980816306, 0.0054190770909337497)
# (u'topic_35', 0.56091879574898418, 0.14460993669952332)
# (u'topic_37', 0.24852022336504376, 0.076021138773838884)
# (u'topic_12', 0.11065149590515579, 0)
# it = 80 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 75.0%
# (u'topic_40', 0.57818163508303222, 0.022567555576006881)
# (u'topic_76', 0.21943117976280771, 0.12855801836307398)
# (u'topic_85', 0.1900786020465817, 0.12253430404369733)
# (u'topic_6', 0.012308583107578507, 0)
# it = 81 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_15', 0.25643653892136264, 0.1059397276964264)
# (u'topic_74', 0.29923209998000128, 0.036843626224453155)
# (u'topic_82', 0.21458193053804625, 0.091808933864827566)
# (u'topic_52', 0.22974943056059, 0.046327695456032207)
# it = 82 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_81', 0.42631752936590178, 0.0057815746724468693)
# (u'topic_9', 0.57368247063409816, 0.045770067240761034)
# it = 83 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_78', 0.080588481938554946, 0.067561124719519139)
# (u'topic_72', 0.13423557906003908, 0.056950465486327623)
# (u'topic_75', 0.26464686421884265, 0.10776330512735467)
# (u'topic_22', 0.15250512823011381, 0.051359559679637276)
# (u'topic_47', 0.095816601661804501, 0)
# (u'topic_32', 0.27220734489064513, 0.062935103158182973)
# it = 84 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 83.3333333333%
# (u'topic_24', 0.021586572544254137, 0)
# (u'topic_41', 0.2360521922575555, 0.098401386076332018)
# (u'topic_39', 0.18818622640730759, 0.11638654983467049)
# (u'topic_70', 0.21421593702922784, 0.076729284370994494)
# (u'topic_98', 0.0060345727359835573, 0)
# (u'topic_57', 0.33392449902567151, 0.013990399878283875)
# it = 85 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_25', 0.32124823660383728, 0.058104004300880988)
# (u'topic_14', 0.23081838829277895, 0.01435158301207067)
# (u'topic_69', 0.12285243357479728, 0.13061260210955519)
# (u'topic_68', 0.014905046158920117, 0)
# (u'topic_33', 0.31017589536966639, 0.041596319914745897)
# it = 86 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_49', 0.21739572144369557, 0.0531148504368152)
# (u'topic_61', 0.15733770701161684, 0.031449266913508758)
# (u'topic_86', 0.019413449724000751, 0)
# (u'topic_24', 0.20365754842383532, 0.071898557948651798)
# (u'topic_89', 0.26853085482505368, 0.044382660983500799)
# (u'topic_87', 0.13366471857179787, 0.10924428251482377)
# it = 87 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_93', 0.22342770108032239, 0.00049095159333312286)
# (u'topic_32', 0.25347003912325772, 0.077472455363948076)
# (u'topic_56', 0.2717930382788592, 0.11314301218812202)
# (u'topic_96', 0.14234575788657833, 0.097488128928129858)
# (u'topic_12', 0.072931014550452894, 0)
# (u'topic_20', 0.036032449080529279, 0)
# it = 88 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 66.6666666667%
# (u'topic_74', 0.085393810570790749, 0.041102145755588564)
# (u'topic_40', 0.10517126191941409, 0.1140512931379941)
# (u'topic_44', 0.25188825957103389, 0.059637775855679837)
# (u'topic_61', 0.039514307851547012, 0)
# (u'topic_89', 0.20531383271112849, 0.075945203212788276)
# (u'topic_1', 0.3127185273760858, 0.041118965747400316)
# it = 89 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_94', 0.88520362066159841, 0.080142830969448312)
# (u'topic_89', 0.11479637933840157, 0)
# it = 90 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_75', 0.3719700044508798, 0.12073906423783663)
# (u'topic_32', 0.38161641561268983, 0.00043992763524344341)
# (u'topic_45', 0.24641357993643032, 0.10559291539950283)
# it = 91 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 40.0%
# (u'topic_98', 0.25323883362861122, 0.099118997670248801)
# (u'topic_12', 0.16942453795472551, 0)
# (u'topic_29', 0.42200390673946059, 0.04240481147746307)
# (u'topic_20', 0.027212805172238619, 0)
# (u'topic_59', 0.12811991650496407, 0.03681105452952043)
# it = 92 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_65', 0.23553662893410052, 0.08268018801925954)
# (u'topic_79', 0.21007709874707126, 0.0010155481398383989)
# (u'topic_10', 0.25026478114982126, 0.12656967667231245)
# (u'topic_49', 0.30412149116900689, 0.034123266713114955)
# it = 93 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 83.3333333333%
# (u'topic_96', 0.17752000616158237, 0.031357579125150969)
# (u'topic_84', 0.077463953367079702, 0.1001669742733248)
# (u'topic_1', 0.067579176086114967, 0)
# (u'topic_46', 0.16099223782221705, 0.099890881003263904)
# (u'topic_36', 0.28599257346151691, 0.013442157231120454)
# (u'topic_29', 0.23045205310148892, 0.086703994456631475)
# it = 94 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 0.0%
# (u'topic_2', 0.8288165848795408, 0.04704340761938991)
# (u'topic_92', 0.17118341512045918, 0)
# it = 95 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_86', 0.01443892982715992, 0)
# (u'topic_89', 0.44701958761293648, 0.091594353082441848)
# (u'topic_80', 0.036609942846234353, 0.047466246320139925)
# (u'topic_32', 0.4492805431459842, 0.07522932276945514)
# (u'topic_53', 0.05265099656768514, 0)
# it = 96 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 50.0%
# (u'topic_7', 0.31390182661386412, 0.11505665309457314)
# (u'topic_16', 0.3274771143378693, 0.0316541042299055)
# (u'topic_10', 0.21478312731312002, 0.10210235959701203)
# (u'topic_81', 0.14383793173514656, 0.060959027540635813)
# it = 97 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 33.3333333333%
# (u'topic_5', 0.080944377429110023, 0)
# (u'topic_41', 0.337401622621959, 0.032329436247469506)
# (u'topic_63', 0.58165399994893108, 0.097273786942168539)
# it = 98 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 83.3333333333%
# (u'topic_34', 0.28507756444749438, 0.071561823627417795)
# (u'topic_60', 0.1171782997280074, 0)
# (u'topic_12', 0.078146073297121338, 0)
# (u'topic_79', 0.066186217713819717, 0.0003592421743652209)
# (u'topic_44', 0.20036366267588873, 0.063541766356315782)
# (u'topic_74', 0.25304818213766833, 0.11116813104972814)
# it = 99 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 60.0%
# (u'topic_21', 0.081839082066645655, 0.056109152474414163)
# (u'topic_69', 0.35388240085228356, 0.050432354281853629)
# (u'topic_44', 0.2243932496909701, 0.049816789108602863)
# (u'topic_82', 0.22262710523632837, 0.090962484231782076)
# (u'topic_11', 0.11725816215377233, 0)
# it = 100 / 100 not_found_columns_count = 0.0%, matched_coeffs_count = 25.0%
# (u'topic_65', 0.25391743142280049, 0.0085000792468503065)
# (u'topic_73', 0.29469627487097799, 0.10445443459502997)
# (u'topic_83', 0.23751236835331674, 0.063220511241248556)
# (u'topic_38', 0.2138739253529047, 0.1120181310130723)
# total not_found_columns_count = 0.0%, matched_coeffs_count = 44.8666666667%
# =======================================================
# Processing distance fn = <function cos_dist at 0x000000000C457358>
# matched_columns = 100.0%, good_x_coefficient = 100.0%
# -------------------------------------------------------
# total not_found_columns_count = 0.0%, matched_coeffs_count = 100.0%
# =======================================================
