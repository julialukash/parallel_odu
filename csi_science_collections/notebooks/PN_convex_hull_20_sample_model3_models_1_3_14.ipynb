# %%
import pickle
import sys
import numpy as np
import pandas as pd
import artm
import seaborn as sns
import matplotlib.pyplot as plt
print artm.version()

from os import path, mkdir
from datetime import datetime
sys.path.insert(0, '..\\modules\\helpers')
import distances_helper as dh 
from plot_helper import PlotMaker
from config_helper import ConfigPaths
from print_helper import PrintHelper
from sklearn.decomposition import PCA
from scipy.spatial import ConvexHull
from scipy.optimize import minimize
from sklearn.metrics.pairwise import cosine_distances
from numpy.linalg import norm as euclidean_norm
# Out:
# 0.8.1

# %%
config = ConfigPaths('config_sample_m3.cfg')
print config.models_file_name
models_file = open(config.models_file_name, 'a')

plot_maker = PlotMaker()
printer = PrintHelper()
# Out:
# Q:\\topic_modeling\\csi_science_collections.git\experiments\pn_model3\np_25_01_m3_convex\models.txt

# %%
def create_model(current_dictionary, n_topics, n_doc_passes, seed_value, n_top_tokens, p_mass_threshold, _debug_print=False):    
    if _debug_print:
        print '[{}] creating model'.format(datetime.now())
    model = artm.ARTM(num_topics=n_topics, dictionary=current_dictionary, cache_theta=True, seed=seed_value, 
                  class_ids={'@default_class': 1.0})
    model.num_document_passes = n_doc_passes
    add_scores_to_model(model, n_top_tokens=n_top_tokens, p_mass_threshold=p_mass_threshold)
    return model
def add_scores_to_model(artm_model, n_top_tokens, p_mass_threshold, _debug_print=False):
    if _debug_print:
        print '[{}] adding scores'.format(datetime.now())
    artm_model.scores.add(artm.PerplexityScore(name='perplexity_score',
                                      dictionary=dictionary))
    artm_model.scores.add(artm.SparsityPhiScore(name='ss_phi_score', class_id='@default_class'))
    artm_model.scores.add(artm.SparsityThetaScore(name='ss_theta_score'))
    artm_model.scores.add(artm.TopicKernelScore(name='topic_kernel_score', class_id='@default_class', 
                                                probability_mass_threshold=p_mass_threshold))
    artm_model.scores.add(artm.TopTokensScore(name='top_tokens_score', class_id='@default_class', num_tokens=n_top_tokens))
def fit_one_model(model, _n_iterations, _model_name='', _debug_print=False): 
    if _debug_print:
        print '[{}] fitting'.format(datetime.now())
    model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=_n_iterations)
    if _debug_print:
        print '[{}] outputting'.format(datetime.now())
    printer.print_artm_model(model, _model_name, _n_iterations, output_file=models_file)
    model_pics_file_name =  path.join(config.experiment_path, _model_name)
    plot_maker.make_tm_plots(model, model_pics_file_name)
    model_output_file_name = path.join(config.experiment_path, _model_name + '.txt')
    printer.print_scores(model, _model_name, _n_iterations, model_output_file_name)
    printer.print_top_tokens(model, model_output_file_name)
    return model
def save_pickle_file(dists, filename):
    pickle_filename = path.join(config.experiment_path, filename)
    pickle_file = open(pickle_filename, 'wb')
    pickle.dump(dists, pickle_file)
    pickle_file.close()
def save_model_pickle(_model_name, _model, _save=True):
    phi = _model.get_phi()
    phi = phi[(phi.T != 0).any()]
    theta = _model.get_theta()    
    saved_top_tokens = _model.score_tracker['top_tokens_score'].last_tokens
    if _save:
        save_pickle_file(phi, 'phi_{}.p'.format(_model_name))
        save_pickle_file(theta, 'theta_{}.p'.format(_model_name))
        save_pickle_file(saved_top_tokens, 'saved_top_tokens_{}.p'.format(_model_name))
    return phi, theta, saved_top_tokens
def load_pickle_file(filename, _path=config.experiment_path):
    pickle_filename = path.join(_path, filename)
    pickle_file = open(pickle_filename, 'rb')
    p_file = pickle.load(pickle_file)
    pickle_file.close()
    return p_file
def load_model_pickle(_model_name, _distance_name=None, _path=config.experiment_path):
    phi = load_pickle_file('phi_{}.p'.format(_model_name), _path)
    theta = load_pickle_file('theta_{}.p'.format(_model_name), _path)
    saved_top_tokens = load_pickle_file('saved_top_tokens_{}.p'.format(_model_name), _path)
    distances = None
    if _distance_name is not None:
        distances = load_pickle_file('{}.p'.format(_distance_name), _path)
    return phi, theta, saved_top_tokens, distances

# %%
batch_vectorizer = artm.BatchVectorizer(data_path=config.output_batches_path,
                                        data_format='batches')
dictionary = artm.Dictionary()
dictionary.load(dictionary_path=config.dictionary_path + '.dict')

# %%
def calculate_distances(dist_fun, _phi, _phi_other, _debug_print=False):
    if _debug_print:
        print '[{}] take_distances between {} columns and {} columns'.format(datetime.now(), len(_phi.columns), len(_phi_other.columns))
    distances = pd.DataFrame(0, index = _phi.columns, columns=_phi_other.columns)
    for idx, col in enumerate(_phi.columns):
        if _debug_print and idx % 20 == 0:
            print '[{}] column {} / {}'.format(datetime.now(), idx, len(_phi.columns))
        for idx_other, col_other in enumerate(_phi_other.columns):
            distance = dist_fun(_phi[col], _phi_other[col_other])
            distances.iloc[idx, idx_other] = distance
    return distances
def get_optimization_result_one_matrix(dist_fn, jac_dist_fn, phi, distances, _debug_print=False):
    opt_results = {}
    for col_idx, col_name in enumerate(phi.columns):
        if _debug_print and col_idx % 20 == 0:
            print '[{}] get_optimization_result for column {} / {}'.format(datetime.now(), col_idx, len(phi.columns))
        column = phi[col_name]
        # delete col from phi
        phi_cut = phi.drop(col_name, axis=1)
        opt_results[col_name] = solve_optimization_problem(dist_fn, jac_dist_fn, column, col_name, phi_cut, distances)
    return opt_results
def get_optimization_result(dist_fn, jac_dist_fn, phi, phi_other, distances):
    opt_results = {}
    for col_idx, col_name in enumerate(phi.columns):
        if _debug_print and col_idx % 20 == 0:
            print '[{}] get_optimization_result for column {} / {}'.format(datetime.now(), col_idx, len(phi.columns))        
        column = phi[col_name]
        opt_results[col_name] = solve_optimization_problem(dist_fn, jac_dist_fn, column, col_name, phi_other, distances)
    return opt_results
def solve_optimization_problem(dist_fn, jac_dist_fn, column, column_name, phi, distances, verbose=False):
    max_iter = 50
    phi_columns = phi.columns
    # cut distances by phi columns 
    cut_distances = distances[phi_columns]
    # get n closest topics
    closest_column_names = cut_distances.loc[column_name].sort_values().head(N_CLOSEST_TOPICS).index.values
    phi_closest = phi[closest_column_names]
    
    # opt solver
    n_columns = phi_closest.shape[1] 
    bnds = [(0, 1)] * n_columns
    constraints = cons = ({'type': 'eq', 'fun': lambda x:  np.sum(x) - 1, 'jac': lambda x: [1] * n_columns})
    opt_fun = lambda x: dist_fn(column, phi_closest.dot(x))
    jac_fun = lambda x: jac_dist_fn(column, phi_closest, x)
    
    is_optimized = False
    it = 0
    while (not is_optimized) and it != 4:
        it += 1
        init_x = np.random.uniform(0, 1, (1, n_columns))
        init_x /= np.sum(init_x)
        if jac_dist_fn is not None:
            res = minimize(opt_fun, jac=jac_fun, x0=init_x, method='SLSQP', bounds=bnds, constraints=cons, options={'maxiter': max_iter, 'disp': verbose})
        else:
            res = minimize(opt_fun, x0=init_x, method='SLSQP', bounds=bnds, constraints=cons, options={'maxiter': max_iter, 'disp': verbose})
        is_optimized = res.success
    if not is_optimized:
        print 'Not optimized'         
    res['column_names'] = phi_closest.columns
    res['optimized_column'] = column_name
    res['projection'] = phi_closest.dot(res.x)
    res['column'] = column
    return res

# %% [markdown]
# Загрузим оригинальный sample датасет (от model3), до этого скопировав в папку с batches нужные pickle файлы модели.
# Сначала провизуалируем по одной итерации каждой новой модели, а потом будем итерационно строить выпуклую оболочку для каждой модели по отдельности и затем сравнивать их.

# %%
phi_original, theta_original, saved_top_tokens_original, distances_hellinger_model_original = load_model_pickle('model3', 'distances_hellinger_model3', config.output_batches_path)
print phi_original.shape, theta_original.shape
# Out:
# (2216, 100) (100, 3446)

# %% [markdown]
# Запустить несколько раз с разным рандомом. Следить за тем, чтобы накапливались только независимые темы. Каждый раз смотреть. как проектируется на оригинальную матрицу.

# %%
N_CLOSEST_TOPICS = 10
def create_model_fn_1(n_iteration):
    tmp_model = create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                             n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model = fit_one_model(tmp_model, _n_iterations=20, _model_name='model_20_m1_iter_{}'.format(n_iteration))
    return tmp_model
def filter_convex_hull(phi_convex_hull, get_topics_to_remove_fn, max_iteration=5):
    distances_model_iter = calculate_distances(dh.hellinger_dist, phi_convex_hull, phi_convex_hull)
    iterations_info = []
    for n_iteration in range(max_iteration):
        print('[{}] iteration = {} / {}'.format(datetime.now(), n_iteration, max_iteration))
        # get new opts results
        opt_res_convex_hull_inter = get_optimization_result_one_matrix(dh.hellinger_dist, None, 
                                                                       phi_convex_hull, distances_model_iter)
        # get topics to remove
        topics_to_remove, not_removed_topics_count = get_topics_to_remove_fn(opt_res_convex_hull_inter, distances_model_iter)
        # update phi convex
        phi_convex_hull = remove_topics_from_phi(phi_convex_hull, topics_to_remove)
        distances_model_iter = remove_topics_from_distances_xy(distances_model_iter, topics_to_remove)
        iterations_info.append({'it': n_iteration,
                                'n_topics_to_remove': len(topics_to_remove),
                                'phi_convex_hull_shape': phi_convex_hull.shape,
                                'removed_topics': topics_to_remove,
                                'not_removed_topics_count': not_removed_topics_count,
                                'phi_convex_hull': phi_convex_hull, 
                                'opt_res': opt_res_convex_hull_inter})
        print('[{}] {} topics to remove, {} not_removed_topics_count because close topics, current convex_hull shape = {}'.format(datetime.now(), 
               iterations_info[-1]['n_topics_to_remove'], not_removed_topics_count, iterations_info[-1]['phi_convex_hull_shape']))
        if len(iterations_info) > 3 and iterations_info[-1]['n_topics_to_remove'] == 0 and iterations_info[-2]['n_topics_to_remove'] == 0:
            print('[{}] topics to remove not increasing, breaking the for loop'.format(datetime.now()))
            break
    return phi_convex_hull, iterations_info
def build_convex_hull(create_model_fn, get_topics_to_remove_fn, words,
                      init_convex_hull, start_iteration, max_iteration):
    # init phi of convex hull
    phi_convex_hull = init_convex_hull
    if len(phi_convex_hull) == 0:
        phi_convex_hull = pd.DataFrame(0, index = words, columns=[])
    iterations_info = []
    for n_iteration in range(start_iteration, start_iteration + max_iteration):
        print('[{}] iteration = {} / {}'.format(datetime.now(), n_iteration, start_iteration + max_iteration))
        # build model
        model = create_model_fn(n_iteration)
        phi = model.get_phi()
        # rename phi columns 
        phi.columns = [c + '_{}'.format(n_iteration) for c in phi.columns]
        # add to convex hull
        phi_convex_hull_expanded = pd.concat([phi_convex_hull, phi], axis=1)
        # get new opts results
        distances_model_iter = calculate_distances(dh.hellinger_dist, phi_convex_hull_expanded, phi_convex_hull_expanded)
        opt_res_convex_hull_inter = get_optimization_result_one_matrix(dh.hellinger_dist, None, 
                                                                       phi_convex_hull_expanded, distances_model_iter)
        # get topics to remove
        topics_to_remove, not_removed_topics_count = get_topics_to_remove_fn(opt_res_convex_hull_inter, distances_model_iter)
        # update phi convex
        phi_convex_hull = remove_topics_from_phi(phi_convex_hull_expanded, topics_to_remove)
        iterations_info.append({'it': n_iteration,
                                'n_topics_to_remove': len(topics_to_remove),
                                'phi_convex_hull_shape': phi_convex_hull.shape,
                                'removed_topics': topics_to_remove,
                                'not_removed_topics_count': not_removed_topics_count,
                                'phi_convex_hull': phi_convex_hull, 
                                'opt_res': opt_res_convex_hull_inter})
        print('[{}] {} topics to remove, {} not_removed_topics_count because close topics, current convex_hull shape = {}'.format(datetime.now(), 
               iterations_info[-1]['n_topics_to_remove'], 
               iterations_info[-1]['not_removed_topics_count'],
               iterations_info[-1]['phi_convex_hull_shape']))
    return phi_convex_hull, iterations_info
def build_convex_hull_2(create_model_fn, get_topics_to_remove_fn, words,
                      init_convex_hull, start_iteration, max_iteration):
    # init phi of convex hull
    phi_convex_hull = init_convex_hull
    if len(phi_convex_hull) == 0:
        phi_convex_hull = pd.DataFrame(0, index = words, columns=[])
    iterations_info = []
    for n_iteration in range(start_iteration, start_iteration + max_iteration):
        print('[{}] iteration = {} / {}'.format(datetime.now(), n_iteration, start_iteration + max_iteration))
        # build model
        model = create_model_fn(n_iteration)
        phi = model.get_phi()
        # rename phi columns 
        phi.columns = [c + '_{}'.format(n_iteration) for c in phi.columns]
        # add to convex hull
        phi_convex_hull_expanded = pd.concat([phi_convex_hull, phi], axis=1)
        # filter topics 
        phi_convex_hull, iterations_info_filter = filter_convex_hull(phi_convex_hull_expanded, get_topics_to_remove_fn,
                                                                     max_iteration=15)
        iterations_info.append({'it': n_iteration,
                                'n_topics_to_remove': len(topics_to_remove),
                                'phi_convex_hull_shape': phi_convex_hull.shape,
                                'removed_topics': topics_to_remove,
                                'not_removed_topics_count': not_removed_topics_count,
                                'iterations_info_filter': iterations_info_filter,
                                'phi_convex_hull': phi_convex_hull, 
                                'opt_res': opt_res_convex_hull_inter})
        print('[{}] {} topics to remove, {} not_removed_topics_count because close topics, current convex_hull shape = {}'.format(datetime.now(), 
               iterations_info[-1]['n_topics_to_remove'], 
               iterations_info[-1]['not_removed_topics_count'],
               iterations_info[-1]['phi_convex_hull_shape']))
    return phi_convex_hull, iterations_info
def get_topics_to_remove_by_opt_fun_and_distance(opt_res, distances, n_closest=N_CLOSEST_TOPICS):
    small_dist_opts = {k:i for k, i in opt_res.iteritems() if i['fun'] < OPT_FUN_THRESHOLD}
    sorted_by_fun = sorted(small_dist_opts.values(), key = lambda opt: opt['fun'])
    topics_to_remove = []
    not_removed_count = 0 
    for opt_res in sorted_by_fun:
        topic_name = opt_res.optimized_column
        # check not close to current topics to remove
        is_close_fn = lambda topic, other_topic: other_topic in distances[topic].sort_values().head(n_closest).index
        is_close_to_topics_to_remove = [is_close_fn(topic_name, t) for t in topics_to_remove]
        is_close_to_topics_to_remove = True in is_close_to_topics_to_remove 
        if not is_close_to_topics_to_remove:
            topics_to_remove.append(topic_name)
        else:
            not_removed_count += 1 
    return topics_to_remove, not_removed_count
def get_topics_to_remove_by_opt_fun(opt_res, distances, n_closest=N_CLOSEST_TOPICS):
    small_dist_opts = {k:i for k, i in opt_res.iteritems() if i['fun'] < OPT_FUN_THRESHOLD}
    topics_to_remove = [x['optimized_column'] for x in small_dist_opts.values()]
    not_removed_count = 0
    return topics_to_remove, not_removed_count
def remove_topics_from_phi(phi, topics_to_remove):
    return phi.drop(topics_to_remove, axis=1)
def remove_topics_from_distances_x(distances, topics_to_remove):
    distances_convex_hull = distances.drop(topics_to_remove, axis=0)
    return distances_convex_hull
def remove_topics_from_distances_xy(distances, topics_to_remove):
    distances_convex_hull = distances.drop(topics_to_remove, axis=1)
    distances_convex_hull = distances_convex_hull.drop(topics_to_remove, axis=0)
    return distances_convex_hull

# %%
OPT_FUN_THRESHOLD = 0.6
phi_convex_hull, iterations_info = build_convex_hull(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)
# Out:
# [2017-01-29 22:56:49.729000] iteration = 0 / 50
# name = model_20_m1_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 22:57:19.783000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-01-29 22:57:19.783000] iteration = 1 / 50
# name = model_20_m1_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 22:57:56.480000] 36 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 4)
# [2017-01-29 22:57:56.481000] iteration = 2 / 50
# name = model_20_m1_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 22:58:28.715000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 23)
# [2017-01-29 22:58:28.715000] iteration = 3 / 50
# name = model_20_m1_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 22:59:06.773000] 41 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 2)
# [2017-01-29 22:59:06.774000] iteration = 4 / 50
# name = model_20_m1_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 22:59:43.389000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 22)
# [2017-01-29 22:59:43.390000] iteration = 5 / 50
# name = model_20_m1_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:00:23.532000] 37 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 5)
# [2017-01-29 23:00:23.532000] iteration = 6 / 50
# name = model_20_m1_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:01:05.860000] 3 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 22)
# [2017-01-29 23:01:05.860000] iteration = 7 / 50
# name = model_20_m1_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:01:50.539000] 37 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 5)
# [2017-01-29 23:01:50.539000] iteration = 8 / 50
# name = model_20_m1_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:02:31.928000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 23)
# [2017-01-29 23:02:31.928000] iteration = 9 / 50
# name = model_20_m1_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:03:13.766000] 38 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 5)
# [2017-01-29 23:03:13.766000] iteration = 10 / 50
# name = model_20_m1_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:03:53.464000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 25)
# [2017-01-29 23:03:53.464000] iteration = 11 / 50
# name = model_20_m1_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:04:33.526000] 38 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 7)
# [2017-01-29 23:04:33.526000] iteration = 12 / 50
# name = model_20_m1_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:05:08.258000] 3 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 24)
# [2017-01-29 23:05:08.258000] iteration = 13 / 50
# name = model_20_m1_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:05:47.123000] 40 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 4)
# [2017-01-29 23:05:47.123000] iteration = 14 / 50
# name = model_20_m1_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:06:25.762000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 22)
# [2017-01-29 23:06:25.763000] iteration = 15 / 50
# name = model_20_m1_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:07:06.727000] 33 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 9)
# [2017-01-29 23:07:06.727000] iteration = 16 / 50
# name = model_20_m1_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:07:43.450000] 11 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 18)
# [2017-01-29 23:07:43.450000] iteration = 17 / 50
# name = model_20_m1_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:08:24.905000] 30 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 8)
# [2017-01-29 23:08:24.905000] iteration = 18 / 50
# name = model_20_m1_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:09:01.646000] 7 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 21)
# [2017-01-29 23:09:01.646000] iteration = 19 / 50
# name = model_20_m1_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# Not optimized
# [2017-01-29 23:09:45.434000] 35 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 6)
# [2017-01-29 23:09:45.434000] iteration = 20 / 50
# name = model_20_m1_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:10:30.946000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-01-29 23:10:30.946000] iteration = 21 / 50
# name = model_20_m1_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:11:15.741000] 31 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 9)
# [2017-01-29 23:11:15.741000] iteration = 22 / 50
# name = model_20_m1_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:12:00.543000] 12 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 17)
# [2017-01-29 23:12:00.544000] iteration = 23 / 50
# name = model_20_m1_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:12:47.770000] 31 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 6)
# [2017-01-29 23:12:47.771000] iteration = 24 / 50
# name = model_20_m1_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:13:32.140000] 4 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 22)
# [2017-01-29 23:13:32.140000] iteration = 25 / 50
# name = model_20_m1_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:14:19.883000] 32 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 10)
# [2017-01-29 23:14:19.883000] iteration = 26 / 50
# name = model_20_m1_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:15:01.518000] 10 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-01-29 23:15:01.518000] iteration = 27 / 50
# name = model_20_m1_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:15:48.585000] 31 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 9)
# [2017-01-29 23:15:48.585000] iteration = 28 / 50
# name = model_20_m1_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:16:30.346000] 5 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 24)
# [2017-01-29 23:16:30.346000] iteration = 29 / 50
# name = model_20_m1_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:17:14.260000] 37 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 7)
# [2017-01-29 23:17:14.260000] iteration = 30 / 50
# name = model_20_m1_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:17:52.428000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 27)
# [2017-01-29 23:17:52.428000] iteration = 31 / 50
# name = model_20_m1_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:18:33.868000] 41 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 6)
# [2017-01-29 23:18:33.868000] iteration = 32 / 50
# name = model_20_m1_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:19:09.295000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 25)
# [2017-01-29 23:19:09.295000] iteration = 33 / 50
# name = model_20_m1_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:19:51.226000] 40 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 5)
# [2017-01-29 23:19:51.226000] iteration = 34 / 50
# name = model_20_m1_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:20:29.375000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 23)
# [2017-01-29 23:20:29.376000] iteration = 35 / 50
# name = model_20_m1_iter_35, n_topics = 20, n_doc_passes = 5, seed_value = 135, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:21:10.259000] 36 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 7)
# [2017-01-29 23:21:10.259000] iteration = 36 / 50
# name = model_20_m1_iter_36, n_topics = 20, n_doc_passes = 5, seed_value = 136, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:21:48.462000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 21)
# [2017-01-29 23:21:48.462000] iteration = 37 / 50
# name = model_20_m1_iter_37, n_topics = 20, n_doc_passes = 5, seed_value = 137, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:22:28.915000] 35 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 6)
# [2017-01-29 23:22:28.915000] iteration = 38 / 50
# name = model_20_m1_iter_38, n_topics = 20, n_doc_passes = 5, seed_value = 138, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:23:06.255000] 5 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 21)
# [2017-01-29 23:23:06.255000] iteration = 39 / 50
# name = model_20_m1_iter_39, n_topics = 20, n_doc_passes = 5, seed_value = 139, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:23:46.153000] 36 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 5)
# [2017-01-29 23:23:46.153000] iteration = 40 / 50
# name = model_20_m1_iter_40, n_topics = 20, n_doc_passes = 5, seed_value = 140, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:24:19.541000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 23)
# [2017-01-29 23:24:19.541000] iteration = 41 / 50
# name = model_20_m1_iter_41, n_topics = 20, n_doc_passes = 5, seed_value = 141, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:24:55.570000] 37 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 6)
# [2017-01-29 23:24:55.570000] iteration = 42 / 50
# name = model_20_m1_iter_42, n_topics = 20, n_doc_passes = 5, seed_value = 142, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:25:30.083000] 3 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 23)
# [2017-01-29 23:25:30.083000] iteration = 43 / 50
# name = model_20_m1_iter_43, n_topics = 20, n_doc_passes = 5, seed_value = 143, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:26:07.424000] 38 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 5)
# [2017-01-29 23:26:07.424000] iteration = 44 / 50
# name = model_20_m1_iter_44, n_topics = 20, n_doc_passes = 5, seed_value = 144, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:26:42.034000] 4 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 21)
# [2017-01-29 23:26:42.035000] iteration = 45 / 50
# name = model_20_m1_iter_45, n_topics = 20, n_doc_passes = 5, seed_value = 145, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:27:17.728000] 31 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 10)
# [2017-01-29 23:27:17.728000] iteration = 46 / 50
# name = model_20_m1_iter_46, n_topics = 20, n_doc_passes = 5, seed_value = 146, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:27:55.925000] 8 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 22)
# [2017-01-29 23:27:55.925000] iteration = 47 / 50
# name = model_20_m1_iter_47, n_topics = 20, n_doc_passes = 5, seed_value = 147, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:28:31.598000] 36 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 6)
# [2017-01-29 23:28:31.598000] iteration = 48 / 50
# name = model_20_m1_iter_48, n_topics = 20, n_doc_passes = 5, seed_value = 148, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:29:04.560000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-01-29 23:29:04.560000] iteration = 49 / 50
# name = model_20_m1_iter_49, n_topics = 20, n_doc_passes = 5, seed_value = 149, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:29:45.945000] 31 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 9)

# %%
OPT_FUN_THRESHOLD = 0.2
phi_convex_hull_1, iterations_info_1 = build_convex_hull(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)
# Out:
# [2017-01-29 23:32:23.095000] iteration = 0 / 50
# name = model_20_m1_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:32:49.895000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 20)
# [2017-01-29 23:32:49.895000] iteration = 1 / 50
# name = model_20_m1_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:33:22.115000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 38)
# [2017-01-29 23:33:22.115000] iteration = 2 / 50
# name = model_20_m1_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:33:58.544000] 3 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 55)
# [2017-01-29 23:33:58.544000] iteration = 3 / 50
# name = model_20_m1_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:34:42.169000] 7 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 68)
# [2017-01-29 23:34:42.170000] iteration = 4 / 50
# name = model_20_m1_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:35:26.740000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 82)
# [2017-01-29 23:35:26.740000] iteration = 5 / 50
# name = model_20_m1_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:36:14.912000] 4 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 98)
# [2017-01-29 23:36:14.913000] iteration = 6 / 50
# name = model_20_m1_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:37:07.040000] 0 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 118)
# [2017-01-29 23:37:07.040000] iteration = 7 / 50
# name = model_20_m1_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:38:06.039000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 132)
# [2017-01-29 23:38:06.039000] iteration = 8 / 50
# name = model_20_m1_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:39:06.441000] 11 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 141)
# [2017-01-29 23:39:06.441000] iteration = 9 / 50
# name = model_20_m1_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:40:10.879000] 2 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 159)
# [2017-01-29 23:40:10.879000] iteration = 10 / 50
# name = model_20_m1_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:41:22.476000] 7 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 172)
# [2017-01-29 23:41:22.476000] iteration = 11 / 50
# name = model_20_m1_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:42:38.644000] 1 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 191)
# [2017-01-29 23:42:38.644000] iteration = 12 / 50
# name = model_20_m1_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:44:08.004000] 9 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 202)
# [2017-01-29 23:44:08.004000] iteration = 13 / 50
# name = model_20_m1_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:45:38.722000] 10 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 212)
# [2017-01-29 23:45:38.722000] iteration = 14 / 50
# name = model_20_m1_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:47:14.959000] 10 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 222)
# [2017-01-29 23:47:14.959000] iteration = 15 / 50
# name = model_20_m1_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:48:57.603000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 236)
# [2017-01-29 23:48:57.603000] iteration = 16 / 50
# name = model_20_m1_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:50:44.955000] 10 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 246)
# [2017-01-29 23:50:44.956000] iteration = 17 / 50
# name = model_20_m1_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:52:35.628000] 8 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 258)
# [2017-01-29 23:52:35.628000] iteration = 18 / 50
# name = model_20_m1_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:54:34] 3 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 275)
# [2017-01-29 23:54:34.001000] iteration = 19 / 50
# name = model_20_m1_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:56:44.363000] 7 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 288)
# [2017-01-29 23:56:44.363000] iteration = 20 / 50
# name = model_20_m1_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-29 23:59:02.985000] 10 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 298)
# [2017-01-29 23:59:02.985000] iteration = 21 / 50
# name = model_20_m1_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:01:29.108000] 7 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 311)
# [2017-01-30 00:01:29.108000] iteration = 22 / 50
# name = model_20_m1_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:04:02.249000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 325)
# [2017-01-30 00:04:02.249000] iteration = 23 / 50
# name = model_20_m1_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:06:46.269000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 339)
# [2017-01-30 00:06:46.270000] iteration = 24 / 50
# name = model_20_m1_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:09:38.352000] 7 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 352)
# [2017-01-30 00:09:38.352000] iteration = 25 / 50
# name = model_20_m1_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:12:39.360000] 8 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 364)
# [2017-01-30 00:12:39.361000] iteration = 26 / 50
# name = model_20_m1_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:15:51.954000] 9 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 375)
# [2017-01-30 00:15:51.954000] iteration = 27 / 50
# name = model_20_m1_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:19:16.755000] 4 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 391)
# [2017-01-30 00:19:16.755000] iteration = 28 / 50
# name = model_20_m1_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:22:54.489000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 405)
# [2017-01-30 00:22:54.489000] iteration = 29 / 50
# name = model_20_m1_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:26:42.385000] 9 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 416)
# [2017-01-30 00:26:42.385000] iteration = 30 / 50
# name = model_20_m1_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:30:42.538000] 11 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 425)
# [2017-01-30 00:30:42.539000] iteration = 31 / 50
# name = model_20_m1_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:34:54.140000] 7 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 438)
# [2017-01-30 00:34:54.141000] iteration = 32 / 50
# name = model_20_m1_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:39:15.509000] 16 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 442)
# [2017-01-30 00:39:15.509000] iteration = 33 / 50
# name = model_20_m1_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:43:41.662000] 5 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 457)
# [2017-01-30 00:43:41.663000] iteration = 34 / 50
# name = model_20_m1_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:48:25.750000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 471)
# [2017-01-30 00:48:25.750000] iteration = 35 / 50
# name = model_20_m1_iter_35, n_topics = 20, n_doc_passes = 5, seed_value = 135, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:53:20.511000] 5 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 486)
# [2017-01-30 00:53:20.511000] iteration = 36 / 50
# name = model_20_m1_iter_36, n_topics = 20, n_doc_passes = 5, seed_value = 136, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 00:58:24.455000] 3 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 503)
# [2017-01-30 00:58:24.456000] iteration = 37 / 50
# name = model_20_m1_iter_37, n_topics = 20, n_doc_passes = 5, seed_value = 137, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:03:39.176000] 12 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 511)
# [2017-01-30 01:03:39.176000] iteration = 38 / 50
# name = model_20_m1_iter_38, n_topics = 20, n_doc_passes = 5, seed_value = 138, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:09:01.468000] 13 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 518)
# [2017-01-30 01:09:01.468000] iteration = 39 / 50
# name = model_20_m1_iter_39, n_topics = 20, n_doc_passes = 5, seed_value = 139, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:14:34.295000] 13 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 525)
# [2017-01-30 01:14:34.296000] iteration = 40 / 50
# name = model_20_m1_iter_40, n_topics = 20, n_doc_passes = 5, seed_value = 140, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:20:11.886000] 6 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 539)
# [2017-01-30 01:20:11.886000] iteration = 41 / 50
# name = model_20_m1_iter_41, n_topics = 20, n_doc_passes = 5, seed_value = 141, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:26:04.482000] 4 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 555)
# [2017-01-30 01:26:04.483000] iteration = 42 / 50
# name = model_20_m1_iter_42, n_topics = 20, n_doc_passes = 5, seed_value = 142, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:32:19.073000] 8 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 567)
# [2017-01-30 01:32:19.073000] iteration = 43 / 50
# name = model_20_m1_iter_43, n_topics = 20, n_doc_passes = 5, seed_value = 143, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:38:44.188000] 13 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 574)
# [2017-01-30 01:38:44.203000] iteration = 44 / 50
# name = model_20_m1_iter_44, n_topics = 20, n_doc_passes = 5, seed_value = 144, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25
#
# [2017-01-30 01:45:19.106000] 10 topics to remove, 0 not_removed_topics_count because close topics, current convex_hull shape = (2216, 584)
# [2017-01-30 01:45:19.106000] iteration = 45 / 50
# name = model_20_m1_iter_45, n_topics = 20, n_doc_passes = 5, seed_value = 145, n_iterations = 20, n_top_tokens = 15, p_threshold = 0.25

# %%
OPT_FUN_THRESHOLD = 0.3
phi_convex_hull_2, iterations_info_2 = build_convex_hull(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.4
phi_convex_hull_3, iterations_info_3 = build_convex_hull(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_4, iterations_info_4 = build_convex_hull(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.5
N_CLOSEST_TOPICS = 10
phi_convex_hull_5, iterations_info_5 = build_convex_hull(create_model_fn_1, get_topics_to_remove_by_opt_fun_and_distance, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.5
N_CLOSEST_TOPICS = 15
phi_convex_hull_6, iterations_info_6 = build_convex_hull(create_model_fn_1, get_topics_to_remove_by_opt_fun_and_distance, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.2
phi_convex_hull_7, iterations_info_7 = build_convex_hull_2(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.3
phi_convex_hull_8, iterations_info_8 = build_convex_hull_2(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.4
phi_convex_hull_9, iterations_info_9 = build_convex_hull_2(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
OPT_FUN_THRESHOLD = 0.5
phi_convex_hull_10, iterations_info_10 = build_convex_hull_2(create_model_fn_1, get_topics_to_remove_by_opt_fun, phi_original.index,
                                                     init_convex_hull=[], start_iteration=0,
                                                     max_iteration=50)

# %%
# %matplotlib inline
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False, figsize=(15,5))
ax1.plot([val['n_topics_to_remove'] for val in iterations_info], color='r', label='model1')
ax1.set_title('Num columns to remove')
ax1.set_xlabel('n iteration')
ax1.legend()

ax2.plot([val['phi_convex_hull_shape'][1] for val in iterations_info], color='r', label='model1')
ax2.set_title('Num columns of convex hull')
ax2.set_xlabel('n iteration')
ax2.legend()

get_topic_iteration_fn = lambda x: int(x[x.rfind('_') + 1 :])
n_topics_removed_from_current_iteration = [[get_topic_iteration_fn(t) for t in it['removed_topics']].count(indx) for indx, it in enumerate(iterations_info)]
ax1.plot(n_topics_removed_from_current_iteration, color='b')

# %%
filtered_phi_convex_hull, filtered_iterations_info = filter_convex_hull(phi_convex_hull.copy(), max_iteration=20)
# Out:
# [2017-01-29 20:33:09.297000] take_distances between 139 columns and 139 columns
# [2017-01-29 20:33:09.301000] column 0 / 139
# [2017-01-29 20:33:11.629000] column 20 / 139
# [2017-01-29 20:33:13.710000] column 40 / 139
# [2017-01-29 20:33:15.929000] column 60 / 139
# [2017-01-29 20:33:18.057000] column 80 / 139
# [2017-01-29 20:33:20.149000] column 100 / 139
# [2017-01-29 20:33:22.247000] column 120 / 139
# [2017-01-29 20:33:24.259000] iteration = 0 / 20
# [2017-01-29 20:33:24.259000] get_optimization_result for column 0 / 139
# [2017-01-29 20:33:26.885000] get_optimization_result for column 20 / 139
# [2017-01-29 20:33:30.921000] get_optimization_result for column 40 / 139
# [2017-01-29 20:33:33.839000] get_optimization_result for column 60 / 139
# [2017-01-29 20:33:37.092000] get_optimization_result for column 80 / 139
# [2017-01-29 20:33:39.808000] get_optimization_result for column 100 / 139
# [2017-01-29 20:33:42.224000] get_optimization_result for column 120 / 139
# [2017-01-29 20:33:44.958000] 20 topics to remove, current convex_hull shape = (2216, 119)
# [2017-01-29 20:33:44.958000] iteration = 1 / 20
# [2017-01-29 20:33:44.958000] get_optimization_result for column 0 / 119
# [2017-01-29 20:33:47.487000] get_optimization_result for column 20 / 119
# [2017-01-29 20:33:50.243000] get_optimization_result for column 40 / 119
# [2017-01-29 20:33:52.985000] get_optimization_result for column 60 / 119
# [2017-01-29 20:33:55.636000] get_optimization_result for column 80 / 119
# [2017-01-29 20:33:57.927000] get_optimization_result for column 100 / 119
# [2017-01-29 20:34:00.943000] 18 topics to remove, current convex_hull shape = (2216, 101)
# [2017-01-29 20:34:00.943000] iteration = 2 / 20
# [2017-01-29 20:34:00.943000] get_optimization_result for column 0 / 101
# [2017-01-29 20:34:03.614000] get_optimization_result for column 20 / 101
# [2017-01-29 20:34:05.994000] get_optimization_result for column 40 / 101
# [2017-01-29 20:34:09.156000] get_optimization_result for column 60 / 101
# [2017-01-29 20:34:11.844000] get_optimization_result for column 80 / 101
# [2017-01-29 20:34:14.267000] get_optimization_result for column 100 / 101
# [2017-01-29 20:34:14.752000] 15 topics to remove, current convex_hull shape = (2216, 86)
# [2017-01-29 20:34:14.752000] iteration = 3 / 20
# [2017-01-29 20:34:14.752000] get_optimization_result for column 0 / 86
# [2017-01-29 20:34:17.892000] get_optimization_result for column 20 / 86
# [2017-01-29 20:34:20.502000] get_optimization_result for column 40 / 86
# [2017-01-29 20:34:23.502000] get_optimization_result for column 60 / 86
# [2017-01-29 20:34:26.669000] get_optimization_result for column 80 / 86
# [2017-01-29 20:34:27.427000] 9 topics to remove, current convex_hull shape = (2216, 77)
# [2017-01-29 20:34:27.428000] iteration = 4 / 20
# [2017-01-29 20:34:27.428000] get_optimization_result for column 0 / 77
# [2017-01-29 20:34:29.629000] get_optimization_result for column 20 / 77
# [2017-01-29 20:34:31.861000] get_optimization_result for column 40 / 77
# [2017-01-29 20:34:34.723000] get_optimization_result for column 60 / 77
# [2017-01-29 20:34:36.977000] 5 topics to remove, current convex_hull shape = (2216, 72)
# [2017-01-29 20:34:36.977000] iteration = 5 / 20
# [2017-01-29 20:34:36.977000] get_optimization_result for column 0 / 72
# [2017-01-29 20:34:39.272000] get_optimization_result for column 20 / 72
# [2017-01-29 20:34:42.339000] get_optimization_result for column 40 / 72
# [2017-01-29 20:34:45.027000] get_optimization_result for column 60 / 72
# [2017-01-29 20:34:46.790000] 4 topics to remove, current convex_hull shape = (2216, 68)
# [2017-01-29 20:34:46.790000] iteration = 6 / 20
# [2017-01-29 20:34:46.790000] get_optimization_result for column 0 / 68
# [2017-01-29 20:34:49.570000] get_optimization_result for column 20 / 68
# [2017-01-29 20:34:52.646000] get_optimization_result for column 40 / 68
# [2017-01-29 20:34:55.121000] get_optimization_result for column 60 / 68
# [2017-01-29 20:34:56.122000] 2 topics to remove, current convex_hull shape = (2216, 66)
# [2017-01-29 20:34:56.122000] iteration = 7 / 20
# [2017-01-29 20:34:56.122000] get_optimization_result for column 0 / 66
# [2017-01-29 20:34:59.085000] get_optimization_result for column 20 / 66
# [2017-01-29 20:35:02.099000] get_optimization_result for column 40 / 66
# [2017-01-29 20:35:04.686000] get_optimization_result for column 60 / 66
# [2017-01-29 20:35:06.019000] 1 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:35:06.019000] iteration = 8 / 20
# [2017-01-29 20:35:06.019000] get_optimization_result for column 0 / 65
# [2017-01-29 20:35:08.583000] get_optimization_result for column 20 / 65
# [2017-01-29 20:35:11.398000] get_optimization_result for column 40 / 65
# [2017-01-29 20:35:14.213000] get_optimization_result for column 60 / 65
# [2017-01-29 20:35:14.861000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:35:14.862000] iteration = 9 / 20
# [2017-01-29 20:35:14.862000] get_optimization_result for column 0 / 65
# [2017-01-29 20:35:17.576000] get_optimization_result for column 20 / 65
# [2017-01-29 20:35:20.554000] get_optimization_result for column 40 / 65
# [2017-01-29 20:35:23.513000] get_optimization_result for column 60 / 65
# [2017-01-29 20:35:24.244000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:35:24.244000] iteration = 10 / 20
# [2017-01-29 20:35:24.244000] get_optimization_result for column 0 / 65
# [2017-01-29 20:35:26.430000] get_optimization_result for column 20 / 65
# [2017-01-29 20:35:28.925000] get_optimization_result for column 40 / 65
# [2017-01-29 20:35:31.845000] get_optimization_result for column 60 / 65
# [2017-01-29 20:35:32.772000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:35:32.772000] iteration = 11 / 20
# [2017-01-29 20:35:32.772000] get_optimization_result for column 0 / 65
# [2017-01-29 20:35:35.930000] get_optimization_result for column 20 / 65
# [2017-01-29 20:35:39.300000] get_optimization_result for column 40 / 65
# [2017-01-29 20:35:41.654000] get_optimization_result for column 60 / 65
# [2017-01-29 20:35:42.107000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:35:42.107000] iteration = 12 / 20
# [2017-01-29 20:35:42.107000] get_optimization_result for column 0 / 65
# [2017-01-29 20:35:45.145000] get_optimization_result for column 20 / 65
# [2017-01-29 20:35:48.175000] get_optimization_result for column 40 / 65
# [2017-01-29 20:35:50.867000] get_optimization_result for column 60 / 65
# [2017-01-29 20:35:51.599000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:35:51.599000] iteration = 13 / 20
# [2017-01-29 20:35:51.599000] get_optimization_result for column 0 / 65
# [2017-01-29 20:35:54.290000] get_optimization_result for column 20 / 65
# [2017-01-29 20:35:57.798000] get_optimization_result for column 40 / 65
# [2017-01-29 20:36:01.348000] get_optimization_result for column 60 / 65
# [2017-01-29 20:36:01.836000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:36:01.836000] iteration = 14 / 20
# [2017-01-29 20:36:01.837000] get_optimization_result for column 0 / 65
# [2017-01-29 20:36:04.545000] get_optimization_result for column 20 / 65
# [2017-01-29 20:36:07.107000] get_optimization_result for column 40 / 65
# [2017-01-29 20:36:10.165000] get_optimization_result for column 60 / 65
# [2017-01-29 20:36:11.378000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:36:11.378000] iteration = 15 / 20
# [2017-01-29 20:36:11.378000] get_optimization_result for column 0 / 65
# [2017-01-29 20:36:13.855000] get_optimization_result for column 20 / 65
# [2017-01-29 20:36:16.184000] get_optimization_result for column 40 / 65
# [2017-01-29 20:36:18.897000] get_optimization_result for column 60 / 65
# [2017-01-29 20:36:19.782000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:36:19.782000] iteration = 16 / 20
# [2017-01-29 20:36:19.782000] get_optimization_result for column 0 / 65
# [2017-01-29 20:36:22.742000] get_optimization_result for column 20 / 65
# [2017-01-29 20:36:25.225000] get_optimization_result for column 40 / 65
# [2017-01-29 20:36:27.969000] get_optimization_result for column 60 / 65
# [2017-01-29 20:36:28.609000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:36:28.609000] iteration = 17 / 20
# [2017-01-29 20:36:28.609000] get_optimization_result for column 0 / 65
# [2017-01-29 20:36:31.250000] get_optimization_result for column 20 / 65
# [2017-01-29 20:36:35.794000] get_optimization_result for column 40 / 65
# [2017-01-29 20:36:38.318000] get_optimization_result for column 60 / 65
# [2017-01-29 20:36:39.029000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:36:39.029000] iteration = 18 / 20
# [2017-01-29 20:36:39.029000] get_optimization_result for column 0 / 65
# [2017-01-29 20:36:42.096000] get_optimization_result for column 20 / 65
# [2017-01-29 20:36:45.843000] get_optimization_result for column 40 / 65
# [2017-01-29 20:36:49.047000] get_optimization_result for column 60 / 65
# [2017-01-29 20:36:50.586000] 0 topics to remove, current convex_hull shape = (2216, 65)
# [2017-01-29 20:36:50.586000] iteration = 19 / 20
# [2017-01-29 20:36:50.586000] get_optimization_result for column 0 / 65
# [2017-01-29 20:36:53.464000] get_optimization_result for column 20 / 65
# [2017-01-29 20:36:56.859000] get_optimization_result for column 40 / 65
# [2017-01-29 20:36:59.490000] get_optimization_result for column 60 / 65
# [2017-01-29 20:37:00.306000] 0 topics to remove, current convex_hull shape = (2216, 65)

# %%
# to do : save phi_convex on each iteration,
# make plot each iteration , save it
# разобраться почему 
# заодно сразу стабильность мерить
# спроектировать конечный результат на оригинальную
# Out:
# [0, 2, 4, 6, 4, 9, 8, 7, 12, 7, 8, 9, 10, 10, 11, 15, 13, 13, 11, 13, 11, 15, 9, 13, 15, 15, 7, 11, 16, 8, 12, 11, 11, 18, 6, 10, 12, 11, 12, 13, 17, 15, 16, 11, 15, 12, 15, 14, 13, 15]
